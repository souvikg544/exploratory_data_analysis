# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("air_data.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month   Day
# 0           NaN    NaN      NaN   NaN   NaN    NaN   NaN
# 1           1.0   41.0    190.0   7.4  67.0    5.0   1.0
# 2           2.0   36.0    118.0   8.0  72.0    5.0   2.0
# 3           3.0   12.0    149.0  12.6  74.0    5.0   3.0
# 4           4.0   18.0    313.0  11.5  62.0    5.0   4.0
# ..          ...    ...      ...   ...   ...    ...   ...
# 105       105.0   28.0    273.0  11.5  82.0    8.0  13.0
# 106       106.0   65.0    157.0   9.7  80.0    8.0  14.0
# 107       107.0    NaN     64.0  11.5  79.0    8.0  15.0
# 108       108.0   22.0     71.0  10.3  77.0    8.0  16.0
# 109         NaN    NaN      NaN   NaN   NaN    NaN   NaN
#
# [110 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     2
# Ozone         36
# Solar.R        9
# Wind           2
# Temp           2
# Month          2
# Day            2
# dtype: int64

# %%
data=data.drop(index=[0,109])

# %%
data1=data.fillna(data.mean())
data1
# Out:
#      Unnamed: 0      Ozone     Solar.R  Wind  Temp  Month   Day
# 1           1.0  41.000000  190.000000   7.4  67.0    5.0   1.0
# 2           2.0  36.000000  118.000000   8.0  72.0    5.0   2.0
# 3           3.0  12.000000  149.000000  12.6  74.0    5.0   3.0
# 4           4.0  18.000000  313.000000  11.5  62.0    5.0   4.0
# 5           5.0  42.418919  191.108911  14.3  56.0    5.0   5.0
# ..          ...        ...         ...   ...   ...    ...   ...
# 104       104.0  44.000000  192.000000  11.5  86.0    8.0  12.0
# 105       105.0  28.000000  273.000000  11.5  82.0    8.0  13.0
# 106       106.0  65.000000  157.000000   9.7  80.0    8.0  14.0
# 107       107.0  42.418919   64.000000  11.5  79.0    8.0  15.0
# 108       108.0  22.000000   71.000000  10.3  77.0    8.0  16.0
#
# [108 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
data1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f74be8f7f10>,
# ...
#       dtype=object)

# %%
data1.plot.bar()

# %%
plt.scatter(data1['Wind'],data1['Temp'])
plt.ylabel("Temp")
plt.xlabel("Wind")
plt.show()

# %%
import seaborn as sns
sns.kdeplot(data1['Temp'])

# %%
fig = sns.kdeplot(data1['Temp'], shade=True, color="r")
fig = sns.kdeplot(data1['Wind'], shade=True, color="b")
plt.show()

# %%
fig = plt.figure(figsize = (15, 10))
plt.bar(data1["Unnamed: 0"], data1["Ozone"])
plt.xlabel("#Day")
plt.ylabel("Ozone")
plt.show()

# %%
data1.plot(figsize=(10,5))

# %%
sns.countplot(data1['Month'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
airdata = data1[['Temp']].head(10)
airdata.plot.area()

# %%
sns.pairplot(data1, kind = 'scatter')

# %%
plt.scatter(data1['Ozone'],data1['Temp'])
plt.ylabel("Temp")
plt.xlabel("Month")
plt.show()
