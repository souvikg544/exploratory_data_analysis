# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyanadipta/LGMVIP-DataScience/blob/main/Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **TASK 2 -- Image to Pencil Sketch with Python**

# %%
import cv2
from IPython.display import Image
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Image Loading**

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-7364305f-d374-4d55-bde0-73da9da2e5c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7364305f-d374-4d55-bde0-73da9da2e5c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.jpg to download.jpg

# %%
image = cv2.imread("download.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FA2AE935CD0>

# %% [markdown]
# Grayscale Image

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FA2BBBE30D0>

# %% [markdown]
# Invert Image

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# invert the values of color code
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FA2AE8DD390>

# %% [markdown]
# Blur Image

# %%
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FA2AE8E3550>

# %% [markdown]
# Inverted Blur Image

# %%
inverted_blurred = 255 - blurred
cv2_imshow(inverted_blurred)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FA2AD8705D0>

# %% [markdown]
# **Pencil Sketch**

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FA2AD870F10>
