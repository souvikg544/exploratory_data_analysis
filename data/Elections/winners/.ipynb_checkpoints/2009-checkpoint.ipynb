# %% [markdown]
# # EDA : Lok Sabha Winners, 2009

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate",  "Constituency", "Party", "Criminal Cases", "Education", "Total Assets", "Liabilities", "Year"]
    data = []
    constituencies = 0
    try:
        url = "https://myneta.info/ls2009/index.php?action=show_winners&sort=default"
        html = urlopen(url)
        soup = BeautifulSoup(html,'html.parser')
        title = soup.title.text
        title = title.split()
        title = title[4:-3]
        title = " ".join(title)
        title = title.title()
        title = title.split(":")
        constituency = "+".join(title)
        title = ",".join(title)
        table = soup.find('table',attrs={'style':'padding: 0px;'})
        rows = table.find_all('tr')
        for i in range(2, len(rows)):
            col_data = []
            cols = rows[i].find_all('td')
            for i in range(1, 6):
                col_data.append(cols[i].text)
            for i in range(6, 8):
                col_data.append(inr_to_int(cols[i].text))
            col_data.append(2009)
            data.append(col_data)
            print("Saving", col_data[1], "=>", col_data[0], "("+col_data[2]+")")
            constituencies += 1
    except:
        print('ERROR')
    else:
        print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', constituencies, 'constituencies')
    df.to_csv('2009.csv', index=False)
    

main()
# Out:
# Saving Adilabad => Ramesh Rathod (TDP)
# Saving Agra => DR. RAMSHANKAR (BJP)
# Saving Ahmedabad East => HARIN PATHAK (BJP)
# Saving Ahmedabad West => KIRITBHAI PREMJIBHAI SOLANKI (BJP)
# Saving Ahmednagar => GANDHI DILIPKUMAR MANSUKHLAL (BJP)
# Saving Ajmer => SACHIN PILOT (INC)
# Saving Akbarpur => RAJARAM PAL (INC)
# Saving Akola => DHOTRE SANJAY SHAMRAO (BJP)
# Saving Alappuzha => K C Venugopal (INC)
# Saving Alathur => P K Biju (CPM)
# Saving Aligarh => RAJ KUMARI CHAUHAN (BSP)
# Saving Alipurduars => Manohar Tirkey (RSP)
# Saving Allahabad => KUNWAR REWATI RAMAN SINGH ALIAS MANI JI (SP)
# Saving Almora => PRADEEP TAMTA (INC)
# Saving Alwar => JITENDRA SINGH (INC)
# Saving Amalapuram => G V Harsha Kumar (INC)
# Saving Ambala => SELJA (INC)
# Saving Ambedkar Nagar => RAKESH PANDEY (BSP)
# Saving Amethi => RAHUL GANDHI (INC)
# Saving Amravati => ADSUL ANANDRAO VITHOBA (SHS)
# Saving Amreli => NARANBHAI BHIKHABHAI KACHHADIYA (BJP)
# Saving Amritsar => NAVJOT SINGH SIDHU (BJP)
# Saving Amroha => DEVENDRA NAGPAL (RLD)
# Saving Anakapalle => Sabbam Hari (INC)
# Saving Anandpur Sahib => RAVNEET SINGH (INC)
# Saving Anantapur => ANANTHA VENKATA RAMI REDDY (INC)
# Saving Anantnag => MIRZA MEHBOOB BEG (JKN)
# Saving Andaman & Nicobar Islands => Shri Bishnu Pada Ray (BJP)
# Saving Aonla => MANEKA GANDHI (BJP)
# Saving Arakkonam => JAGATHRAKSHAKAN (DMK)
# Saving Araku => V. Kishore Chandra Deo (INC)
# Saving Arambag => SAKTI MOHAN MALIK (CPM)
# Saving Arani => KRISHNASAMY M (INC)
# Saving Araria => PRADEEP KUMAR SINGH (BJP)
# Saving Arrah => Meena Singh (JD(U))
# Saving Arunachal East => NINONG ERING (INC)
# Saving Arunachal West => TAKAM SANJOY (INC)
# Saving Asansol => BANSAGOPAL CHOWDHURY (CPM)
# Saving Aska => Nityananda Pradhan (BJD)
# Saving Attingal => Adv A Sampath (CPM)
# Saving Aurangabad => CHANDRAKANT KHAIRE (SHS)
# Saving Aurangabad => Sushil Kumar Singh (JD(U))
# Saving Autonomous District => BIREN SINGH ENGTI (INC)
# Saving Azamgarh => RAMAKANT YADAV (BJP)
# Saving Badaun => DHARMENDRA YADAV (SP)
# Saving Bagalkot => GADDIGOUDAR P C (BJP)
# Saving Baghpat => AJIT SINGH (RLD)
# Saving Baharampur => ADHIR RANJAN CHOWDHURY (INC)
# Saving Bahraich => KAMAL KISHOR (INC)
# Saving Balasore => Srikanta Kumar Jena (INC)
# Saving Ballia => NEERAJ SHEKHAR (SP)
# Saving Balurghat => Prasanta Kumar Majumdar (RSP)
# Saving Banaskantha => MUKESH BHAIRAVDANJI GADHAVI (INC)
# Saving Banda => R. K. SINGH PATEL (SP)
# Saving Bangalore Central => P.C.Mohan (BJP)
# Saving Bangalore North => D.B. Chandre Gowda (BJP)
# Saving Bangalore Rural => H D KUMARA SWAMY (JD(S))
# Saving Bangalore South => Ananth Kumar (BJP)
# Saving Bangaon => GOBINDA CHANDRA NASKAR (AITC)
# Saving Bankura => Acharia Basudeb (CPM)
# Saving Banswara => Tara chand (INC)
# Saving Bapatla => PANABAKA LAKSHMI (INC)
# Saving Barabanki => P.L.PUNIA (INC)
# Saving Baramati => SUPRIYA SULE (NCP)
# Saving Baramulla => SHARIEF UD DIN SHARIQ (JKN)
# Saving Barasat => KAKALI GHOSH DASTIDAR (AITC)
# Saving Bardhaman Purba => ANUP KUMAR SAHA (CPM)
# Saving Bardhaman-Durgapur => SK. SAIDUL HAQUE (CPM)
# Saving Bareilly => PRAVEEN SINGH ARON (INC)
# Saving Bargarh => Sanjay Bhoi (INC)
# Saving Barmer => Harish choudhary (INC)
# Saving Barpeta => ISMAIL HUSSAIN (INC)
# Saving Barrackpur => DINESH TRIVEDI (AITC)
# Saving Basirhat => SK. NURUL ISLAM (AITC)
# Saving Bastar => Baliram Kashyap (BJP)
# Saving Basti => ARVIND KUMAR CHAUDHARY (BSP)
# Saving Bathinda => HARSIMRAT KAUR (SAD)
# Saving Beed => MUNDE GOPINATHRAO PANDURANG (BJP)
# Saving Begusarai => DR. MONAZIR HASSAN (JD(U))
# Saving Belgaum => Angadi Suresh Channabasappa (BJP)
# Saving Bellary => J. SHANTHA (BJP)
# Saving Berhampur => Sidhant Mohapatra (BJD)
# Saving Betul => JYOTI DHURVE (BJP)
# Saving Bhadohi => GORAKHNATH (BSP)
# Saving Bhadrak => Arjun Charan Sethi (BJD)
# Saving Bhagalpur => SYED SHAHNAWAZ HUSSAIN (BJP)
# Saving Bharatpur => RATAN SINGH (INC)
# Saving Bharuch => MANSUKHBHAI DHANJIBHAI VASAVA (BJP)
# Saving Bhavnagar => RAJENDRASINH GHANSHYAMSINH RANA (BJP)
# Saving Bhilwara => C P JOSHI (INC)
# Saving Bhind => ASHOK ARGAL (BJP)
# Saving Bhiwandi => TAWARE SURESH KASHINATH (INC)
# Saving Bhiwani-Mahendragarh => SHRUTI CHOUDHRY (INC)
# Saving Bhongir => KOMATIREDDY RAJ GOPAL REDDY (INC)
# Saving Bhopal => KAILASH JOSHI (BJP)
# Saving Bhubaneswar => Prasanna Kumar Patasani (BJD)
# Saving Bidar => N. Dharamsingh (INC)
# Saving Bijapur => Jigajinagi Ramesh Chandappa (BJP)
# Saving Bijnor => SANJAY SINGH CHAUHAN (RLD)
# Saving Bikaner => ARJUN RAM MEGHWAL (BJP)
# Saving Birbhum => SATABDI ROY (BANERJEE) (AITC)
# Saving Bishnupur => Susmita Bauri (CPM)
# Saving Bolangir => KALIKESH NARAYAN SINGH DEO (BJD)
# Saving Bolpur => RAM CHANDRA DOME (CPM)
# Saving Bulandshahr => KAMLESH (SP)
# Saving Buldhana => JADHAV PRATAPRAO GANPATRAO (SHS)
# Saving Buxar => Jagda Nand singh (RJD)
# Saving Chalakudy => K P Dhanapalan (INC)
# Saving Chamarajanagar => R.DHRUVANARAYANA (INC)
# Saving Chandauli => RAMKISHUN (SP)
# Saving Chandigarh => PAWAN KUMAR BANSAL (INC)
# Saving Chandni Chowk => KAPIL SIBAL (INC)
# Saving Chandrapur => AHIR HANSARAJ GANGARAM (BJP)
# Saving Chatra => Inder Singh Namdhari (IND)
# Saving Chennai South => RAJENDRAN C (ADMK)
# Saving Chevella => Sudini Jaipal Reddy (INC)
# Saving Chhota Udaipur => RAMSINHBHAI PATALBHAI RATHAVA (BJP)
# Saving Chidambaram => THIRUMAAVALAVAN, THOL (VCK)
# Saving Chikkballapur => M. Veerappa Moily (INC)
# Saving Chikkodi => KATTI RAMESH VISHWANATH (BJP)
# Saving Chitradurga => JANARDHANA SWAMY (BJP)
# Saving Chittoor => NARAMALLI SIVAPRASAD (TDP)
# Saving Chittorgarh => GIRIJA VYAS (INC)
# Saving Churu => RAM SINGH KASWAN (BJP)
# Saving Coimbatore => NATARAJAN.P.R. (CPM)
# Saving Coochbehar => Nripendra Nath Ray (AIFB)
# Saving Cuddalore => ALAGIRI S (INC)
# Saving Cuttack => Bhartruhari Mahtab (BJD)
# Saving Dadra & Nagar Haveli => PATEL NATUBHAI GOMANBHAI (BJP)
# Saving Dahod => PRABHABEN KISHORESINH TAVIAD (INC)
# Saving Dakshina Kannada => Nalin Kumar Kateel (BJP)
# Saving Daman & Diu => LALUBHAI PATEL (BJP)
# Saving Damoh => SHIVRAJ BHAIYA (BJP)
# Saving Darbhanga => KIRTI AZAD (BJP)
# Saving Darjeeling => Jaswant Singh (BJP)
# Saving Dausa => KIRODI LAL (IND)
# Saving Davanagere => Siddeswara.G.M (BJP)
# Saving Deoria => GORAKH PRASAD JAISWAL (BSP)
# Saving Dewas => SAJJAN SINGH VERMA (INC)
# Saving Dhanbad => PASHUPATI NATH SINGH (BJP)
# Saving Dhar => GAJENDRASINGH RAJUKHEDI (INC)
# Saving Dharmapuri => THAMARAISELVAN. R (DMK)
# Saving Dharwad => Pralhad Joshi (BJP)
# Saving Dhaurahra => KUNWAR JITIN PRASAD (INC)
# Saving Dhenkanal => Tathagata Satpathy (BJD)
# Saving Dhubri => BADRUDDIN AJMAL (AUDF)
# Saving Dhule => SONAWANE PRATAP NARAYANRAO (BJP)
# Saving Diamond Harbour => SOMENDRA NATH MITRA (AITC)
# Saving Dibrugarh => SRI PABAN SINGH GHATOWAR (INC)
# Saving Dindigul => CHITTHAN N S V (INC)
# Saving Dindori => CHAVAN HARISHCHANDRA DEORAM (BJP)
# Saving Domariyaganj => JAGDAMBIKA PAL (INC)
# Saving Dum Dum => SAUGATA RAY (AITC)
# Saving Dumka => SHIBU SOREN (JMM)
# Saving Durg => SAROJ PANDEY (BJP)
# Saving East Delhi => SANDEEP DIKSHIT (INC)
# Saving Eluru => KAVURI SAMBASIVA RAO (INC)
# Saving Ernakulam => Prof K V Thomas (INC)
# Saving Erode => GANESHAMURTHI.A. (MDMK)
# Saving Etawah => PREMDAS (SP)
# Saving Faizabad => NIRMAL KHATRI (INC)
# Saving Faridabad => AVTAR SINGH BHADANA (INC)
# Saving Faridkot => PARAMJIT KAUR GULSHAN (SAD)
# Saving Farrukhabad => SALMAN KHURSHEED (INC)
# Saving Fatehgarh Sahib => SUKHDEV SINGH (INC)
# Saving Fatehpur => RAKESH SACHAN (SP)
# Saving Fatehpur Sikri => SEEMA UPADHAYAY (BSP)
# Saving Firozabad => AKHILESH YADAV (SP)
# Saving Firozpur => SHER SINGH GHUBAYA (SAD)
# Saving Gadchiroli-Chimur => KOWASE MAROTRAO SAINUJI (INC)
# Saving Gandhinagar => LALKRISHNA KISHANCHAND ADVANI (BJP)
# Saving Ganganagar => BHARAT RAM MEGHWAL (INC)
# Saving Garhwal => SATPAL MAHARAJ (INC)
# Saving Gauhati => BIJOYA CHAKRAVARTY (BJP)
# Saving Gautam Budhha Nagar => SURENDRA SINGH NAGAR (BSP)
# Saving Gaya => Hari Manjhi (BJP)
# Saving Ghatal => Gurudas Dasgupta (CPI)
# Saving Ghaziabad => RAJNATH SINGH (BJP)
# Saving Ghazipur => RADHEY MOHAN SINGH (SP)
# Saving Ghosi => DARA SINGH CHAUHAN (BSP)
# Saving Giridih => RAVINDRA KUMAR PANDEY (BJP)
# Saving Godda => NISHIKANT DUBEY (BJP)
# Saving Gonda => BENI PRASAD VERMA (INC)
# Saving Gopalganj => PURNAMASI RAM (JD(U))
# Saving Gorakhpur => ADITYA NATH (BJP)
# Saving Gulbarga => Mallikarjun Kharge (INC)
# Saving Guna => JYOTIRADITYA MADHAVRAO SCINDIA (INC)
# Saving Guntur => SAMBASIVA RAO RAYAPATI (INC)
# Saving Gurdaspur => PARTAP SINGH BAJWA (INC)
# Saving Gurgaon => INDERJIT SINGH (INC)
# Saving Hajipur => RAM SUNDAR DAS (JD(U))
# Saving Hamirpur => VIJAY BAHADUR SINGH (BSP)
# Saving Hamirpur => ANURAG SINGH THAKUR (BJP)
# Saving Hardoi => USHA VERMA (SP)
# Saving Hardwar => HARISH RAWAT (INC)
# Saving Hassan => H. D. Devegowda (JD(S))
# Saving Hathras => SARIKA SINGH (RLD)
# Saving Hatkanangle => SHETTI RAJU ALIAS DEVAPPA ANNA (SWP)
# Saving Haveri => SHIVAKUMAR CHANNABASAPPA UDASI (BJP)
# Saving Hazaribagh => YASHWANT SINHA (BJP)
# Saving Hindupur => KRISTAPPA NIMMALA (TDP)
# Saving Hingoli => SUBHASH BAPURAO WANKHEDE (SHS)
# Saving Hisar => BHAJAN LAL (HJC(BL))
# Saving Hooghly => RATNA DE (AITC)
# Saving Hoshangabad => UDAY PRATAP SINGH (INC)
# Saving Hoshiarpur => SANTOSH CHOWDHARY (INC)
# Saving Howrah => AMBICA BANERJEE (AITC)
# Saving Hyderabad => Asaduddin Owaisi (AIMIM)
# Saving Idukki => Adv P T Thomas (INC)
# Saving Indore => SUMITRA MAHAJAN (TAI) (BJP)
# Saving Inner Manipur => DR. THOKCHOM MEINYA (INC)
# Saving Jabalpur => RAKESH SINGH (BJP)
# Saving Jadavpur => KABIR SUMAN (AITC)
# Saving Jagatsinghpur => Bibhu Prasad Tarai (CPI)
# Saving Jaipur => MAHESH JOSHI (INC)
# Saving Jaipur Rural => LAL CHAND KATARIA (INC)
# Saving Jajpur => Mohan Jena (BJD)
# Saving Jalandhar => MOHINDER SINGH KAYPEE (INC)
# Saving Jalaun => GHANSYAM ANURAGI (SP)
# Saving Jalgaon => A.T. NANA PATIL (BJP)
# Saving Jalna => DANVE RAOSAHEB DADARAO (BJP)
# Saving Jalore => DEV JI PATEL (BJP)
# Saving Jalpaiguri => Mahendra Kumar Roy (CPM)
# Saving Jammu => MADAN LAL SHARMA (INC)
# Saving Jamnagar => VIKRAMBHAI ARJANBHAI MADAM (INC)
# Saving Jamshedpur => ARJUN MUNDA (BJP)
# Saving Jamui => BHUDEO CHOUDHARY (JD(U))
# Saving Jangipur => PRANAB MUKHERJEE (INC)
# Saving Janjgir-Champa => Kamaladevi Patale (BJP)
# Saving Jaunpur => DHANANJAY SINGH (BSP)
# Saving Jaynagar => DR. TARUN MONDAL (IND)
# Saving Jhalawar-Baran => DUSHYANT SINGH (BJP)
# Saving Jhanjharpur => MANGANI LAL MANDAL (JD(U))
# Saving Jhansi => PRADEEP KUMAR JAIN (INC)
# Saving Jhargram => Pulin Bihari Baske (CPM)
# Saving Jhunjhunu => SHEESHRAM OLA (INC)
# Saving Jodhpur => CHANDRESH KUMARI (INC)
# Saving Jorhat => BIJOY KRISHNA HANDIQUE (INC)
# Saving Junagadh => DINUBHAI BOGHABHAI SOLANKI (BJP)
# Saving Kachchh => POONAMBEN VELJIBHAI JAT (BJP)
# Saving Kadapa => Y.S. Jagan Mohan Reddy (INC)
# Saving Kairana => TABASSUM BEGAM (BSP)
# Saving Kaiserganj => BRIJBHUSHAN SARAN SINGH (SP)
# Saving Kakinada => M M Pallamraju (INC)
# Saving Kalahandi => Bhakta Charan Das (INC)
# Saving Kaliabor => DIP GOGOI (INC)
# Saving Kallakurichi => SANKAR ADHI (DMK)
# Saving Kalyan => ANAND PRAKASH PARANJAPE (SHS)
# Saving Kancheepuram => VISWANATHAN.P (INC)
# Saving Kandhamal => Rudra Madhab Ray (BJD)
# Saving Kangra => DR. RAJAN SUSHANT (BJP)
# Saving Kanker => Sohan Potai (BJP)
# Saving Kannauj => AKHILESH YADAV (SP)
# Saving Kanniyakumari => HELEN DAVIDSON J (DMK)
# Saving Kannur => K Sudhakaran Kavinte Arikathu (INC)
# Saving Kanpur => SRI PRAKASH JAISWAL (INC)
# Saving Kanthi => ADHIKARI SISIR KUMAR (AITC)
# Saving Karakat => Mahabali Singh (JD(U))
# Saving Karauli-Dholpur => KHILADI LAL BAIRWA (INC)
# Saving Karimganj => Lalit Mohan Suklabaidya (INC)
# Saving Karimnagar => Ponnam Prabhakar (INC)
# Saving Karnal => ARVIND KUMAR SHARMA (INC)
# Saving Karur => TAMBIDURAI.M (ADMK)
# Saving Kasaragod => P.Karunakaran (CPM)
# Saving Katihar => NIKHIL KUMAR CHOUDHARY (BJP)
# Saving Kaushambi => SHAILENDRA KUMAR (SP)
# Saving Kendrapara => Baijayant Panda (BJD)
# Saving Keonjhar => Yashbanta Narayan Singh Laguri (BJD)
# Saving Khadoor Sahib => DR. RATTAN SINGH AJNALA (SAD)
# Saving Khagaria => DINESH CHANDRA YADAV (JD(U))
# Saving Khajuraho => JEETENDRA SINGH (BJP)
# Saving Khammam => Nama Nageswara Rao (TDP)
# Saving Khandwa => ARUN SUBHASHCHANDRA YADAV (INC)
# Saving Khargone => MAKNSINGH SOLANKI (BABUJI) (BJP)
# Saving Kheda => DINSHA ZAVARBHAI PATEL (INC)
# Saving Kheri => ZAFAR ALI NAQVI (INC)
# Saving Khunti => KARIYA MUNDA (BJP)
# Saving Kishanganj => MOHAMMAD ASRARUL HAQUE (INC)
# Saving Kodarma => Babu Lal Marandi (JVM(P))
# Saving Kokrajhar => SANSUMA KHUNGGUR BWISWMUTHIARY (BPF)
# Saving Kolar => K.H.Muniyappa (INC)
# Saving Kolhapur => SADASHIVRAO MANDLIK DADOBA (IND)
# Saving Kolkata Dakshin  => MAMATA BANERJEE (AITC)
# Saving Kolkata Uttar => SUDIP BANDYOPADHYAY (AITC)
# Saving Kollam => N Peethambarakurup (INC)
# Saving Koppal => Shivaramgouda (BJP)
# Saving Koraput => Jayaram Pangi (BJD)
# Saving Korba => Charandas Mahant (INC)
# Saving Kota => IJYARAJ SINGH (INC)
# Saving Kottayam => Jose K Mani (KEC(M))
# Saving Kozhikode => M K Raghavan (INC)
# Saving Krishnagiri => SUGAVANAM. E.G. (DMK)
# Saving Krishnanagar => TAPAS PAUL (AITC)
# Saving Kurnool => KOTLA JAYA SURYA PRAKASH REDDY (INC)
# Saving Kurukshetra => NAVEEN JINDAL (INC)
# Saving Kushi Nagar => KU. RATANJEET PRATAP NARAYAN SINGH (INC)
# Saving Ladakh => HASSAN KHAN (IND)
# Saving Lakhimpur => RANEE NARAH (INC)
# Saving Lakshadweep => Muhammed Hamdulla Sayeed A.B. (INC)
# Saving Lalganj => DR. BALIRAM (BSP)
# Saving Latur => AAWALE JAYWANT GANGARAM (INC)
# Saving Lohardaga => Sudershan Bhagat (BJP)
# Saving Lucknow => LAL JI TANDON (BJP)
# Saving Ludhiana => MANISH TEWARI (INC)
# Saving Machhlishahr => TUFANI SAROJ (SP)
# Saving Machilipatnam => Konakalla Narayana Rao (TDP)
# Saving Madha => PAWAR SHARADCHANDRA GOVINDRAO (NCP)
# Saving Madhepura => SHARAD YADAV (JD(U))
# Saving Madhubani => HUKM DEO NARAYAN YADAV (BJP)
# Saving Madurai => ALAGIRI M.K (DMK)
# Saving Mahabubabad => P. BALRAM (INC)
# Saving Maharajganj => Uma Shanaker Singh (RJD)
# Saving Mahasamund => Chandulal Sahu (Chandu Bhaiya) (BJP)
# Saving Mahbubnagar => K. CHANDRASEKHARA RAO (TRS)
# Saving Mahesana => JAYSHREEBEN KANUBHAI PATEL (BJP)
# Saving Mainpuri => MULAYAM SINGH YADAV (SP)
# Saving Malappuram => E Ahamed (MUL)
# Saving Maldaha Dakshin => Abu Hasem Khan Choudhury (INC)
# Saving Maldaha Uttar => Mausam Noor (INC)
# Saving Malkajgiri => SARVEY SATYANARAYANA (INC)
# Saving Mandi => VIRBHADRA SINGH (INC)
# Saving Mandla => BASORI SINGH MASRAM (INC)
# Saving Mandsour => MEENAKSHI NATRAJAN (INC)
# Saving Mandya => N Chaluvarayaswamy (JD(S))
# Saving Mangaldoi => RAMEN DEKA (BJP)
# Saving Mathura => JAYANT K SINGH (RLD)
# Saving Mathurapur => CHOUDHURY MOHAN JATUA (AITC)
# Saving Maval => BABAR GAJANAN DHARMSHI (SHS)
# Saving Mavelikkara => Kodikunnil Suresh (INC)
# Saving Mayiladuthurai => MANIAN O.S (ADMK)
# Saving Mayurbhanj => Laxman Tudu (BJD)
# Saving Medak => VIJAYA SHANTHI .M (TRS)
# Saving Medinipur => Prabodh Panda (CPI)
# Saving Meerut => RAJENDRA AGARWAL (BJP)
# Saving Mirzapur => BAL KUMAR PATEL (SP)
# Saving Misrikh => ASHOK KUMAR RAWAT (BSP)
# Saving Mizoram => C.L.RUALA (INC)
# Saving Mohanlalganj => SUSHILA SAROJ (SP)
# Saving Moradabad => MOHAMMED AZHARUDDIN (INC)
# Saving Morena => NARENDRA SINGH TOMAR (BJP)
# Saving Mumbai North => SANJAY BRIJKISHORLAL NIRUPAM (INC)
# Saving Mumbai North Central => DUTT PRIYA SUNIL (INC)
# Saving Mumbai North East => SANJAY DINA PATIL (NCP)
# Saving Mumbai North West => AD.KAMAT GURUDAS VASANT (INC)
# Saving Mumbai South => DEORA MILIND MURLI (INC)
# Saving Mumbai South Central => EKNATH M. GAIKWAD (INC)
# Saving Murshidabad => ABDUL MANNAN HOSSAIN (INC)
# Saving Muzaffarnagar => KADEER RANA (BSP)
# Saving Muzaffarpur => CAPTAIN JAI NARAYAN PRASAD NISHAD (JD(U))
# Saving Mysore => ADAGUR H. VISWANATH (INC)
# Saving Nabarangpur => Pradeep Kumar Majhi (INC)
# Saving Nagapattinam => VIJAYAN A K S (DMK)
# Saving Nagarkurnool => Dr. Manda Jagannath (INC)
# Saving Nagaur => DR JYOTI MIRDHA (INC)
# Saving Nagina => YASHVIR SINGH (SP)
# Saving Nagpur => MUTTEMWAR VILASRAO BABURAOJI (INC)
# Saving Nainital-Udhamsingh Nagar => K.C. SINGH BABA (INC)
# Saving Nalanda => KAUSHALENDRA KUMAR (JD(U))
# Saving Nalgonda => Gutha Sukender Reddy (INC)
# Saving Namakkal => GANDHISELVAN.S (DMK)
# Saving Nanded => KHATGAONK PATIL BHASKARRAO BAPURAO (INC)
# Saving Nandurbar => GAVIT MANIKRAO HODLYA (INC)
# Saving Nandyal => S.P.Y.REDDY (INC)
# Saving Narasaraopet => VENUGOPALA REDDY MODUGULA (TDP)
# Saving Narsapuram => BAPIRAJU KANUMURU (INC)
# Saving Nashik => SAMEER BHUJBAL (NCP)
# Saving Navsari => CHANDRAKANT RAGHUNATH PATIL (BJP)
# Saving Nawada => BholaSingh (BJP)
# Saving Nellore => M Rajamohan Reddy (INC)
# Saving New Delhi => AJAY MAKAN (INC)
# Saving Nilgiris => RAJA A (DMK)
# Saving Nizamabad => Madhu Yaskhi Goud (INC)
# Saving North East Delhi => JAI PRAKASH AGARWAL (INC)
# Saving North Goa => SHRIPAD YESSO NAIK (BJP)
# Saving North West Delhi => KIRSHNA TIRATH (INC)
# Saving Nowgong => RAJEN GOHAIN (BJP)
# Saving Ongole => MAGUNTA SRINIVASULU REDDY (INC)
# Saving Osmanabad => PATIL PADAMSINHA BAJIRAO (NCP)
# Saving Outer Manipur => THANGSO BAITE (INC)
# Saving Palakkad => M B Rajesh (CPM)
# Saving Palamau => KAMESHWAR BAITHA (JMM)
# Saving Palghar => JADHAV BALIRAM SUKUR (BVA)
# Saving Pali => BADRI RAM (INC)
# Saving Panchmahal => PRABHATSINH PRATAPSINH CHAUHAN (BJP)
# Saving Parbhani => ADV. DUDHGAONKAR GANESHRAO NAGORAO (SHS)
# Saving Paschim Champaran => DR. SANJAY JAISWAL (BJP)
# Saving Pataliputra => RANJAN  PRASAD YADAV (JD(U))
# Saving Patan => JAGDISHBHAI MOTIJI THAKORE (INC)
# Saving Pathanamthitta => Anto Antony (INC)
# Saving Patiala => PRENEET KAUR (INC)
# Saving Patna Sahib => SHATRUGHAN SINHA (BJP)
# Saving Peddapalle => Dr. G. Vivekanand (INC)
# Saving Perambalur => NAPOLEON,D. (DMK)
# Saving Phulpur => KAPIL MUNI KARWARIYA (BSP)
# Saving Pilibhit => FEROZE VARUN GANDHI (BJP)
# Saving Pollachi => SUGUMAR.K (ADMK)
# Saving Pondicherry => NARAYANASAMY (INC)
# Saving Ponnani => E T Mohamed Basheer (MUL)
# Saving Porbandar => VITTHALBHAI HANSRAJBHAI RADADIYA (INC)
# Saving Pratapgarh => RAJKUMARI RATNA SINGH (INC)
# Saving Pune => KALMADI SURESH (INC)
# Saving Puri => Pinaki Misra (BJD)
# Saving Purnia => UDAY SINGH ALIAS PAPPU SINGH (BJP)
# Saving Purulia => Narahari Mahato (AIFB)
# Saving Purvi Champaran => RADHA MOHAN SINGH (BJP)
# Saving Rae bareli => SONIA GANDHI (INC)
# Saving Raichur => S Pakkirappa (BJP)
# Saving Raigad => ANANT GEETE (SHS)
# Saving Raiganj => Deepa Dasmunsi (INC)
# Saving Raigarh => Vishu Deo Sai (BJP)
# Saving Rajahmundry => V Arun Kumar (INC)
# Saving Rajampet => ANNAYYAGARI SAI PRATHAP (INC)
# Saving Rajgarh => NARAYANSINGH AMLABE (INC)
# Saving Rajkot => KUNVARJIBHAI MOHANBHAI BAVALIYA (INC)
# Saving Rajmahal => DEVIDHAN BESRA (BJP)
# Saving Rajnandgaon => Madhusudan Yadav (BJP)
# Saving Rajsamand => GOPAL SINGH (INC)
# Saving Ramanathapuram => SIVAKUMAR @ J.K. RITHEESH. K (DMK)
# Saving Rampur => JAYA PRADA NAHATA (SP)
# Saving Ramtek => WASNIK MUKUL BALKRISHNA (INC)
# Saving Ranaghat => SUCHARU RANJAN HALDAR (AITC)
# Saving Ranchi => SUBODH KANT SAHAY (INC)
# Saving Ratlam => KANTILAL BHURIA (INC)
# Saving Ratnagiri Sindhudurg => DR.NILESH NARAYAN RANE (INC)
# Saving Raver => HARIBHAU MADHAV JAWALE (BJP)
# Saving Rewa => DEORAJ SINGH PATEL (BSP)
# Saving Robertsganj => PAKAURI LAL (SP)
# Saving Rohtak => DEEPENDER SINGH (INC)
# Saving Sabarkantha => MAHENDRASINH PRUTHVISINH CHAUHAN (BJP)
# Saving Saharanpur => JAGDISH SINGH RANA (BSP)
# Saving Salem => SEMMALAI S (ADMK)
# Saving Salempur => RAMASHANKAR RAJBHAR (BSP)
# Saving Samastipur => MAHESWER HAZARI (JD(U))
# Saving Sambalpur => Amarnath Pradhan (INC)
# Saving Sambhal => DR. SHAFIQUR RAHMAN BARQ (BSP)
# Saving Sangli => PRATIK PRAKASHBAPU PATIL (INC)
# Saving Sangrur => VIJAY INDER SINGLA (INC)
# Saving Sant Kabir Nagar => BHISMA SHANKAR ALIAS KUSHAL TIWARI (BSP)
# Saving Sasaram => MEIRA KUMAR (INC)
# Saving Satara => BHONSLE SHRIMANT CHH. UDYANRAJE PRATAPSINH (NCP)
# Saving Satna => GANESH SINGH (BJP)
# Saving Secunderabad => ANJAN KUMAR YADAV (INC)
# Saving Shahdol => RAJESH NANDINI SINGH (INC)
# Saving Shahjahanpur => MITHLESH (SP)
# Saving Sheohar => RAMA DEVI (BJP)
# Saving Shillong => VINCENT H PALA (INC)
# Saving Shimla => VIRENDER KASHYAP (BJP)
# Saving Shimoga => B.Y. RAGHAVENDRA (BJP)
# Saving Shirdi => WAKCHOURE BHAUSAHEB RAJARAM (SHS)
# Saving Shirur => ADHALRAO SHIVAJI DATTATRAY (SHS)
# Saving Shrawasti => VINAY KUMAR ALIAS VINNU (INC)
# Saving Sidhi => GOVIND PRASAD MISHRA (BJP)
# Saving Sikar => MAHADEV SINGH (INC)
# Saving Sikkim => PREM DAS RAI (SDF)
# Saving Silchar => Kabindra Purkayastha (BJP)
# Saving Singhbhum => MADHU KORA (IND)
# Saving Sirsa => ASHOK TANWAR (INC)
# Saving Sitamarhi => ARJUN ROY (JD(U))
# Saving Sitapur => KAISAR JAHAN (BSP)
# Saving Sivaganga => CHIDAMBARAM P (INC)
# Saving Siwan => OmPrakashYadav (IND)
# Saving Solapur => SHINDE SUSHILKUMAR SAMBHAJIRAO (INC)
# Saving Sonipat => JITENDER SINGH (INC)
# Saving South Delhi => RAMESH KUMAR (INC)
# Saving South Goa => COSME FRANCISCO CAITANO SARDINHA (INC)
# Saving Sreerampur => KALYAN BANERJEE (AITC)
# Saving Srikakulam => K. KRUPA RANI (INC)
# Saving Srinagar => FAROOQ ABDULLAH (JKN)
# Saving Sriperumbudur => BAALU T R (DMK)
# Saving Sultanpur => DR.SANJAY SINGH (INC)
# Saving Sundargarh => HEMANAND BISWAL (INC)
# Saving Supaul => VISHWA MOHAN KUMAR (JD(U))
# Saving Surat => DARSNABEN VIKRAMBHAI JARDOS (BJP)
# Saving Surendranagar => SOMABHAI GANDABHAI KOLIPATEL (INC)
# Saving Tamluk => ADHIKARI SUVENDU (AITC)
# Saving Tehri Garhwal => VIJAY BAHUGUNA (INC)
# Saving Tenkasi => LINGAM P (CPI)
# Saving Tezpur => JOSEPH TOPPO (AGP)
# Saving Thane => DR.SANJEEV GANESH NAIK (NCP)
# Saving Thanjavur => PALANIMANICKAM.S.S (DMK)
# Saving Theni => AARON RASHID.J.M (INC)
# Saving Thiruvananthapuram => Shashi Tharoor (INC)
# Saving Thoothukkudi => JEYADURAI S R (DMK)
# Saving Thrissur => P C Chacko (INC)
# Saving Tikamgarh => VIRENDRA KUMAR (BJP)
# Saving Tiruchirappalli => KUMAR.P (ADMK)
# Saving Tirunelveli => RAMASUBBU S (INC)
# Saving Tirupati => Chinta Mohan (INC)
# Saving Tiruppur => SIVASAMI C (ADMK)
# Saving Tiruvallur => VENUGOPAL.P (ADMK)
# Saving Tiruvannamalai => VENUGOPAL.D (DMK)
# Saving Tripura East => BAJU BAN RIYAN (CPM)
# Saving Tripura West => KHAGEN DAS (CPM)
# Saving Tumkur => G.S. BASAVARAJU (BJP)
# Saving Tura => AGATHA K. SANGMA (NCP)
# Saving Udaipur => Raghuveer singh (INC)
# Saving Udhampur => CH. LAL SINGH (INC)
# Saving Udupi Chikmagalur => D.V.Sadananda Gowda (BJP)
# Saving Ujiarpur => ASWAMEDH DEVI (JD(U))
# Saving Ujjain => GUDDU PREMCHAND (INC)
# Saving Uluberia => SULTAN AHMED (AITC)
# Saving Unnao => ANNUTANDON (INC)
# Saving Uttara Kannada => Ananthkumar Hegde (BJP)
# Saving Vadakara => Mullappally Ramachandran (INC)
# Saving Vadodara => BALKRISHNA KHANDERAO SHUKLA (BJP)
# Saving Vaishali => RAGHUVANSH PRASAD SINGH (RJD)
# Saving Valmiki Nagar => BAIDYANATH PRASAD MAHTO (JD(U))
# Saving Valsad => KISANBHAI VESTABHAI PATEL (INC)
# Saving Varanasi => DR. MURLI MANOHAR JOSHI (BJP)
# Saving Vellore => ABDUL RAHMAN (DMK)
# Saving Vidisha => SUSHMA SWARAJ (BJP)
# Saving Vijayawada => L Rajagopal (INC)
# Saving Viluppuram => ANANDAN M (ADMK)
# Saving Virudhunagar => MANICKA TAGORE (INC)
# Saving Visakhapatnam => D. PURANDARESHWARI (INC)
# Saving Vizianagaram => B. JHANSI (INC)
# Saving Warangal => Rajaiah Siricilla (INC)
# Saving Wardha => DATTA MEGHE (INC)
# Saving Wayanad => M I Shanavas (INC)
# Saving West Delhi => MAHABAL MISHRA (INC)
# Saving Yavatmal-Washim => BHAVANA GAWALI (PATIL) (SHS)
# Saving Zahirabad => SURESH KUMAR SHETKAR (INC)
# SUCCESS
# Saved => 522 constituencies

# %% [markdown]
# ## Visualizing data

# %%
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

matplotlib.rc('figure', figsize=(10, 5))
matplotlib.rc('font', weight='bold', size=12)

# %%
data = pd.read_csv('2009.csv')
data
# Out:
#                         Candidate     Constituency Party  Criminal Cases  \
# 0                   Ramesh Rathod         Adilabad   TDP               2
# 1                  DR. RAMSHANKAR             Agra   BJP               0
# 2                    HARIN PATHAK   Ahmedabad East   BJP               2
# 3    KIRITBHAI PREMJIBHAI SOLANKI   Ahmedabad West   BJP               0
# 4    GANDHI DILIPKUMAR MANSUKHLAL       Ahmednagar   BJP               9
# ..                            ...              ...   ...             ...
# 517                   DATTA MEGHE           Wardha   INC               0
# 518                  M I Shanavas          Wayanad   INC               0
# 519                MAHABAL MISHRA       West Delhi   INC               0
# 520        BHAVANA GAWALI (PATIL)  Yavatmal-Washim   SHS               1
# 521          SURESH KUMAR SHETKAR        Zahirabad   INC               0
#
#                  Education  Total Assets  Liabilities
# 0                12th Pass       3410000       815241
# 1                Doctorate       1511000       639959
# 2            Post Graduate      14578184        22734
# 3    Graduate Professional      26122439       709488
# 4                10th Pass      13053391       955351
# ..                     ...           ...          ...
# 517               Graduate     287739495     70008871
# 518          Post Graduate      23904424      2548978
# 519              12th Pass      61994338       989118
# 520               Graduate      30399471      2430911
# 521               Graduate       3011999            0
#
# [522 rows x 7 columns]

# %%
data.describe()
# Out:
#        Criminal Cases  Total Assets   Liabilities
# count      522.000000  5.220000e+02  5.220000e+02
# mean         1.036398  5.349847e+07  3.008035e+06
# std          3.239129  1.406614e+08  1.661583e+07
# min          0.000000  0.000000e+00  0.000000e+00
# 25%          0.000000  4.828495e+06  0.000000e+00
# 50%          0.000000  1.418007e+07  1.642395e+05
# 75%          1.000000  4.010500e+07  1.248750e+06
# max         46.000000  1.737508e+09  3.362372e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       522 non-null    object
#  1   Constituency    522 non-null    object
#  2   Party           522 non-null    object
#  3   Criminal Cases  522 non-null    int64
#  4   Education       522 non-null    object
#  5   Total Assets    522 non-null    int64
#  6   Liabilities     522 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 28.7+ KB

# %%
# Total number of Parties
np.size(data["Party"].unique()) - 1
# Reducing by one for independent candidates
# Out:
# 36

# %%
candidates = np.size(data["Candidate"])
candidates
# Out:
# 522

# %%
candidates - np.size(data["Candidate"].unique())
# Out:
# 1

# %%
candidates - data.groupby(['Candidate', 'Party']).ngroups
# Out:
# 1

# %%
candidates - data.groupby(['Candidate', 'Constituency']).ngroups
# Out:
# 0

# %%
data.groupby(['Candidate', 'Education'])['Total Assets'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                       Education
# Nama Nageswara Rao              12th Pass                1737508117
# NAVEEN JINDAL                   Post Graduate            1310730000
# L Rajagopal                     Graduate Professional    1222964909
# Dr. G. Vivekanand               Graduate Professional     729509675
# Y.S. Jagan Mohan Reddy          Graduate                  728151658
# RAJKUMARI RATNA SINGH           Graduate                  678270725
# HARSIMRAT KAUR                  10th Pass                 603100135
# SUPRIYA SULE                    Graduate                  515363663
# SURENDRA SINGH NAGAR            Graduate                  492084300
# H D KUMARA SWAMY                Graduate                  491683477
# PRENEET KAUR                    Graduate                  423043438
# ANNUTANDON                      Graduate                  421352753
# UDAY SINGH ALIAS PAPPU SINGH    12th Pass                 419130669
# M Rajamohan Reddy               Graduate Professional     363462696
# DUTT PRIYA SUNIL                Graduate                  349576448
# SHIVAKUMAR CHANNABASAPPA UDASI  Graduate                  323361935
# KAPIL SIBAL                     Post Graduate             319722459
# BADRUDDIN AJMAL                 Literate                  303520991
# Pinaki Misra                    Graduate                  296900000
# PRAVEEN SINGH ARON              Graduate Professional     288019293
# DATTA MEGHE                     Graduate                  287739495
# VIJAYA SHANTHI .M               10th Pass                 271066905
# CHIDAMBARAM P                   Post Graduate             267908542
# VINCENT H PALA                  Graduate Professional     251618190
# AARON RASHID.J.M                12th Pass                 248974573
# Name: Total Assets, dtype: int64

# %%
data.groupby(['Candidate', 'Education'])['Liabilities'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                       Education
# H D KUMARA SWAMY                Graduate                 336237223
# ALAGIRI S                       Graduate                  78136525
# DATTA MEGHE                     Graduate                  70008871
# Y.S. Jagan Mohan Reddy          Graduate                  66396966
# SAMBASIVA RAO RAYAPATI          Graduate                  45204329
# MUNDE GOPINATHRAO PANDURANG     Graduate Professional     45090238
# N. Dharamsingh                  Post Graduate             43958832
# Angadi Suresh Channabasappa     Graduate Professional     43392842
# CHANDRAKANT RAGHUNATH PATIL     10th Pass                 42208512
# SHIVAKUMAR CHANNABASAPPA UDASI  Graduate                  33833437
# P.C.Mohan                       12th Pass                 32887000
# PRAVEEN SINGH ARON              Graduate Professional     32622036
# NAPOLEON,D.                     Graduate                  28270000
# ARUN SUBHASHCHANDRA YADAV       Graduate                  27562966
# SHATRUGHAN SINHA                Graduate                  25878099
# L Rajagopal                     Graduate Professional     23967984
# K.H.Muniyappa                   Graduate Professional     21019510
# SHRUTI CHOUDHRY                 Graduate Professional     17000000
# KRISHNASAMY M                   Graduate Professional     16792067
# Gutha Sukender Reddy            12th Pass                 16662997
# ADHALRAO SHIVAJI DATTATRAY      Post Graduate             16221275
# AKHILESH YADAV                  Graduate Professional     15452708
# Madhu Yaskhi Goud               Post Graduate             15422084
# NEERAJ SHEKHAR                  Graduate                  15100000
# Yashbanta Narayan Singh Laguri  Graduate                  15000000
# Name: Liabilities, dtype: int64

# %%
party_data = data[data["Party"].isin(["AAP","SAD","BSP","BJP","INC","IND","Republican Party of India (A)", "Punjab Lok Congress Party"])]
party_data.reset_index()
party_data
# Out:
#                         Candidate    Constituency Party  Criminal Cases  \
# 1                  DR. RAMSHANKAR            Agra   BJP               0
# 2                    HARIN PATHAK  Ahmedabad East   BJP               2
# 3    KIRITBHAI PREMJIBHAI SOLANKI  Ahmedabad West   BJP               0
# 4    GANDHI DILIPKUMAR MANSUKHLAL      Ahmednagar   BJP               9
# 5                    SACHIN PILOT           Ajmer   INC               0
# ..                            ...             ...   ...             ...
# 516             Rajaiah Siricilla        Warangal   INC               0
# 517                   DATTA MEGHE          Wardha   INC               0
# 518                  M I Shanavas         Wayanad   INC               0
# 519                MAHABAL MISHRA      West Delhi   INC               0
# 521          SURESH KUMAR SHETKAR       Zahirabad   INC               0
#
#                  Education  Total Assets  Liabilities
# 1                Doctorate       1511000       639959
# 2            Post Graduate      14578184        22734
# 3    Graduate Professional      26122439       709488
# 4                10th Pass      13053391       955351
# 5            Post Graduate      46489558            0
# ..                     ...           ...          ...
# 516               Graduate       4224704      1461167
# 517               Graduate     287739495     70008871
# 518          Post Graduate      23904424      2548978
# 519              12th Pass      61994338       989118
# 521               Graduate       3011999            0
#
# [342 rows x 7 columns]

# %%
party_sorted = party_data[["Party","Candidate"]].groupby(["Party"]).aggregate(lambda x: len(x.unique())).sort_values(["Candidate"], ascending = False )
party_sorted
# Out:
#        Candidate
# Party
# INC          201
# BJP          109
# BSP           21
# IND            7
# SAD            4

# %%
party_sorted.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
ed_data = pd.pivot_table(data,values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"]).sort_values(["Candidate"], ascending = False )
ed_data.reset_index()
ed_data.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
ed_party_data = pd.pivot_table(party_data, values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"], columns=["Party"])
ed_party_data.fillna(0)
# Out:
#                       Candidate
# Party                       BJP  BSP   INC  IND  SAD
# Education
# 10th Pass                  16.0  3.0  11.0  0.0  2.0
# 12th Pass                  12.0  3.0  15.0  0.0  0.0
# 5th Pass                    4.0  0.0   3.0  0.0  0.0
# 8th Pass                    2.0  2.0   2.0  0.0  0.0
# Doctorate                   4.0  1.0  13.0  0.0  0.0
# Graduate                   29.0  5.0  55.0  4.0  0.0
# Graduate Professional      23.0  2.0  45.0  3.0  1.0
# Literate                    0.0  1.0   1.0  0.0  0.0
# Others                      0.0  0.0   2.0  0.0  0.0
# Post Graduate              19.0  4.0  54.0  0.0  1.0

# %%
criminal_data_asc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=False).head(25)
criminal_data_asc = criminal_data_asc.reset_index(drop=True)
criminal_data_asc
# Out:
#                                      Candidate  Constituency  Party  \
# 0                             KAMESHWAR BAITHA       Palamau    JMM
# 1                       AHIR HANSARAJ GANGARAM    Chandrapur    BJP
# 2             VITTHALBHAI HANSRAJBHAI RADADIYA     Porbandar    INC
# 3                           CHANDRAKANT KHAIRE    Aurangabad    SHS
# 4                                   M B Rajesh      Palakkad    CPM
# 5                           N Chaluvarayaswamy        Mandya  JD(S)
# 6   BHONSLE SHRIMANT CHH. UDYANRAJE PRATAPSINH        Satara    NCP
# 7                           Tathagata Satpathy     Dhenkanal    BJD
# 8                                P.Karunakaran     Kasaragod    CPM
# 9                               RAMAKANT YADAV      Azamgarh    BJP
# 10                             BAL KUMAR PATEL      Mirzapur     SP
# 11                  JADHAV PRATAPRAO GANPATRAO      Buldhana    SHS
# 12                                   RAMKISHUN     Chandauli     SP
# 13                GANDHI DILIPKUMAR MANSUKHLAL    Ahmednagar    BJP
# 14                    PATIL PADAMSINHA BAJIRAO     Osmanabad    NCP
# 15                               RAKESH SACHAN      Fatehpur     SP
# 16                      BABAR GAJANAN DHARMSHI         Maval    SHS
# 17              Yashbanta Narayan Singh Laguri      Keonjhar    BJD
# 18                 CHANDRAKANT RAGHUNATH PATIL       Navsari    BJP
# 19                         FEROZE VARUN GANDHI      Pilibhit    BJP
# 20                             DEVENDRA NAGPAL        Amroha    RLD
# 21                       RAJKUMARI RATNA SINGH    Pratapgarh    INC
# 22                              N. Dharamsingh         Bidar    INC
# 23                                  TAPAS PAUL  Krishnanagar   AITC
# 24                SANJAY BRIJKISHORLAL NIRUPAM  Mumbai North    INC
#
#                 Education  Criminal Cases
# 0               10th Pass              46
# 1               10th Pass              30
# 2                Graduate              16
# 3               12th Pass              16
# 4           Post Graduate              16
# 5               12th Pass              15
# 6                  Others              14
# 7               12th Pass              13
# 8           Post Graduate              12
# 9               10th Pass              11
# 10              12th Pass              10
# 11               Graduate              10
# 12  Graduate Professional              10
# 13              10th Pass               9
# 14  Graduate Professional               7
# 15          Post Graduate               7
# 16               Literate               7
# 17               Graduate               6
# 18              10th Pass               6
# 19               Graduate               6
# 20               Graduate               6
# 21               Graduate               5
# 22          Post Graduate               5
# 23               Graduate               5
# 24               Graduate               5

# %%
criminal_data_dsc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=True).head(25)
criminal_data_dsc = criminal_data_dsc.reset_index(drop=True)
criminal_data_dsc
# Out:
#                          Candidate     Constituency Party  \
# 0                 Ponnam Prabhakar       Karimnagar   INC
# 1                       RAMEN DEKA        Mangaldoi   BJP
# 2               MEENAKSHI NATRAJAN         Mandsour   INC
# 3              BASORI SINGH MASRAM           Mandla   INC
# 4                  VIRBHADRA SINGH            Mandi   INC
# 5                      Mausam Noor    Maldaha Uttar   INC
# 6         Abu Hasem Khan Choudhury  Maldaha Dakshin   INC
# 7                         E Ahamed       Malappuram   MUL
# 8              MULAYAM SINGH YADAV         Mainpuri    SP
# 9       JAYSHREEBEN KANUBHAI PATEL         Mahesana   BJP
# 10  Chandulal Sahu (Chandu Bhaiya)       Mahasamund   BJP
# 11           CHOUDHURY MOHAN JATUA       Mathurapur  AITC
# 12                       P. BALRAM      Mahabubabad   INC
# 13          HUKM DEO NARAYAN YADAV        Madhubani   BJP
# 14   PAWAR SHARADCHANDRA GOVINDRAO            Madha   NCP
# 15          Konakalla Narayana Rao    Machilipatnam   TDP
# 16                    TUFANI SAROJ     Machhlishahr    SP
# 17                   MANISH TEWARI         Ludhiana   INC
# 18                   LAL JI TANDON          Lucknow   BJP
# 19                Sudershan Bhagat        Lohardaga   BJP
# 20                     DR. BALIRAM          Lalganj   BSP
# 21   Muhammed Hamdulla Sayeed A.B.      Lakshadweep   INC
# 22                     HASSAN KHAN           Ladakh   IND
# 23                     ALAGIRI M.K          Madurai   DMK
# 24                     Laxman Tudu       Mayurbhanj   BJD
#
#                 Education  Criminal Cases
# 0   Graduate Professional               0
# 1                Graduate               0
# 2           Post Graduate               0
# 3                8th Pass               0
# 4           Post Graduate               0
# 5   Graduate Professional               0
# 6               Doctorate               0
# 7           Post Graduate               0
# 8           Post Graduate               0
# 9               10th Pass               0
# 10  Graduate Professional               0
# 11          Post Graduate               0
# 12               Graduate               0
# 13               Graduate               0
# 14              10th Pass               0
# 15              12th Pass               0
# 16               Graduate               0
# 17  Graduate Professional               0
# 18               Graduate               0
# 19               Graduate               0
# 20              Doctorate               0
# 21  Graduate Professional               0
# 22               Graduate               0
# 23               Graduate               0
# 24               Graduate               0

# %%
criminal_data_asc.groupby("Party").aggregate(np.sum).sort_values("Criminal Cases",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
asset_data = data[["Candidate","Constituency","Party", "Total Assets"]].sort_values('Total Assets', ascending=False).head(25)
asset_data = asset_data.reset_index(drop=True)
asset_data
# Out:
#                          Candidate          Constituency  Party  Total Assets
# 0               Nama Nageswara Rao               Khammam    TDP    1737508117
# 1                    NAVEEN JINDAL           Kurukshetra    INC    1310730000
# 2                      L Rajagopal            Vijayawada    INC    1222964909
# 3                Dr. G. Vivekanand            Peddapalle    INC     729509675
# 4           Y.S. Jagan Mohan Reddy                Kadapa    INC     728151658
# 5            RAJKUMARI RATNA SINGH            Pratapgarh    INC     678270725
# 6                   HARSIMRAT KAUR              Bathinda    SAD     603100135
# 7                     SUPRIYA SULE              Baramati    NCP     515363663
# 8             SURENDRA SINGH NAGAR   Gautam Budhha Nagar    BSP     492084300
# 9                 H D KUMARA SWAMY       Bangalore Rural  JD(S)     491683477
# 10                    PRENEET KAUR               Patiala    INC     423043438
# 11                      ANNUTANDON                 Unnao    INC     421352753
# 12    UDAY SINGH ALIAS PAPPU SINGH                Purnia    BJP     419130669
# 13               M Rajamohan Reddy               Nellore    INC     363462696
# 14                DUTT PRIYA SUNIL  Mumbai North Central    INC     349576448
# 15  SHIVAKUMAR CHANNABASAPPA UDASI                Haveri    BJP     323361935
# 16                     KAPIL SIBAL         Chandni Chowk    INC     319722459
# 17                 BADRUDDIN AJMAL                Dhubri   AUDF     303520991
# 18                    Pinaki Misra                  Puri    BJD     296900000
# 19              PRAVEEN SINGH ARON              Bareilly    INC     288019293
# 20                     DATTA MEGHE                Wardha    INC     287739495
# 21               VIJAYA SHANTHI .M                 Medak    TRS     271066905
# 22                   CHIDAMBARAM P             Sivaganga    INC     267908542
# 23                  VINCENT H PALA              Shillong    INC     251618190
# 24                AARON RASHID.J.M                 Theni    INC     248974573

# %%
asset_data.groupby("Party").aggregate(np.sum).sort_values("Total Assets",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>
