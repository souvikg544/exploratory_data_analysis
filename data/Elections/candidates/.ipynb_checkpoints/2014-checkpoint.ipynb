# %% [markdown]
# # EDA : Lok Sabha Candidates, 2014

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate

year = 2014


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate", "Party", "Criminal Cases", "Education", "Age", "Constituency",  "Total Assets", "Liabilities", "Year"]
    data = []
    constituencies = 0
    candidates = 0
    for i in range(1, 575):
        try:
            print("Trying ID", i, end = ' => ')
            url = "https://myneta.info/ls" + str(year) + "/index.php?action=show_candidates&constituency_id=" + str(i)
            html = urlopen(url)
            soup = BeautifulSoup(html,'html.parser')
            title = soup.title.text
            title = title.split()
            title = title[4:-2]
            title = " ".join(title)
            title = title.title()
            title = title.split(":")
            constituency = "+".join(title)
            title = ",".join(title)
            print("Saving", title, end = ' => ')
            table = soup.find("table", {"id": "table1"})
            rows = table.find_all('tr')
            total_rows = len(rows)
            for i in range(1, total_rows):
                col_data = []
                cols = rows[i].find_all('td')
                total_cols = len(cols)
                for i in range(0, 5):
                    col_data.append(cols[i].text)
                col_data.append(constituency)
                for i in range(5, total_cols):
                    col_data.append(inr_to_int(cols[i].text))  
                col_data.append(2014)
                data.append(col_data)
                candidates += 1
        except :
            print('ERROR')
        else:
            constituencies += 1
            print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', candidates, "candidates from", constituencies, "constituencies")
    df.to_csv(str(year) + '.csv', index=False)
    

main()
# Out:
# Trying ID 1 => Saving Adilabad , Telangana => SUCCESS
# Trying ID 2 => Saving Peddapalle , Telangana => SUCCESS
# Trying ID 3 => Saving Karimnagar , Telangana => SUCCESS
# Trying ID 4 => Saving Nizamabad , Telangana => SUCCESS
# Trying ID 5 => Saving Zahirabad , Telangana => SUCCESS
# Trying ID 6 => Saving Medak , Telangana => SUCCESS
# Trying ID 7 => Saving Malkajgiri , Telangana => SUCCESS
# Trying ID 8 => Saving Secunderabad , Telangana => SUCCESS
# Trying ID 9 => Saving Hyderabad , Telangana => SUCCESS
# Trying ID 10 => Saving Chevella , Telangana => SUCCESS
# Trying ID 11 => Saving Mahbubnagar , Telangana => SUCCESS
# Trying ID 12 => Saving Nagarkurnool , Telangana => SUCCESS
# Trying ID 13 => Saving Nalgonda , Telangana => SUCCESS
# Trying ID 14 => Saving Bhongir , Telangana => SUCCESS
# Trying ID 15 => Saving Warangal , Telangana => SUCCESS
# Trying ID 16 => Saving Mahabubabad , Telangana => SUCCESS
# Trying ID 17 => Saving Khammam , Telangana => SUCCESS
# Trying ID 18 => Saving Araku , Andhra Pradesh => SUCCESS
# Trying ID 19 => Saving Srikakulam , Andhra Pradesh => SUCCESS
# Trying ID 20 => Saving Vizianagaram , Andhra Pradesh => SUCCESS
# Trying ID 21 => Saving Visakhapatnam , Andhra Pradesh => SUCCESS
# Trying ID 22 => Saving Anakapalle , Andhra Pradesh => SUCCESS
# Trying ID 23 => Saving Arunachal West , Arunachal Pradesh => SUCCESS
# Trying ID 24 => Saving Arunachal East , Arunachal Pradesh => SUCCESS
# Trying ID 25 => Saving Karimganj , Assam => SUCCESS
# Trying ID 26 => Saving Silchar , Assam => SUCCESS
# Trying ID 27 => Saving Autonomous District , Assam => SUCCESS
# Trying ID 28 => Saving Gopalganj , Bihar => SUCCESS
# Trying ID 29 => Saving Siwan , Bihar => SUCCESS
# Trying ID 30 => Saving Maharajganj , Bihar => SUCCESS
# Trying ID 31 => Saving Saran , Bihar => SUCCESS
# Trying ID 32 => Saving Arrah , Bihar => SUCCESS
# Trying ID 33 => Saving Buxar , Bihar => SUCCESS
# Trying ID 34 => Saving Sasaram , Bihar => SUCCESS
# Trying ID 35 => Saving Karakat , Bihar => SUCCESS
# Trying ID 36 => Saving Jahanabad , Bihar => SUCCESS
# Trying ID 37 => Saving Aurangabad , Bihar => SUCCESS
# Trying ID 38 => Saving Gaya , Bihar => SUCCESS
# Trying ID 39 => Saving Nawada , Bihar => SUCCESS
# Trying ID 40 => Saving Jamui , Bihar => SUCCESS
# Trying ID 41 => Saving Jammu , Jammu & Kashmir => SUCCESS
# Trying ID 42 => Saving Kasaragod , Kerala => SUCCESS
# Trying ID 43 => Saving Kannur , Kerala => SUCCESS
# Trying ID 44 => Saving Vadakara , Kerala => SUCCESS
# Trying ID 45 => Saving Wayanad , Kerala => SUCCESS
# Trying ID 46 => Saving Kozhikode , Kerala => SUCCESS
# Trying ID 47 => Saving Malappuram , Kerala => SUCCESS
# Trying ID 48 => Saving Ponnani , Kerala => SUCCESS
# Trying ID 49 => Saving Palakkad , Kerala => SUCCESS
# Trying ID 50 => Saving Alathur , Kerala => SUCCESS
# Trying ID 51 => Saving Thrissur , Kerala => SUCCESS
# Trying ID 52 => Saving Chalakudy , Kerala => SUCCESS
# Trying ID 53 => Saving Ernakulam , Kerala => SUCCESS
# Trying ID 54 => Saving Idukki , Kerala => SUCCESS
# Trying ID 55 => Saving Kottayam , Kerala => SUCCESS
# Trying ID 56 => Saving Alappuzha , Kerala => SUCCESS
# Trying ID 57 => Saving Mavelikkara , Kerala => SUCCESS
# Trying ID 58 => Saving Pathanamthitta , Kerala => SUCCESS
# Trying ID 59 => Saving Kollam , Kerala => SUCCESS
# Trying ID 60 => Saving Attingal , Kerala => SUCCESS
# Trying ID 61 => Saving Thiruvananthapuram , Kerala => SUCCESS
# Trying ID 62 => Saving Buldhana , Maharashtra => SUCCESS
# Trying ID 63 => Saving Akola , Maharashtra => SUCCESS
# Trying ID 64 => Saving Amravati , Maharashtra => SUCCESS
# Trying ID 65 => Saving Wardha , Maharashtra => SUCCESS
# Trying ID 66 => Saving Ramtek , Maharashtra => SUCCESS
# Trying ID 67 => Saving Nagpur , Maharashtra => SUCCESS
# Trying ID 68 => Saving Bhandara Gondiya , Maharashtra => SUCCESS
# Trying ID 69 => Saving Gadchiroli Chimur , Maharashtra => SUCCESS
# Trying ID 70 => Saving Chandrapur , Maharashtra => SUCCESS
# Trying ID 71 => Saving Yavatmal Washim , Maharashtra => SUCCESS
# Trying ID 72 => Saving Hingoli , Maharashtra => SUCCESS
# Trying ID 73 => Saving Nanded , Maharashtra => SUCCESS
# Trying ID 74 => Saving Parbhani , Maharashtra => SUCCESS
# Trying ID 75 => Saving Outer Manipur , Manipur => SUCCESS
# Trying ID 76 => Saving Shillong , Meghalaya => SUCCESS
# Trying ID 77 => Saving Tura , Meghalaya => SUCCESS
# Trying ID 78 => Saving Mizoram , Mizoram => SUCCESS
# Trying ID 79 => Saving Nagaland , Nagaland => SUCCESS
# Trying ID 80 => Saving Bargarh , Orissa => SUCCESS
# Trying ID 81 => Saving Sundargarh , Orissa => SUCCESS
# Trying ID 82 => Saving Sambalpur , Orissa => SUCCESS
# Trying ID 83 => Saving Bolangir , Orissa => SUCCESS
# Trying ID 84 => Saving Kalahandi , Orissa => SUCCESS
# Trying ID 85 => Saving Nabarangpur , Orissa => SUCCESS
# Trying ID 86 => Saving Kandhamal , Orissa => SUCCESS
# Trying ID 87 => Saving Aska , Orissa => SUCCESS
# Trying ID 88 => Saving Berhampur , Orissa => SUCCESS
# Trying ID 89 => Saving Koraput , Orissa => SUCCESS
# Trying ID 90 => Saving Maharajganj , Uttar Pradesh => SUCCESS
# Trying ID 91 => Saving Gorakhpur , Uttar Pradesh => SUCCESS
# Trying ID 92 => Saving Kushi Nagar , Uttar Pradesh => SUCCESS
# Trying ID 93 => Saving Deoria , Uttar Pradesh => SUCCESS
# Trying ID 94 => Saving Bansgaon , Uttar Pradesh => SUCCESS
# Trying ID 95 => Saving Lalganj , Uttar Pradesh => SUCCESS
# Trying ID 96 => Saving Azamgarh , Uttar Pradesh => SUCCESS
# Trying ID 97 => Saving Ghosi , Uttar Pradesh => SUCCESS
# Trying ID 98 => Saving Salempur , Uttar Pradesh => SUCCESS
# Trying ID 99 => Saving Ballia , Uttar Pradesh => SUCCESS
# Trying ID 100 => Saving Machhlishahr , Uttar Pradesh => SUCCESS
# Trying ID 101 => Saving Ghazipur , Uttar Pradesh => SUCCESS
# Trying ID 102 => Saving Chandauli , Uttar Pradesh => SUCCESS
# Trying ID 103 => Saving Varanasi , Uttar Pradesh => SUCCESS
# Trying ID 104 => Saving Mirzapur , Uttar Pradesh => SUCCESS
# Trying ID 105 => Saving Robertsganj , Uttar Pradesh => SUCCESS
# Trying ID 106 => Saving Surguja , Chhattisgarh => SUCCESS
# Trying ID 107 => Saving Raigarh , Chhattisgarh => SUCCESS
# Trying ID 108 => Saving Janjgir-Champa , Chhattisgarh => SUCCESS
# Trying ID 109 => Saving Korba , Chhattisgarh => SUCCESS
# Trying ID 110 => Saving Bilaspur , Chhattisgarh => SUCCESS
# Trying ID 111 => Saving Rajnandgaon , Chhattisgarh => SUCCESS
# Trying ID 112 => Saving Durg , Chhattisgarh => SUCCESS
# Trying ID 113 => Saving Raipur , Chhattisgarh => SUCCESS
# Trying ID 114 => Saving Mahasamund , Chhattisgarh => SUCCESS
# Trying ID 115 => Saving Bastar , Chhattisgarh => SUCCESS
# Trying ID 116 => Saving Kanker , Chhattisgarh => SUCCESS
# Trying ID 117 => Saving Chatra , Jharkhand => SUCCESS
# Trying ID 118 => Saving Kodarma , Jharkhand => SUCCESS
# Trying ID 119 => Saving Khunti , Jharkhand => SUCCESS
# Trying ID 120 => Saving Lohardaga , Jharkhand => SUCCESS
# Trying ID 121 => Saving Palamau , Jharkhand => SUCCESS
# Trying ID 122 => Saving Hazaribagh , Jharkhand => SUCCESS
# Trying ID 123 => Saving Andaman And Nicobar Islands , Andaman & Nicobar Islands => SUCCESS
# Trying ID 124 => Saving Lakshadweep , Lakshadweep => SUCCESS
# Trying ID 125 => Saving Chikkodi , Karnataka => SUCCESS
# Trying ID 126 => Saving Belgaum , Karnataka => SUCCESS
# Trying ID 127 => Saving Bijapur , Karnataka => SUCCESS
# Trying ID 128 => Saving Gulbarga , Karnataka => SUCCESS
# Trying ID 129 => Saving Raichur , Karnataka => SUCCESS
# Trying ID 130 => Saving Bidar , Karnataka => SUCCESS
# Trying ID 131 => Saving Koppal , Karnataka => SUCCESS
# Trying ID 132 => Saving Bellary , Karnataka => SUCCESS
# Trying ID 133 => Saving Uttara Kannada , Karnataka => SUCCESS
# Trying ID 134 => Saving Chitradurga , Karnataka => SUCCESS
# Trying ID 135 => Saving Tumkur , Karnataka => SUCCESS
# Trying ID 136 => Saving Bangalore Rural , Karnataka => SUCCESS
# Trying ID 137 => Saving Bangalore North , Karnataka => SUCCESS
# Trying ID 138 => Saving Bangalore Central , Karnataka => SUCCESS
# Trying ID 139 => Saving Bangalore South , Karnataka => SUCCESS
# Trying ID 140 => Saving Chikkballapur , Karnataka => SUCCESS
# Trying ID 141 => Saving Kolar , Karnataka => SUCCESS
# Trying ID 142 => Saving Kakinada , Andhra Pradesh => SUCCESS
# Trying ID 143 => Saving Amalapuram , Andhra Pradesh => SUCCESS
# Trying ID 144 => Saving Rajahmundry , Andhra Pradesh => SUCCESS
# Trying ID 145 => Saving Narsapuram , Andhra Pradesh => SUCCESS
# Trying ID 146 => Saving Eluru , Andhra Pradesh => SUCCESS
# Trying ID 147 => Saving Machilipatnam , Andhra Pradesh => SUCCESS
# Trying ID 148 => Saving Vijayawada , Andhra Pradesh => SUCCESS
# Trying ID 149 => Saving Guntur , Andhra Pradesh => SUCCESS
# Trying ID 150 => Saving Narasaraopet , Andhra Pradesh => SUCCESS
# Trying ID 151 => Saving Bapatla , Andhra Pradesh => SUCCESS
# Trying ID 152 => Saving Ongole , Andhra Pradesh => SUCCESS
# Trying ID 153 => Saving Nandyal , Andhra Pradesh => SUCCESS
# Trying ID 154 => Saving Kurnool , Andhra Pradesh => SUCCESS
# Trying ID 155 => Saving Anantapur , Andhra Pradesh => SUCCESS
# Trying ID 156 => Saving Hindupur , Andhra Pradesh => SUCCESS
# Trying ID 157 => Saving Kadapa , Andhra Pradesh => SUCCESS
# Trying ID 158 => Saving Nellore , Andhra Pradesh => SUCCESS
# Trying ID 159 => Saving Tirupati , Andhra Pradesh => SUCCESS
# Trying ID 160 => Saving Rajampet , Andhra Pradesh => SUCCESS
# Trying ID 161 => Saving Chittoor , Andhra Pradesh => SUCCESS
# Trying ID 162 => Saving Dhubri , Assam => SUCCESS
# Trying ID 163 => Saving Kokrajhar , Assam => SUCCESS
# Trying ID 164 => Saving Barpeta , Assam => SUCCESS
# Trying ID 165 => Saving Gauhati , Assam => SUCCESS
# Trying ID 166 => Saving Mangaldoi , Assam => SUCCESS
# Trying ID 167 => Saving Tezpur , Assam => SUCCESS
# Trying ID 168 => Saving Nowgong , Assam => SUCCESS
# Trying ID 169 => Saving Kaliabor , Assam => SUCCESS
# Trying ID 170 => Saving Jorhat , Assam => SUCCESS
# Trying ID 171 => Saving Dibrugarh , Assam => SUCCESS
# Trying ID 172 => Saving Lakhimpur , Assam => SUCCESS
# Trying ID 173 => Saving Valmiki Nagar , Bihar => SUCCESS
# Trying ID 174 => Saving Paschim Champaran , Bihar => SUCCESS
# Trying ID 175 => Saving Purvi Champaran , Bihar => SUCCESS
# Trying ID 176 => Saving Sheohar , Bihar => SUCCESS
# Trying ID 177 => Saving Sitamarhi , Bihar => SUCCESS
# Trying ID 178 => Saving Madhubani , Bihar => SUCCESS
# Trying ID 179 => Saving Jhanjharpur , Bihar => SUCCESS
# Trying ID 180 => Saving Darbhanga , Bihar => SUCCESS
# Trying ID 181 => Saving Muzaffarpur , Bihar => SUCCESS
# Trying ID 182 => Saving Vaishali , Bihar => SUCCESS
# Trying ID 183 => Saving Hajipur , Bihar => SUCCESS
# Trying ID 184 => Saving Ujiarpur , Bihar => SUCCESS
# Trying ID 185 => Saving Samastipur , Bihar => SUCCESS
# Trying ID 186 => Saving North Goa , Goa => SUCCESS
# Trying ID 187 => Saving South Goa , Goa => SUCCESS
# Trying ID 188 => Saving Udhampur , Jammu & Kashmir => SUCCESS
# Trying ID 189 => Saving Khajuraho , Madhya Pradesh => SUCCESS
# Trying ID 190 => Saving Satna , Madhya Pradesh => SUCCESS
# Trying ID 191 => Saving Rewa , Madhya Pradesh => SUCCESS
# Trying ID 192 => Saving Sidhi , Madhya Pradesh => SUCCESS
# Trying ID 193 => Saving Shahdol , Madhya Pradesh => SUCCESS
# Trying ID 194 => Saving Jabalpur , Madhya Pradesh => SUCCESS
# Trying ID 195 => Saving Mandla , Madhya Pradesh => SUCCESS
# Trying ID 196 => Saving Balaghat , Madhya Pradesh => SUCCESS
# Trying ID 197 => Saving Chhindwara , Madhya Pradesh => SUCCESS
# Trying ID 198 => Saving Hoshangabad , Madhya Pradesh => SUCCESS
# Trying ID 199 => Saving Vidisha , Madhya Pradesh => SUCCESS
# Trying ID 200 => Saving Bhopal , Madhya Pradesh => SUCCESS
# Trying ID 201 => Saving Betul , Madhya Pradesh => SUCCESS
# Trying ID 202 => Saving Nandurbar , Maharashtra => SUCCESS
# Trying ID 203 => Saving Dhule , Maharashtra => SUCCESS
# Trying ID 204 => Saving Jalgaon , Maharashtra => SUCCESS
# Trying ID 205 => Saving Raver , Maharashtra => SUCCESS
# Trying ID 206 => Saving Jalna , Maharashtra => SUCCESS
# Trying ID 207 => Saving Aurangabad , Maharashtra => SUCCESS
# Trying ID 208 => Saving Dindori , Maharashtra => SUCCESS
# Trying ID 209 => Saving Nashik , Maharashtra => SUCCESS
# Trying ID 210 => Saving Raigad , Maharashtra => SUCCESS
# Trying ID 211 => Saving Maval , Maharashtra => SUCCESS
# Trying ID 212 => Saving Pune , Maharashtra => SUCCESS
# Trying ID 213 => Saving Baramati , Maharashtra => SUCCESS
# Trying ID 214 => Saving Shirur , Maharashtra => SUCCESS
# Trying ID 215 => Saving Ahmednagar , Maharashtra => SUCCESS
# Trying ID 216 => Saving Shirdi , Maharashtra => SUCCESS
# Trying ID 217 => Saving Beed , Maharashtra => SUCCESS
# Trying ID 218 => Saving Osmanabad , Maharashtra => SUCCESS
# Trying ID 219 => Saving Latur , Maharashtra => SUCCESS
# Trying ID 220 => Saving Solapur , Maharashtra => SUCCESS
# Trying ID 221 => Saving Madha , Maharashtra => SUCCESS
# Trying ID 222 => Saving Sangli , Maharashtra => SUCCESS
# Trying ID 223 => Saving Satara , Maharashtra => SUCCESS
# Trying ID 224 => Saving Ratnagiri Sindhudurg , Maharashtra => SUCCESS
# Trying ID 225 => Saving Kolhapur , Maharashtra => SUCCESS
# Trying ID 226 => Saving Hatkanangle , Maharashtra => SUCCESS
# Trying ID 227 => Saving Keonjhar , Orissa => SUCCESS
# Trying ID 228 => Saving Mayurbhanj , Orissa => SUCCESS
# Trying ID 229 => Saving Balasore , Orissa => SUCCESS
# Trying ID 230 => Saving Bhadrak , Orissa => SUCCESS
# Trying ID 231 => Saving Jajpur , Orissa => SUCCESS
# Trying ID 232 => Saving Dhenkanal , Orissa => SUCCESS
# Trying ID 233 => Saving Cuttack , Orissa => SUCCESS
# Trying ID 234 => Saving Kendrapara , Orissa => SUCCESS
# Trying ID 235 => Saving Jagatsinghpur , Orissa => SUCCESS
# Trying ID 236 => Saving Puri , Orissa => SUCCESS
# Trying ID 237 => Saving Bhubaneswar , Orissa => SUCCESS
# Trying ID 238 => Saving Tripura West , Tripura => SUCCESS
# Trying ID 239 => Saving Tripura East , Tripura => SUCCESS
# Trying ID 240 => Saving Amethi , Uttar Pradesh => SUCCESS
# Trying ID 241 => Saving Sultanpur , Uttar Pradesh => SUCCESS
# Trying ID 242 => Saving Pratapgarh , Uttar Pradesh => SUCCESS
# Trying ID 243 => Saving Banda , Uttar Pradesh => SUCCESS
# Trying ID 244 => Saving Kaushambi , Uttar Pradesh => SUCCESS
# Trying ID 245 => Saving Phulpur , Uttar Pradesh => SUCCESS
# Trying ID 246 => Saving Allahabad , Uttar Pradesh => SUCCESS
# Trying ID 247 => Saving Faizabad , Uttar Pradesh => SUCCESS
# Trying ID 248 => Saving Ambedkar Nagar , Uttar Pradesh => SUCCESS
# Trying ID 249 => Saving Kaiserganj , Uttar Pradesh => SUCCESS
# Trying ID 250 => Saving Shrawasti , Uttar Pradesh => SUCCESS
# Trying ID 251 => Saving Gonda , Uttar Pradesh => SUCCESS
# Trying ID 252 => Saving Domariyaganj , Uttar Pradesh => SUCCESS
# Trying ID 253 => Saving Basti , Uttar Pradesh => SUCCESS
# Trying ID 254 => Saving Sant Kabir Nagar , Uttar Pradesh => SUCCESS
# Trying ID 255 => Saving Jaunpur , Uttar Pradesh => SUCCESS
# Trying ID 256 => Saving Bhadohi , Uttar Pradesh => SUCCESS
# Trying ID 257 => Saving Rajmahal , Jharkhand => SUCCESS
# Trying ID 258 => Saving Dumka , Jharkhand => SUCCESS
# Trying ID 259 => Saving Godda , Jharkhand => SUCCESS
# Trying ID 260 => Saving Giridih , Jharkhand => SUCCESS
# Trying ID 261 => Saving Dhanbad , Jharkhand => SUCCESS
# Trying ID 262 => Saving Ranchi , Jharkhand => SUCCESS
# Trying ID 263 => Saving Jamshedpur , Jharkhand => SUCCESS
# Trying ID 264 => Saving Singhbhum , Jharkhand => SUCCESS
# Trying ID 265 => Saving Inner Manipur , Manipur => SUCCESS
# Trying ID 266 => Saving Kachchh , Gujarat => SUCCESS
# Trying ID 267 => Saving Banaskantha , Gujarat => SUCCESS
# Trying ID 268 => Saving Patan , Gujarat => SUCCESS
# Trying ID 269 => Saving Mahesana , Gujarat => SUCCESS
# Trying ID 270 => Saving Sabarkantha , Gujarat => SUCCESS
# Trying ID 271 => Saving Gandhinagar , Gujarat => SUCCESS
# Trying ID 272 => Saving Ahmedabad East , Gujarat => SUCCESS
# Trying ID 273 => Saving Ahmedabad West , Gujarat => SUCCESS
# Trying ID 274 => Saving Surendranagar , Gujarat => SUCCESS
# Trying ID 275 => Saving Rajkot , Gujarat => SUCCESS
# Trying ID 276 => Saving Porbandar , Gujarat => SUCCESS
# Trying ID 277 => Saving Jamnagar , Gujarat => SUCCESS
# Trying ID 278 => Saving Junagadh , Gujarat => SUCCESS
# Trying ID 279 => Saving Amreli , Gujarat => SUCCESS
# Trying ID 280 => Saving Bhavnagar , Gujarat => SUCCESS
# Trying ID 281 => Saving Anand , Gujarat => SUCCESS
# Trying ID 282 => Saving Kheda , Gujarat => SUCCESS
# Trying ID 283 => Saving Panchmahal , Gujarat => SUCCESS
# Trying ID 284 => Saving Dahod , Gujarat => SUCCESS
# Trying ID 285 => Saving Vadodara , Gujarat => SUCCESS
# Trying ID 286 => Saving Chhota Udaipur , Gujarat => SUCCESS
# Trying ID 287 => Saving Bharuch , Gujarat => SUCCESS
# Trying ID 288 => Saving Bardoli , Gujarat => SUCCESS
# Trying ID 289 => Saving Surat , Gujarat => SUCCESS
# Trying ID 290 => Saving Navsari , Gujarat => SUCCESS
# Trying ID 291 => Saving Valsad , Gujarat => SUCCESS
# Trying ID 292 => Saving Bagalkot , Karnataka => SUCCESS
# Trying ID 293 => Saving Haveri , Karnataka => SUCCESS
# Trying ID 294 => Saving Dharwad , Karnataka => SUCCESS
# Trying ID 295 => Saving Davanagere , Karnataka => SUCCESS
# Trying ID 296 => Saving Shimoga , Karnataka => SUCCESS
# Trying ID 297 => Saving Udupi Chikmagalur , Karnataka => SUCCESS
# Trying ID 298 => Saving Hassan , Karnataka => SUCCESS
# Trying ID 299 => Saving Dakshina Kannada , Karnataka => SUCCESS
# Trying ID 300 => Saving Mandya , Karnataka => SUCCESS
# Trying ID 301 => Saving Mysore , Karnataka => SUCCESS
# Trying ID 302 => Saving Chamarajanagar , Karnataka => SUCCESS
# Trying ID 303 => Saving Supaul , Bihar => SUCCESS
# Trying ID 304 => Saving Araria , Bihar => SUCCESS
# Trying ID 305 => Saving Kishanganj , Bihar => SUCCESS
# Trying ID 306 => Saving Katihar , Bihar => SUCCESS
# Trying ID 307 => Saving Purnia , Bihar => SUCCESS
# Trying ID 308 => Saving Madhepura , Bihar => SUCCESS
# Trying ID 309 => Saving Begusarai , Bihar => SUCCESS
# Trying ID 310 => Saving Khagaria , Bihar => SUCCESS
# Trying ID 311 => Saving Bhagalpur , Bihar => SUCCESS
# Trying ID 312 => Saving Banka , Bihar => SUCCESS
# Trying ID 313 => Saving Munger , Bihar => SUCCESS
# Trying ID 314 => Saving Anantnag , Jammu & Kashmir => SUCCESS
# Trying ID 315 => Saving Morena , Madhya Pradesh => SUCCESS
# Trying ID 316 => Saving Bhind , Madhya Pradesh => SUCCESS
# Trying ID 317 => Saving Gwalior , Madhya Pradesh => SUCCESS
# Trying ID 318 => Saving Guna , Madhya Pradesh => SUCCESS
# Trying ID 319 => Saving Sagar , Madhya Pradesh => SUCCESS
# Trying ID 320 => Saving Tikamgarh , Madhya Pradesh => SUCCESS
# Trying ID 321 => Saving Damoh , Madhya Pradesh => SUCCESS
# Trying ID 322 => Saving Rajgarh , Madhya Pradesh => SUCCESS
# Trying ID 323 => Saving Dewas , Madhya Pradesh => SUCCESS
# Trying ID 324 => Saving Ujjain , Madhya Pradesh => SUCCESS
# Trying ID 325 => Saving Mandsour , Madhya Pradesh => SUCCESS
# Trying ID 326 => Saving Ratlam , Madhya Pradesh => SUCCESS
# Trying ID 327 => Saving Dhar , Madhya Pradesh => SUCCESS
# Trying ID 328 => Saving Indore , Madhya Pradesh => SUCCESS
# Trying ID 329 => Saving Khargone , Madhya Pradesh => SUCCESS
# Trying ID 330 => Saving Khandwa , Madhya Pradesh => SUCCESS
# Trying ID 331 => Saving Palghar , Maharashtra => SUCCESS
# Trying ID 332 => Saving Bhiwandi , Maharashtra => SUCCESS
# Trying ID 333 => Saving Kalyan , Maharashtra => SUCCESS
# Trying ID 334 => Saving Thane , Maharashtra => SUCCESS
# Trying ID 335 => Saving Mumbai North , Maharashtra => SUCCESS
# Trying ID 336 => Saving Mumbai North West , Maharashtra => SUCCESS
# Trying ID 337 => Saving Mumbai North East , Maharashtra => SUCCESS
# Trying ID 338 => Saving Mumbai North Central , Maharashtra => SUCCESS
# Trying ID 339 => Saving Mumbai South Central , Maharashtra => SUCCESS
# Trying ID 340 => Saving Mumbai South , Maharashtra => SUCCESS
# Trying ID 341 => Saving Sikkim , Sikkim => SUCCESS
# Trying ID 342 => Saving Sitapur , Uttar Pradesh => SUCCESS
# Trying ID 343 => Saving Hardoi , Uttar Pradesh => SUCCESS
# Trying ID 344 => Saving Misrikh , Uttar Pradesh => SUCCESS
# Trying ID 345 => Saving Unnao , Uttar Pradesh => SUCCESS
# Trying ID 346 => Saving Mohanlalganj , Uttar Pradesh => SUCCESS
# Trying ID 347 => Saving Lucknow , Uttar Pradesh => SUCCESS
# Trying ID 348 => Saving Rae Bareli , Uttar Pradesh => SUCCESS
# Trying ID 349 => Saving Kanpur , Uttar Pradesh => SUCCESS
# Trying ID 350 => Saving Akbarpur , Uttar Pradesh => SUCCESS
# Trying ID 351 => Saving Jalaun , Uttar Pradesh => SUCCESS
# Trying ID 352 => Saving Jhansi , Uttar Pradesh => SUCCESS
# Trying ID 353 => Saving Hamirpur , Uttar Pradesh => SUCCESS
# Trying ID 354 => Saving Fatehpur , Uttar Pradesh => SUCCESS
# Trying ID 355 => Saving Barabanki , Uttar Pradesh => SUCCESS
# Trying ID 356 => Saving Bahraich , Uttar Pradesh => SUCCESS
# Trying ID 357 => Saving Coochbehar , West Bengal => SUCCESS
# Trying ID 358 => Saving Alipurduars , West Bengal => SUCCESS
# Trying ID 359 => Saving Jalpaiguri , West Bengal => SUCCESS
# Trying ID 360 => Saving Darjeeling , West Bengal => SUCCESS
# Trying ID 361 => Saving Raiganj , West Bengal => SUCCESS
# Trying ID 362 => Saving Balurghat , West Bengal => SUCCESS
# Trying ID 363 => Saving Maldaha Uttar , West Bengal => SUCCESS
# Trying ID 364 => Saving Maldaha Dakshin , West Bengal => SUCCESS
# Trying ID 365 => Saving Ghatal , West Bengal => SUCCESS
# Trying ID 366 => Saving Jhargram , West Bengal => SUCCESS
# Trying ID 367 => Saving Medinipur , West Bengal => SUCCESS
# Trying ID 368 => Saving Purulia , West Bengal => SUCCESS
# Trying ID 369 => Saving Bankura , West Bengal => SUCCESS
# Trying ID 370 => Saving Bishnupur , West Bengal => SUCCESS
# Trying ID 371 => Saving Dadra And Nagar Haveli , Dadra & Nagar Haveli => SUCCESS
# Trying ID 372 => Saving Daman And Diu , Daman & Diu => SUCCESS
# Trying ID 373 => Saving Nalanda , Bihar => SUCCESS
# Trying ID 374 => Saving Patna Sahib , Bihar => SUCCESS
# Trying ID 375 => Saving Pataliputra , Bihar => SUCCESS
# Trying ID 376 => Saving Ambala , Haryana => SUCCESS
# Trying ID 377 => Saving Kurukshetra , Haryana => SUCCESS
# Trying ID 378 => Saving Sirsa , Haryana => SUCCESS
# Trying ID 379 => Saving Hisar , Haryana => SUCCESS
# Trying ID 380 => Saving Karnal , Haryana => SUCCESS
# Trying ID 381 => Saving Sonipat , Haryana => SUCCESS
# Trying ID 382 => Saving Rohtak , Haryana => SUCCESS
# Trying ID 383 => Saving Bhiwani Mahendragarh , Haryana => SUCCESS
# Trying ID 384 => Saving Gurgaon , Haryana => SUCCESS
# Trying ID 385 => Saving Faridabad , Haryana => SUCCESS
# Trying ID 386 => Saving Srinagar , Jammu & Kashmir => SUCCESS
# Trying ID 387 => Saving Firozpur , Punjab => SUCCESS
# Trying ID 388 => Saving Bathinda , Punjab => SUCCESS
# Trying ID 389 => Saving Sangrur , Punjab => SUCCESS
# Trying ID 390 => Saving Patiala , Punjab => SUCCESS
# Trying ID 391 => Saving Ganganagar , Rajasthan => SUCCESS
# Trying ID 392 => Saving Bikaner , Rajasthan => SUCCESS
# Trying ID 393 => Saving Churu , Rajasthan => SUCCESS
# Trying ID 394 => Saving Jhunjhunu , Rajasthan => SUCCESS
# Trying ID 395 => Saving Sikar , Rajasthan => SUCCESS
# Trying ID 396 => Saving Jaipur Rural , Rajasthan => SUCCESS
# Trying ID 397 => Saving Jaipur , Rajasthan => SUCCESS
# Trying ID 398 => Saving Alwar , Rajasthan => SUCCESS
# Trying ID 399 => Saving Bharatpur , Rajasthan => SUCCESS
# Trying ID 400 => Saving Karauli Dholpur , Rajasthan => SUCCESS
# Trying ID 401 => Saving Dausa , Rajasthan => SUCCESS
# Trying ID 402 => Saving Tonk Sawai Madhopur , Rajasthan => SUCCESS
# Trying ID 403 => Saving Ajmer , Rajasthan => SUCCESS
# Trying ID 404 => Saving Nagaur , Rajasthan => SUCCESS
# Trying ID 405 => Saving Pali , Rajasthan => SUCCESS
# Trying ID 406 => Saving Jodhpur , Rajasthan => SUCCESS
# Trying ID 407 => Saving Barmer , Rajasthan => SUCCESS
# Trying ID 408 => Saving Jalore , Rajasthan => SUCCESS
# Trying ID 409 => Saving Udaipur , Rajasthan => SUCCESS
# Trying ID 410 => Saving Banswara , Rajasthan => SUCCESS
# Trying ID 411 => Saving Chittorgarh , Rajasthan => SUCCESS
# Trying ID 412 => Saving Rajsamand , Rajasthan => SUCCESS
# Trying ID 413 => Saving Bhilwara , Rajasthan => SUCCESS
# Trying ID 414 => Saving Kota , Rajasthan => SUCCESS
# Trying ID 415 => Saving Jhalawar Baran , Rajasthan => SUCCESS
# Trying ID 416 => Saving Kairana , Uttar Pradesh => SUCCESS
# Trying ID 417 => Saving Muzaffarnagar , Uttar Pradesh => SUCCESS
# Trying ID 418 => Saving Meerut , Uttar Pradesh => SUCCESS
# Trying ID 419 => Saving Baghpat , Uttar Pradesh => SUCCESS
# Trying ID 420 => Saving Ghaziabad , Uttar Pradesh => SUCCESS
# Trying ID 421 => Saving Gautam Budhha Nagar , Uttar Pradesh => SUCCESS
# Trying ID 422 => Saving Bulandshahr , Uttar Pradesh => SUCCESS
# Trying ID 423 => Saving Aligarh , Uttar Pradesh => SUCCESS
# Trying ID 424 => Saving Hathras , Uttar Pradesh => SUCCESS
# Trying ID 425 => Saving Mathura , Uttar Pradesh => SUCCESS
# Trying ID 426 => Saving Agra , Uttar Pradesh => SUCCESS
# Trying ID 427 => Saving Fatehpur Sikri , Uttar Pradesh => SUCCESS
# Trying ID 428 => Saving Firozabad , Uttar Pradesh => SUCCESS
# Trying ID 429 => Saving Mainpuri , Uttar Pradesh => SUCCESS
# Trying ID 430 => Saving Etah , Uttar Pradesh => SUCCESS
# Trying ID 431 => Saving Farrukhabad , Uttar Pradesh => SUCCESS
# Trying ID 432 => Saving Etawah , Uttar Pradesh => SUCCESS
# Trying ID 433 => Saving Kannauj , Uttar Pradesh => SUCCESS
# Trying ID 434 => Saving Jangipur , West Bengal => SUCCESS
# Trying ID 435 => Saving Baharampur , West Bengal => SUCCESS
# Trying ID 436 => Saving Murshidabad , West Bengal => SUCCESS
# Trying ID 437 => Saving Krishnanagar , West Bengal => SUCCESS
# Trying ID 438 => Saving Ranaghat , West Bengal => SUCCESS
# Trying ID 439 => Saving Howrah , West Bengal => SUCCESS
# Trying ID 440 => Saving Uluberia , West Bengal => SUCCESS
# Trying ID 441 => Saving Sreerampur , West Bengal => SUCCESS
# Trying ID 442 => Saving Hooghly , West Bengal => SUCCESS
# Trying ID 443 => Saving Arambag , West Bengal => SUCCESS
# Trying ID 444 => Saving Tamluk , West Bengal => SUCCESS
# Trying ID 445 => Saving Kanthi , West Bengal => SUCCESS
# Trying ID 446 => Saving Bardhaman Purba , West Bengal => SUCCESS
# Trying ID 447 => Saving Bardhaman Durgapur , West Bengal => SUCCESS
# Trying ID 448 => Saving Asansol , West Bengal => SUCCESS
# Trying ID 449 => Saving Bolpur , West Bengal => SUCCESS
# Trying ID 450 => Saving Birbhum , West Bengal => SUCCESS
# Trying ID 451 => Saving Chandni Chowk , National Capital Territory Of Delhi => SUCCESS
# Trying ID 452 => Saving North East Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 453 => Saving East Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 454 => Saving New Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 455 => Saving North West Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 456 => Saving West Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 457 => Saving South Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 458 => Saving Kangra , Himachal Pradesh => SUCCESS
# Trying ID 459 => Saving Mandi , Himachal Pradesh => SUCCESS
# Trying ID 460 => Saving Hamirpur , Himachal Pradesh => SUCCESS
# Trying ID 461 => Saving Shimla , Himachal Pradesh => SUCCESS
# Trying ID 462 => Saving Baramulla , Jammu & Kashmir => SUCCESS
# Trying ID 463 => Saving Ladakh , Jammu & Kashmir => SUCCESS
# Trying ID 464 => Saving Gurdaspur , Punjab => SUCCESS
# Trying ID 465 => Saving Amritsar , Punjab => SUCCESS
# Trying ID 466 => Saving Khadoor Sahib , Punjab => SUCCESS
# Trying ID 467 => Saving Jalandhar , Punjab => SUCCESS
# Trying ID 468 => Saving Hoshiarpur , Punjab => SUCCESS
# Trying ID 469 => Saving Anandpur Sahib , Punjab => SUCCESS
# Trying ID 470 => Saving Ludhiana , Punjab => SUCCESS
# Trying ID 471 => Saving Fatehgarh Sahib , Punjab => SUCCESS
# Trying ID 472 => Saving Faridkot , Punjab => SUCCESS
# Trying ID 473 => Saving Tiruvallur , Tamil Nadu => SUCCESS
# Trying ID 474 => Saving Chennai North , Tamil Nadu => SUCCESS
# Trying ID 475 => Saving Chennai South , Tamil Nadu => SUCCESS
# Trying ID 476 => Saving Chennai Central , Tamil Nadu => SUCCESS
# Trying ID 477 => Saving Sriperumbudur , Tamil Nadu => SUCCESS
# Trying ID 478 => Saving Kancheepuram , Tamil Nadu => SUCCESS
# Trying ID 479 => Saving Arakkonam , Tamil Nadu => SUCCESS
# Trying ID 480 => Saving Vellore , Tamil Nadu => SUCCESS
# Trying ID 481 => Saving Krishnagiri , Tamil Nadu => SUCCESS
# Trying ID 482 => Saving Dharmapuri , Tamil Nadu => SUCCESS
# Trying ID 483 => Saving Tiruvannamalai , Tamil Nadu => SUCCESS
# Trying ID 484 => Saving Arani , Tamil Nadu => SUCCESS
# Trying ID 485 => Saving Viluppuram , Tamil Nadu => SUCCESS
# Trying ID 486 => Saving Kallakurichi , Tamil Nadu => SUCCESS
# Trying ID 487 => Saving Salem , Tamil Nadu => SUCCESS
# Trying ID 488 => Saving Namakkal , Tamil Nadu => SUCCESS
# Trying ID 489 => Saving Erode , Tamil Nadu => SUCCESS
# Trying ID 490 => Saving Tiruppur , Tamil Nadu => SUCCESS
# Trying ID 491 => Saving Nilgiris , Tamil Nadu => SUCCESS
# Trying ID 492 => Saving Coimbatore , Tamil Nadu => SUCCESS
# Trying ID 493 => Saving Pollachi , Tamil Nadu => SUCCESS
# Trying ID 494 => Saving Dindigul , Tamil Nadu => SUCCESS
# Trying ID 495 => Saving Karur , Tamil Nadu => SUCCESS
# Trying ID 496 => Saving Tiruchirappalli , Tamil Nadu => SUCCESS
# Trying ID 497 => Saving Perambalur , Tamil Nadu => SUCCESS
# Trying ID 498 => Saving Cuddalore , Tamil Nadu => SUCCESS
# Trying ID 499 => Saving Chidambaram , Tamil Nadu => SUCCESS
# Trying ID 500 => Saving Mayiladuthurai , Tamil Nadu => SUCCESS
# Trying ID 501 => Saving Nagapattinam , Tamil Nadu => SUCCESS
# Trying ID 502 => Saving Thanjavur , Tamil Nadu => SUCCESS
# Trying ID 503 => Saving Sivaganga , Tamil Nadu => SUCCESS
# Trying ID 504 => Saving Madurai , Tamil Nadu => SUCCESS
# Trying ID 505 => Saving Theni , Tamil Nadu => SUCCESS
# Trying ID 506 => Saving Virudhunagar , Tamil Nadu => SUCCESS
# Trying ID 507 => Saving Ramanathapuram , Tamil Nadu => SUCCESS
# Trying ID 508 => Saving Thoothukkudi , Tamil Nadu => SUCCESS
# Trying ID 509 => Saving Tenkasi , Tamil Nadu => SUCCESS
# Trying ID 510 => Saving Tirunelveli , Tamil Nadu => SUCCESS
# Trying ID 511 => Saving Kanniyakumari , Tamil Nadu => SUCCESS
# Trying ID 512 => Saving Saharanpur , Uttar Pradesh => SUCCESS
# Trying ID 513 => Saving Bijnor , Uttar Pradesh => SUCCESS
# Trying ID 514 => Saving Nagina , Uttar Pradesh => SUCCESS
# Trying ID 515 => Saving Moradabad , Uttar Pradesh => SUCCESS
# Trying ID 516 => Saving Rampur , Uttar Pradesh => SUCCESS
# Trying ID 517 => Saving Sambhal , Uttar Pradesh => SUCCESS
# Trying ID 518 => Saving Amroha , Uttar Pradesh => SUCCESS
# Trying ID 519 => Saving Badaun , Uttar Pradesh => SUCCESS
# Trying ID 520 => Saving Aonla , Uttar Pradesh => SUCCESS
# Trying ID 521 => Saving Bareilly , Uttar Pradesh => SUCCESS
# Trying ID 522 => Saving Pilibhit , Uttar Pradesh => SUCCESS
# Trying ID 523 => Saving Shahjahanpur , Uttar Pradesh => SUCCESS
# Trying ID 524 => Saving Kheri , Uttar Pradesh => SUCCESS
# Trying ID 525 => Saving Dhaurahra , Uttar Pradesh => SUCCESS
# Trying ID 526 => Saving Bangaon , West Bengal => SUCCESS
# Trying ID 527 => Saving Barrackpur , West Bengal => SUCCESS
# Trying ID 528 => Saving Dum Dum , West Bengal => SUCCESS
# Trying ID 529 => Saving Barasat , West Bengal => SUCCESS
# Trying ID 530 => Saving Basirhat , West Bengal => SUCCESS
# Trying ID 531 => Saving Jaynagar , West Bengal => SUCCESS
# Trying ID 532 => Saving Mathurapur , West Bengal => SUCCESS
# Trying ID 533 => Saving Diamond Harbour , West Bengal => SUCCESS
# Trying ID 534 => Saving Jadavpur , West Bengal => SUCCESS
# Trying ID 535 => Saving Kolkata Dakshin , West Bengal => SUCCESS
# Trying ID 536 => Saving Kolkata Uttar , West Bengal => SUCCESS
# Trying ID 537 => Saving Tehri Garhwal , Uttarakhand => SUCCESS
# Trying ID 538 => Saving Garhwal , Uttarakhand => SUCCESS
# Trying ID 539 => Saving Almora , Uttarakhand => SUCCESS
# Trying ID 540 => Saving Nainital Udhamsingh Nagar , Uttarakhand => SUCCESS
# Trying ID 541 => Saving Hardwar , Uttarakhand => SUCCESS
# Trying ID 542 => Saving Chandigarh , Chandigarh => SUCCESS
# Trying ID 543 => Saving Pondicherry , Puducherry => SUCCESS
# Trying ID 544 => Saving Medak , Bye Election On 13-09-2014 , Telangana => SUCCESS
# Trying ID 545 => Saving Vadodara , Bye Election On 13-09-2014 , Gujarat => SUCCESS
# Trying ID 546 => Saving Mainpuri , Bye Election On 13-09-2014 , Uttar Pradesh => SUCCESS
# Trying ID 547 => Saving Beed , Bye Election On 15-10-2014 , Maharashtra => SUCCESS
# Trying ID 548 => Saving Kandhamal , Bye Election On 15-10-2014 , Orissa => SUCCESS
# Trying ID 549 => Saving Bangaon , Bye Election On 13-02-2015 , West Bengal => SUCCESS
# Trying ID 550 => Saving Warangal , Bye Election On 21-11-2015 , Telangana => SUCCESS
# Trying ID 551 => Saving Ratlam , Bye Election On 21-11-2015 , Madhya Pradesh => SUCCESS
# Trying ID 552 => Saving Tura , Bye Election On 16-05-2016 , Meghalaya => SUCCESS
# Trying ID 553 => Saving Lakhimpur , Bye Election On 19-11-2016 , Assam => SUCCESS
# Trying ID 554 => Saving Shahdol (St) , Bye Election On 19-11-2016 , Madhya Pradesh => SUCCESS
# Trying ID 555 => Saving Coochbehar (Sc) , Bye Election On 19-11-2016 , West Bengal => SUCCESS
# Trying ID 556 => Saving Tamluk , Bye Election On 19-11-2016 , West Bengal => SUCCESS
# Trying ID 557 => Saving Srinagar , Bye Election On 09-04-2017 , Jammu & Kashmir => SUCCESS
# Trying ID 558 => Saving Anantnag , Bye Election On 12-04-2017 , Jammu & Kashmir => SUCCESS
# Trying ID 559 => Saving Malappuram , Bye Election On 12-04-2017 , Kerala => SUCCESS
# Trying ID 560 => Saving Gurdaspur , Bye Election On 11-10-2017 , Punjab => SUCCESS
# Trying ID 561 => Saving Amritsar , Bye- Election On 04-02-2017 , Punjab => SUCCESS
# Trying ID 562 => Saving Alwar , Bye Election On 29-01-2018 , Rajasthan => SUCCESS
# Trying ID 563 => Saving Ajmer , Bye Election On 29-01-2018 , Rajasthan => SUCCESS
# Trying ID 564 => Saving Uluberia , Bye Election On 29-01-2018 , West Bengal => SUCCESS
# Trying ID 565 => Saving Araria , Bye Election On 11-03-2018 , Bihar => SUCCESS
# Trying ID 566 => Saving Phulpur , Bye Election On 11-03-2018 , Uttar Pradesh => SUCCESS
# Trying ID 567 => Saving Gorakhpur , Bye Election On 11-03-2018 , Uttar Pradesh => SUCCESS
# Trying ID 568 => Saving Bhandara-Gondiya , Bye Election On 28-05-2018 , Maharashtra => SUCCESS
# Trying ID 569 => Saving Palghar , Bye Election On 28-05-2018 , Maharashtra => SUCCESS
# Trying ID 570 => Saving Nagaland , Bye Election On 28-05-2018 , Nagaland => SUCCESS
# Trying ID 571 => Saving Kairana , Bye Election On 28-05-2018 , Uttar Pradesh => SUCCESS
# Trying ID 572 => Saving Bellary , Bye Election On 03-11-2018 , Karnataka => SUCCESS
# Trying ID 573 => Saving Shimoga , Bye Election On 03-11-2018 , Karnataka => SUCCESS
# Trying ID 574 => Saving Mandya , Bye Election On 03-11-2018 , Karnataka => SUCCESS
# Saved => 8484 candidates from 574 constituencies

# %% [markdown]
# ## Visualizing data

# %%
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

matplotlib.rc('figure', figsize=(10, 5))
matplotlib.rc('font', weight='bold', size=12)

# %%
data = pd.read_csv(str(year) + '.csv')
data
# Out:
#                           Candidate  Party  Criminal Cases  \
# 0            Godam Nagesh   Winner     TRS               0
# 1                     Banka Sahadev    IND               1
# 2                  Mosali Chinnaiah    IND               0
# 3                            Naresh    INC               0
# 4                  Nethawath Ramdas    IND               0
# ...                             ...    ...             ...
# 8479                   Y.pampapathi    IND               0
# 8480      B.y.raghavendra   Winner     BJP               2
# 8481  L.r.shivarame Gowda   Winner   JD(S)               5
# 8482                    K.s.rajanna    IND               0
# 8483             Nandish Kumara K B    IND               0
#
#                   Education  Age  \
# 0             Post Graduate   49
# 1                  Graduate   53
# 2                 12th Pass   40
# 3                 Doctorate   37
# 4                Illiterate   44
# ...                     ...  ...
# 8479              12th Pass   60
# 8480  Graduate Professional   45
# 8481              12th Pass   62
# 8482              10th Pass   59
# 8483              12th Pass   32
#
#                                           Constituency  Total Assets  \
# 0                                 Adilabad + Telangana      10378857
# 1                                 Adilabad + Telangana        393000
# 2                                 Adilabad + Telangana       3167000
# 3                                 Adilabad + Telangana       1800000
# 4                                 Adilabad + Telangana             0
# ...                                                ...           ...
# 8479  Bellary + Bye Election On 03-11-2018 + Karnataka       2760000
# 8480  Shimoga + Bye Election On 03-11-2018 + Karnataka     588903795
# 8481   Mandya + Bye Election On 03-11-2018 + Karnataka     983129191
# 8482   Mandya + Bye Election On 03-11-2018 + Karnataka      42396540
# 8483   Mandya + Bye Election On 03-11-2018 + Karnataka             0
#
#       Liabilities  Year
# 0          148784  2014
# 1               0  2014
# 2           40000  2014
# 3               0  2014
# 4               0  2014
# ...           ...   ...
# 8479            0  2014
# 8480     13350647  2014
# 8481      5339531  2014
# 8482      2400000  2014
# 8483            0  2014
#
# [8484 rows x 9 columns]

# %%
data.describe()
# Out:
#        Criminal Cases          Age  Total Assets   Liabilities    Year
# count     8484.000000  8484.000000  8.484000e+03  8.484000e+03  8484.0
# mean         0.550684    46.762023  4.958916e+07  3.950880e+06  2014.0
# std          6.147574    12.681485  9.194760e+08  4.117516e+07     0.0
# min          0.000000     0.000000  0.000000e+00  0.000000e+00  2014.0
# 25%          0.000000    38.000000  4.453750e+05  0.000000e+00  2014.0
# 50%          0.000000    46.000000  2.458440e+06  0.000000e+00  2014.0
# 75%          0.000000    56.000000  1.151615e+07  4.000000e+05  2014.0
# max        382.000000    93.000000  7.710296e+10  2.218003e+09  2014.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8484 entries, 0 to 8483
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       8484 non-null   object
#  1   Party           8484 non-null   object
#  2   Criminal Cases  8484 non-null   int64
#  3   Education       8484 non-null   object
#  4   Age             8484 non-null   int64
#  5   Constituency    8484 non-null   object
#  6   Total Assets    8484 non-null   int64
#  7   Liabilities     8484 non-null   int64
#  8   Year            8484 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 596.7+ KB

# %%
# Total number of Parties
np.size(data["Party"].unique()) - 1
# Reducing by one for independent candidates
# Out:
# 512

# %%
candidates = np.size(data["Candidate"])
candidates
# Out:
# 8484

# %%
candidates - np.size(data["Candidate"].unique())
# Out:
# 352

# %%
candidates - data.groupby(['Candidate', 'Party']).ngroups
# Out:
# 115

# %%
candidates - data.groupby(['Candidate', 'Constituency']).ngroups
# Out:
# 10

# %%
data.groupby(['Candidate', 'Education'])['Total Assets'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                              Education
# Nandan Nilekani                        Graduate Professional    77102957219
# Shamali Das                            8th Pass                 40000120000
# Anil Kumar Sharma                      Doctorate                 8498803720
# Swaran Salaria                         12th Pass                 7308956418
# Jayadev Galla   Winner                 Graduate                  6830581361
# Ayodhya Rami Reddy Alla                Post Graduate             6543381756
# Konda Vishweshwar Reddy   Winner       Post Graduate             5286230210
# Nama Nageswara Rao                     12th Pass                 3382293440
# Naveen Jindal                          Post Graduate             3083154000
# Moni Kumar Subba                       8th Pass                  3067535137
# Malook Nagar                           Graduate                  2896200000
# Gokaraju Ganga Raju   Winner           Graduate                  2883567122
# Vasantha Kumar H.                      Post Graduate             2857786803
# Dr.gaddam Vivekanand                   Graduate Professional     2665292981
# Vakati Narayana Reddy                  Graduate                  2513866365
# Butta Renuka   Winner                  10th Pass                 2426240513
# R. Prabhakara Reddy                    Graduate                  2243612066
# Kamal Nath   Winner                    Graduate                  2069080434
# M. Shahid                              5th Pass                  1989984945
# Patel Praful Manoharbhai               Graduate                  1959685779
# V. Bala Krishnan                       Graduate Professional     1894253519
# Kanwar Singh Tanwar   Winner           5th Pass                  1788430770
# Deol Hema Malini Dharmendra   Winner   Doctorate                 1782015620
# Narendranath Chaganla                  10th Pass                 1764805829
# Devaiah Pagidipati                     Graduate Professional     1669999189
# Name: Total Assets, dtype: int64

# %%
data.groupby(['Candidate', 'Education'])['Liabilities'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                                           Education
# R. Prabhakara Reddy                                 Graduate                 2218003086
# Moni Kumar Subba                                    8th Pass                 1400740132
# Anil Kumar Sharma                                   Doctorate                1095393904
# Vasantha Kumar H.                                   Post Graduate             876085097
# H D Kumara Swamy                                    Graduate                  729603654
# Srinivas Kesineni   Winner                          10th Pass                 715462989
# Nand Gopal Gupta Nandi                              10th Pass                 642055000
# Jain Manish Ishwarlal                               Graduate                  606612400
# Ayodhya Rami Reddy Alla                             Post Graduate             604035456
# Sri Praksh Jha                                      12th Pass                 552293138
# Balashowry Vallabhaneni                             Graduate                  483766785
# Vakati Narayana Reddy                               Graduate                  459322369
# Devaiah Pagidipati                                  Graduate Professional     458302086
# Poonam Mahajan Alias Poonam Vajendla Rao   Winner   Others                    414479088
# Harsimrat Kaur Badal   Winner                       10th Pass                 412634299
# Patil Chandrakant Raghunath   Winner                10th Pass                 405888122
# Shanmugam, A.c.                                     Graduate Professional     344686084
# Munde Gopinathrao Pandurang   Winner                Graduate Professional     335729817
# Butta Renuka   Winner                               10th Pass                 312279927
# Nama Nageswara Rao                                  12th Pass                 269489166
# Jayasankar.c.r                                      Post Graduate             267451000
# P.c. Mohan   Winner                                 12th Pass                 261111285
# Yarram Venkata Subbareddy   Winner                  Post Graduate             240557614
# Deol Hema Malini Dharmendra   Winner                Doctorate                 231234174
# Dr Jyoti Mirdha                                     Graduate Professional     230942000
# Name: Liabilities, dtype: int64

# %%
party_data = data[data["Party"].isin(["AAP","SAD","BSP","BJP","INC","IND","Republican Party of India (A)", "Punjab Lok Congress Party"])]
party_data.reset_index()
party_data
# Out:
#                       Candidate Party  Criminal Cases              Education  \
# 1                 Banka Sahadev   IND               1               Graduate
# 2              Mosali Chinnaiah   IND               0              12th Pass
# 3                        Naresh   INC               0              Doctorate
# 4              Nethawath Ramdas   IND               0             Illiterate
# 5                 Pawar Krishna   IND               1          Post Graduate
# ...                         ...   ...             ...                    ...
# 8478                  J.shantha   BJP               0              12th Pass
# 8479               Y.pampapathi   IND               0              12th Pass
# 8480  B.y.raghavendra   Winner    BJP               2  Graduate Professional
# 8482                K.s.rajanna   IND               0              10th Pass
# 8483         Nandish Kumara K B   IND               0              12th Pass
#
#       Age                                      Constituency  Total Assets  \
# 1      53                              Adilabad + Telangana        393000
# 2      40                              Adilabad + Telangana       3167000
# 3      37                              Adilabad + Telangana       1800000
# 4      44                              Adilabad + Telangana             0
# 5      33                              Adilabad + Telangana             0
# ...   ...                                               ...           ...
# 8478   46  Bellary + Bye Election On 03-11-2018 + Karnataka      49272747
# 8479   60  Bellary + Bye Election On 03-11-2018 + Karnataka       2760000
# 8480   45  Shimoga + Bye Election On 03-11-2018 + Karnataka     588903795
# 8482   59   Mandya + Bye Election On 03-11-2018 + Karnataka      42396540
# 8483   32   Mandya + Bye Election On 03-11-2018 + Karnataka             0
#
#       Liabilities  Year
# 1               0  2014
# 2           40000  2014
# 3               0  2014
# 4               0  2014
# 5               0  2014
# ...           ...   ...
# 8478      1751785  2014
# 8479            0  2014
# 8480     13350647  2014
# 8482      2400000  2014
# 8483            0  2014
#
# [5216 rows x 9 columns]

# %%
party_sorted = party_data[["Party","Candidate"]].groupby(["Party"]).aggregate(lambda x: len(x.unique())).sort_values(["Candidate"], ascending = False )
party_sorted
# Out:
#        Candidate
# Party
# IND         3248
# BSP          498
# INC          484
# BJP          446
# AAP          429
# SAD           10

# %%
party_sorted.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
ed_data = pd.pivot_table(data,values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"]).sort_values(["Candidate"], ascending = False )
ed_data.reset_index()
ed_data.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
ed_party_data = pd.pivot_table(party_data, values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"], columns=["Party"])
ed_party_data.fillna(0)
# Out:
#                       Candidate
# Party                       AAP    BJP   BSP    INC    IND  SAD
# Education
# 10th Pass                  33.0   44.0  79.0   25.0  618.0  3.0
# 12th Pass                  33.0   50.0  78.0   47.0  511.0  1.0
# 5th Pass                    2.0    7.0  20.0    3.0  255.0  0.0
# 8th Pass                    7.0    8.0  43.0    7.0  378.0  1.0
# Doctorate                  25.0   31.0  11.0   34.0   44.0  0.0
# Graduate                   81.0  111.0  83.0  120.0  501.0  2.0
# Graduate Professional      77.0   85.0  58.0   95.0  260.0  1.0
# Illiterate                  0.0    0.0   6.0    0.0   66.0  0.0
# Literate                    1.0    3.0  17.0    2.0  156.0  0.0
# Not Given                   5.0    0.0   0.0    1.0   62.0  0.0
# Others                     16.0    9.0  14.0    6.0   72.0  0.0
# Post Graduate             150.0   99.0  92.0  145.0  392.0  2.0

# %%
criminal_data_asc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=False).head(25)
criminal_data_asc = criminal_data_asc.reset_index(drop=True)
criminal_data_asc
# Out:
#                                             Candidate  \
# 0                                     Udayakumar S.p.
# 1                                       M.pushparayan
# 2                                 Sridip Bhattacharya
# 3                                          Atiq Ahmad
# 4                                    Kameshwar Baitha
# 5                                          Atiq Ahmad
# 6                                        Pawan Pandey
# 7                                        Nepal Mahata
# 8             Rajesh Ranjan Urf Pappu Yadav   Winner
# 9   Shrimant Chh. Udayanraje Pratapsinha Bhonsale ...
# 10                                        Dadan Yadav
# 11                          Amrishbhai Rasiklal Patel
# 12                                Pradeep Kumar Joshi
# 13                  Dr. Ramshankar Katheria   Winner
# 14                                    Muruganantham.m
# 15                                        Arvind Giri
# 16                             Narendra Ambalal Ravat
# 17                            Bhapkar Maruti Sahebrao
# 18                               Jitendra Kumar Singh
# 19                       Vasava Kishorbhai Chhotubhai
# 20                                     Mitrasen Yadav
# 21                   Adhir Ranjan Chowdhury   Winner
# 22                                      Keshwar Yadav
# 23             Gandhi Dilipkumar Mansukhlal   Winner
# 24                                    Narahari Mahato
#
#                                          Constituency             Party  \
# 0                          Kanniyakumari + Tamil Nadu               AAP
# 1                           Thoothukkudi + Tamil Nadu               AAP
# 2                                Howrah + West Bengal            CPI(M)
# 3   Phulpur + Bye Election On 11-03-2018 + Uttar P...               IND
# 4                                 Palamau + Jharkhand              AITC
# 5                           Shrawasti + Uttar Pradesh                SP
# 6                           Sultanpur + Uttar Pradesh               BSP
# 7                               Purulia + West Bengal               INC
# 8                                   Madhepura + Bihar               RJD
# 9                                Satara + Maharashtra               NCP
# 10                                      Buxar + Bihar               BSP
# 11                                Dhule + Maharashtra               INC
# 12                                    Karakat + Bihar  Rashtra Sewa Dal
# 13                               Agra + Uttar Pradesh               BJP
# 14                             Thanjavur + Tamil Nadu               BJP
# 15                              Kheri + Uttar Pradesh               BSP
# 16    Vadodara + Bye Election On 13-09-2014 + Gujarat               INC
# 17                                Maval + Maharashtra               AAP
# 18                           Faizabad + Uttar Pradesh               BSP
# 19                                    Surat + Gujarat             JD(U)
# 20                           Faizabad + Uttar Pradesh                SP
# 21                           Baharampur + West Bengal               INC
# 22                                 Chatra + Jharkhand                SP
# 23                           Ahmednagar + Maharashtra               BJP
# 24                              Purulia + West Bengal              AIFB
#
#                 Education  Criminal Cases
# 0               Doctorate             382
# 1           Post Graduate             380
# 2   Graduate Professional              57
# 3                8th Pass              53
# 4               10th Pass              48
# 5               10th Pass              42
# 6               12th Pass              32
# 7           Post Graduate              25
# 8                Graduate              24
# 9               12th Pass              23
# 10              10th Pass              22
# 11               8th Pass              21
# 12              12th Pass              21
# 13              Doctorate              21
# 14              10th Pass              20
# 15  Graduate Professional              20
# 16  Graduate Professional              19
# 17              12th Pass              18
# 18              12th Pass              17
# 19              10th Pass              17
# 20              12th Pass              16
# 21              10th Pass              16
# 22               5th Pass              16
# 23              10th Pass              16
# 24          Post Graduate              15

# %%
criminal_data_dsc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=True).head(25)
criminal_data_dsc = criminal_data_dsc.reset_index(drop=True)
criminal_data_dsc
# Out:
#                       Candidate           Constituency  \
# 0        Godam Nagesh   Winner    Adilabad + Telangana
# 1           Dr. Rajesh Mahendia        Hisar + Haryana
# 2                  Balwan Singh        Hisar + Haryana
# 3                       Baljeet        Hisar + Haryana
# 4                  Atam Parkash        Hisar + Haryana
# 5                    Arun Kumar        Hisar + Haryana
# 6   Dushyant Chautala   Winner         Hisar + Haryana
# 7                Surender Kumar        Sirsa + Haryana
# 8                 Ranvir Khobra        Sirsa + Haryana
# 9                  Rajbir Palna        Sirsa + Haryana
# 10              Raj Kumar Nagar        Sirsa + Haryana
# 11                 Poonam Chand        Sirsa + Haryana
# 12                   Mewa Singh        Sirsa + Haryana
# 13    Dr. Yudhbir Singh Khyalia        Hisar + Haryana
# 14                Manjeet Singh        Sirsa + Haryana
# 15                Jaipal Bhatti        Sirsa + Haryana
# 16                      Jagdish        Sirsa + Haryana
# 17                Hansraj Hansa        Sirsa + Haryana
# 18                  Fakir Chand        Sirsa + Haryana
# 19            Dr. Sushil Indora        Sirsa + Haryana
# 20            Comrade Ram Kumar        Sirsa + Haryana
# 21                Balwant Singh        Sirsa + Haryana
# 22   Charanjeet Singh   Winner         Sirsa + Haryana
# 23          Satish Kumar Singal  Kurukshetra + Haryana
# 24          Ranbir Singh Sharma  Kurukshetra + Haryana
#
#                        Party              Education  Criminal Cases
# 0                        TRS          Post Graduate               0
# 1                        IND              Doctorate               0
# 2                        IND              12th Pass               0
# 3                        IND               Graduate               0
# 4                        IND          Post Graduate               0
# 5                        IND              12th Pass               0
# 6                       INLD               Graduate               0
# 7                        IND              12th Pass               0
# 8                        IND               Graduate               0
# 9                        IND          Post Graduate               0
# 10                        SP               Graduate               0
# 11                       AAP              12th Pass               0
# 12                       IND               5th Pass               0
# 13                       AAP              Doctorate               0
# 14                       IND               5th Pass               0
# 15                       IND               5th Pass               0
# 16                       IND               Graduate               0
# 17                Jan Morcha              12th Pass               0
# 18                       IND               8th Pass               0
# 19                   HJC(BL)  Graduate Professional               0
# 20                    CPI(M)              12th Pass               0
# 21  Bharatiya Sant Mat Party              10th Pass               0
# 22                      INLD              10th Pass               0
# 23                       IND          Post Graduate               0
# 24                       IND  Graduate Professional               0

# %%
criminal_data_asc.groupby("Party").aggregate(np.sum).sort_values("Criminal Cases",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
asset_data = data[["Candidate","Constituency","Party", "Total Assets"]].sort_values('Total Assets', ascending=False).head(25)
asset_data = asset_data.reset_index(drop=True)
asset_data
# Out:
#                                 Candidate  \
# 0                         Nandan Nilekani
# 1                             Shamali Das
# 2                             Shamali Das
# 3                       Anil Kumar Sharma
# 4                          Swaran Salaria
# 5                 Jayadev Galla   Winner
# 6                 Ayodhya Rami Reddy Alla
# 7       Konda Vishweshwar Reddy   Winner
# 8                      Nama Nageswara Rao
# 9                           Naveen Jindal
# 10                       Moni Kumar Subba
# 11                           Malook Nagar
# 12          Gokaraju Ganga Raju   Winner
# 13                      Vasantha Kumar H.
# 14                   Dr.gaddam Vivekanand
# 15                  Vakati Narayana Reddy
# 16                 Butta Renuka   Winner
# 17                    R. Prabhakara Reddy
# 18                   Kamal Nath   Winner
# 19                              M. Shahid
# 20               Patel Praful Manoharbhai
# 21                       V. Bala Krishnan
# 22          Kanwar Singh Tanwar   Winner
# 23  Deol Hema Malini Dharmendra   Winner
# 24                  Narendranath Chaganla
#
#                                        Constituency  \
# 0                       Bangalore South + Karnataka
# 1                     Kolkata Dakshin + West Bengal
# 2                            Jadavpur + West Bengal
# 3                                 Jahanabad + Bihar
# 4   Gurdaspur + Bye Election On 11-10-2017 + Punjab
# 5                           Guntur + Andhra Pradesh
# 6                     Narasaraopet + Andhra Pradesh
# 7                              Chevella + Telangana
# 8                               Khammam + Telangana
# 9                             Kurukshetra + Haryana
# 10                                   Tezpur + Assam
# 11                           Bijnor + Uttar Pradesh
# 12                      Narsapuram + Andhra Pradesh
# 13                       Kanniyakumari + Tamil Nadu
# 14                           Peddapalle + Telangana
# 15                         Nellore + Andhra Pradesh
# 16                         Kurnool + Andhra Pradesh
# 17                      Bangalore Rural + Karnataka
# 18                      Chhindwara + Madhya Pradesh
# 19                           Meerut + Uttar Pradesh
# 20                   Bhandara Gondiya + Maharashtra
# 21                    Bangalore Central + Karnataka
# 22                           Amroha + Uttar Pradesh
# 23                          Mathura + Uttar Pradesh
# 24                                Medak + Telangana
#
#                                     Party  Total Assets
# 0                                     INC   77102957219
# 1                                     IND   20000060000
# 2                                     IND   20000060000
# 3                                   JD(U)    8498803720
# 4                                     BJP    7308956418
# 5                                     TDP    6830581361
# 6   Yuvajana Sramika Rythu Congress Party    6543381756
# 7                                     TRS    5286230210
# 8                                     TDP    3382293440
# 9                                     INC    3083154000
# 10                                    IND    3067535137
# 11                                    BSP    2896200000
# 12                                    BJP    2883567122
# 13                                    INC    2857786803
# 14                                    INC    2665292981
# 15                                    INC    2513866365
# 16  Yuvajana Sramika Rythu Congress Party    2426240513
# 17                                  JD(S)    2243612066
# 18                                    INC    2069080434
# 19                                    BSP    1989984945
# 20                                    NCP    1959685779
# 21                                    AAP    1894253519
# 22                                    BJP    1788430770
# 23                                    BJP    1782015620
# 24                                    BJP    1764805829

# %%
asset_data.groupby("Party").aggregate(np.sum).sort_values("Total Assets",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>
