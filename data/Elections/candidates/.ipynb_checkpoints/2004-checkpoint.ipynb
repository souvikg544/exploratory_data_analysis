# %% [markdown]
# # EDA : Lok Sabha Candidates, 2004

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate


year = 2004


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate", "Party", "Criminal Cases", "Education", "Age", "Constituency",  "Total Assets", "Liabilities", "Year"]
    data = []
    constituencies = 0
    candidates = 0
    for i in range(1, 545):
        try:
            print("Trying ID", i, end = ' => ')
            url = "https://myneta.info/loksabha" + str(year) + "/index.php?action=show_candidates&constituency_id=" + str(i)
            html = urlopen(url)
            soup = BeautifulSoup(html,'html.parser')
            title = soup.title.text
            title = title.split()
            title = title[4:-3]
            title = " ".join(title)
            title = title.title()
            title = title.split(":")
            constituency = "+".join(title)
            title = ",".join(title)
            print("Saving", title, end = ' => ')
            table = soup.find("table", {"id": "table1"})
            rows = table.find_all('tr')
            total_rows = len(rows)
            for i in range(1, total_rows):
                col_data = []
                cols = rows[i].find_all('td')
                total_cols = len(cols)
                for i in range(0, 5):
                    col_data.append(cols[i].text)
                col_data.append(constituency)
                for i in range(5, total_cols):
                    col_data.append(inr_to_int(cols[i].text))
                col_data.append(2004)
                data.append(col_data)
                candidates += 1
        except :
            print('ERROR')
        else:
            constituencies += 1
            print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', candidates, "candidates from", constituencies, "constituencies")
    df.to_csv(str(year) + '.csv', index=False)
    

main()
# Out:
# Trying ID 1 => Saving Andaman & Nicobar Islands , Andaman & Nicobar Islands => SUCCESS
# Trying ID 2 => Saving Srikakulam , Andhra Pradesh => SUCCESS
# Trying ID 3 => Saving Parvathipuram , Andhra Pradesh => SUCCESS
# Trying ID 4 => Saving Bobbili , Andhra Pradesh => SUCCESS
# Trying ID 5 => Saving Visakhapatnam , Andhra Pradesh => SUCCESS
# Trying ID 6 => Saving Bhadrachalam , Andhra Pradesh => SUCCESS
# Trying ID 7 => Saving Anakapalli , Andhra Pradesh => SUCCESS
# Trying ID 8 => Saving Kakinada , Andhra Pradesh => SUCCESS
# Trying ID 9 => Saving Rajahmundry , Andhra Pradesh => SUCCESS
# Trying ID 10 => Saving Amalapuram , Andhra Pradesh => SUCCESS
# Trying ID 11 => Saving Narasapur , Andhra Pradesh => SUCCESS
# Trying ID 12 => Saving Eluru , Andhra Pradesh => SUCCESS
# Trying ID 13 => Saving Machilipatnam , Andhra Pradesh => SUCCESS
# Trying ID 14 => Saving Vijayawada , Andhra Pradesh => SUCCESS
# Trying ID 15 => Saving Tenali , Andhra Pradesh => SUCCESS
# Trying ID 16 => Saving Guntur , Andhra Pradesh => SUCCESS
# Trying ID 17 => Saving Bapatla , Andhra Pradesh => SUCCESS
# Trying ID 18 => Saving Narasaraopet , Andhra Pradesh => SUCCESS
# Trying ID 19 => Saving Ongole , Andhra Pradesh => SUCCESS
# Trying ID 20 => Saving Nellore , Andhra Pradesh => SUCCESS
# Trying ID 21 => Saving Tirupathi , Andhra Pradesh => SUCCESS
# Trying ID 22 => Saving Chittoor , Andhra Pradesh => SUCCESS
# Trying ID 23 => Saving Rajampet , Andhra Pradesh => SUCCESS
# Trying ID 24 => Saving Cuddapah , Andhra Pradesh => SUCCESS
# Trying ID 25 => Saving Hindupur , Andhra Pradesh => SUCCESS
# Trying ID 26 => Saving Anantapur , Andhra Pradesh => SUCCESS
# Trying ID 27 => Saving Kurnool , Andhra Pradesh => SUCCESS
# Trying ID 28 => Saving Nandyal , Andhra Pradesh => SUCCESS
# Trying ID 29 => Saving Nagarkurnool , Andhra Pradesh => SUCCESS
# Trying ID 30 => Saving Mahabubnagar , Andhra Pradesh => SUCCESS
# Trying ID 31 => Saving Hyderabad , Andhra Pradesh => SUCCESS
# Trying ID 32 => Saving Secunderabad , Andhra Pradesh => SUCCESS
# Trying ID 33 => Saving Siddipet , Andhra Pradesh => SUCCESS
# Trying ID 34 => Saving Medak , Andhra Pradesh => SUCCESS
# Trying ID 35 => Saving Nizamabad , Andhra Pradesh => SUCCESS
# Trying ID 36 => Saving Adilabad , Andhra Pradesh => SUCCESS
# Trying ID 37 => Saving Peddapalli , Andhra Pradesh => SUCCESS
# Trying ID 38 => Saving Karimnagar , Andhra Pradesh => SUCCESS
# Trying ID 39 => Saving Hanamkonda , Andhra Pradesh => SUCCESS
# Trying ID 40 => Saving Warangal , Andhra Pradesh => SUCCESS
# Trying ID 41 => Saving Khammam , Andhra Pradesh => SUCCESS
# Trying ID 42 => Saving Nalgonda , Andhra Pradesh => SUCCESS
# Trying ID 43 => Saving Miryalguda , Andhra Pradesh => SUCCESS
# Trying ID 44 => Saving Arunachal West , Arunachal Pradesh => SUCCESS
# Trying ID 45 => Saving Arunachal East , Arunachal Pradesh => SUCCESS
# Trying ID 46 => Saving Karimganj , Assam => SUCCESS
# Trying ID 47 => Saving Silchar , Assam => SUCCESS
# Trying ID 48 => Saving Autonomous District , Assam => SUCCESS
# Trying ID 49 => Saving Dhubri , Assam => SUCCESS
# Trying ID 50 => Saving Kokrajhar , Assam => SUCCESS
# Trying ID 51 => Saving Barpeta , Assam => SUCCESS
# Trying ID 52 => Saving Gauhati , Assam => SUCCESS
# Trying ID 53 => Saving Mangaldoi , Assam => SUCCESS
# Trying ID 54 => Saving Tezpur , Assam => SUCCESS
# Trying ID 55 => Saving Nowgong , Assam => SUCCESS
# Trying ID 56 => Saving Kaliabor , Assam => SUCCESS
# Trying ID 57 => Saving Jorhat , Assam => SUCCESS
# Trying ID 58 => Saving Dibrugarh , Assam => SUCCESS
# Trying ID 59 => Saving Lakhimpur , Assam => SUCCESS
# Trying ID 60 => Saving Bagaha , Bihar => SUCCESS
# Trying ID 61 => Saving Bettiah , Bihar => SUCCESS
# Trying ID 62 => Saving Motihari , Bihar => SUCCESS
# Trying ID 63 => Saving Gopalganj , Bihar => SUCCESS
# Trying ID 64 => Saving Siwan , Bihar => SUCCESS
# Trying ID 65 => Saving Maharajganj , Bihar => SUCCESS
# Trying ID 66 => Saving Chapra , Bihar => SUCCESS
# Trying ID 67 => Saving Hajipur , Bihar => SUCCESS
# Trying ID 68 => Saving Vaishali , Bihar => SUCCESS
# Trying ID 69 => Saving Muzaffarpur , Bihar => SUCCESS
# Trying ID 70 => Saving Sitamarhi , Bihar => SUCCESS
# Trying ID 71 => Saving Sheohar , Bihar => SUCCESS
# Trying ID 72 => Saving Madhubani , Bihar => SUCCESS
# Trying ID 73 => Saving Jhanjharpur , Bihar => SUCCESS
# Trying ID 74 => Saving Darbhanga , Bihar => SUCCESS
# Trying ID 75 => Saving Rosera , Bihar => SUCCESS
# Trying ID 76 => Saving Samastipur , Bihar => SUCCESS
# Trying ID 77 => Saving Barh , Bihar => SUCCESS
# Trying ID 78 => Saving Balia , Bihar => SUCCESS
# Trying ID 79 => Saving Saharsa , Bihar => SUCCESS
# Trying ID 80 => Saving Madhepura , Bihar => SUCCESS
# Trying ID 81 => Saving Araria , Bihar => SUCCESS
# Trying ID 82 => Saving Kishanganj , Bihar => SUCCESS
# Trying ID 83 => Saving Purnea , Bihar => SUCCESS
# Trying ID 84 => Saving Katihar , Bihar => SUCCESS
# Trying ID 85 => Saving Banka , Bihar => SUCCESS
# Trying ID 86 => Saving Bhagalpur , Bihar => SUCCESS
# Trying ID 87 => Saving Khagaria , Bihar => SUCCESS
# Trying ID 88 => Saving Monghyr , Bihar => SUCCESS
# Trying ID 89 => Saving Begusarai , Bihar => SUCCESS
# Trying ID 90 => Saving Nalanda , Bihar => SUCCESS
# Trying ID 91 => Saving Patna , Bihar => SUCCESS
# Trying ID 92 => Saving Arrah , Bihar => SUCCESS
# Trying ID 93 => Saving Buxar , Bihar => SUCCESS
# Trying ID 94 => Saving Sasaram , Bihar => SUCCESS
# Trying ID 95 => Saving Bikramganj , Bihar => SUCCESS
# Trying ID 96 => Saving Aurangabad , Bihar => SUCCESS
# Trying ID 97 => Saving Jahanabad , Bihar => SUCCESS
# Trying ID 98 => Saving Nawada , Bihar => SUCCESS
# Trying ID 99 => Saving Gaya , Bihar => SUCCESS
# Trying ID 100 => Saving Chandigarh , Chandigarh => SUCCESS
# Trying ID 101 => Saving Surguja , Chhattisgarh => SUCCESS
# Trying ID 102 => Saving Raigarh , Chhattisgarh => SUCCESS
# Trying ID 103 => Saving Janjgir , Chhattisgarh => SUCCESS
# Trying ID 104 => Saving Bilaspur , Chhattisgarh => SUCCESS
# Trying ID 105 => Saving Sarangarh , Chhattisgarh => SUCCESS
# Trying ID 106 => Saving Raipur , Chhattisgarh => SUCCESS
# Trying ID 107 => Saving Mahasamund , Chhattisgarh => SUCCESS
# Trying ID 108 => Saving Kanker , Chhattisgarh => SUCCESS
# Trying ID 109 => Saving Bastar , Chhattisgarh => SUCCESS
# Trying ID 110 => Saving Durg , Chhattisgarh => SUCCESS
# Trying ID 111 => Saving Rajnandgaon , Chhattisgarh => SUCCESS
# Trying ID 112 => Saving Dadra & Nagar Haveli , Dadra & Nagar Haveli => SUCCESS
# Trying ID 113 => Saving Daman And Diu , Daman & Diu => SUCCESS
# Trying ID 114 => Saving Panaji , Goa => SUCCESS
# Trying ID 115 => Saving Mormugao , Goa => SUCCESS
# Trying ID 116 => Saving Kutch , Gujarat => SUCCESS
# Trying ID 117 => Saving Surendranagar , Gujarat => ERROR
# Trying ID 118 => Saving Jamnagar , Gujarat => SUCCESS
# Trying ID 119 => Saving Rajkot , Gujarat => SUCCESS
# Trying ID 120 => Saving Porbandar , Gujarat => SUCCESS
# Trying ID 121 => Saving Junagadh , Gujarat => SUCCESS
# Trying ID 122 => Saving Amreli , Gujarat => SUCCESS
# Trying ID 123 => Saving Bhavnagar , Gujarat => SUCCESS
# Trying ID 124 => Saving Dhandhuka , Gujarat => SUCCESS
# Trying ID 125 => Saving Ahmedabad , Gujarat => SUCCESS
# Trying ID 126 => Saving Gandhinagar , Gujarat => SUCCESS
# Trying ID 127 => Saving Mehsana , Gujarat => SUCCESS
# Trying ID 128 => Saving Patan , Gujarat => SUCCESS
# Trying ID 129 => Saving Banaskantha , Gujarat => SUCCESS
# Trying ID 130 => Saving Sabarkantha , Gujarat => SUCCESS
# Trying ID 131 => Saving Kapadvanj , Gujarat => SUCCESS
# Trying ID 132 => Saving Dohad , Gujarat => SUCCESS
# Trying ID 133 => Saving Godhra , Gujarat => SUCCESS
# Trying ID 134 => Saving Kaira , Gujarat => SUCCESS
# Trying ID 135 => Saving Anand , Gujarat => SUCCESS
# Trying ID 136 => Saving Chhota Udaipur , Gujarat => SUCCESS
# Trying ID 137 => Saving Baroda , Gujarat => ERROR
# Trying ID 138 => Saving Broach , Gujarat => SUCCESS
# Trying ID 139 => Saving Surat , Gujarat => SUCCESS
# Trying ID 140 => Saving Mandvi , Gujarat => SUCCESS
# Trying ID 141 => Saving Bulsar , Gujarat => SUCCESS
# Trying ID 142 => Saving Ambala , Haryana => SUCCESS
# Trying ID 143 => Saving Kurukshetra , Haryana => SUCCESS
# Trying ID 144 => Saving Karnal , Haryana => SUCCESS
# Trying ID 145 => Saving Sonepat , Haryana => SUCCESS
# Trying ID 146 => Saving Rohtak , Haryana => SUCCESS
# Trying ID 147 => Saving Faridabad , Haryana => SUCCESS
# Trying ID 148 => Saving Mahendragarh , Haryana => SUCCESS
# Trying ID 149 => Saving Bhiwani , Haryana => SUCCESS
# Trying ID 150 => Saving Hissar , Haryana => SUCCESS
# Trying ID 151 => Saving Sirsa , Haryana => SUCCESS
# Trying ID 152 => Saving Simla , Himachal Pradesh => SUCCESS
# Trying ID 153 => Saving Mandi , Himachal Pradesh => SUCCESS
# Trying ID 154 => Saving Kangra , Himachal Pradesh => SUCCESS
# Trying ID 155 => Saving Hamirpur , Himachal Pradesh => SUCCESS
# Trying ID 156 => Saving Baramulla , Jammu & Kashmir => SUCCESS
# Trying ID 157 => Saving Srinagar , Jammu & Kashmir => SUCCESS
# Trying ID 158 => Saving Anantnag , Jammu & Kashmir => SUCCESS
# Trying ID 159 => Saving Ladakh , Jammu & Kashmir => SUCCESS
# Trying ID 160 => Saving Udhampur , Jammu & Kashmir => SUCCESS
# Trying ID 161 => Saving Jammu , Jammu & Kashmir => SUCCESS
# Trying ID 162 => Saving Rajmahal , Jharkhand => SUCCESS
# Trying ID 163 => Saving Dumka , Jharkhand => SUCCESS
# Trying ID 164 => Saving Godda , Jharkhand => SUCCESS
# Trying ID 165 => Saving Chatra , Jharkhand => SUCCESS
# Trying ID 166 => Saving Kodarma , Jharkhand => SUCCESS
# Trying ID 167 => Saving Giridih , Jharkhand => SUCCESS
# Trying ID 168 => Saving Dhanbad , Jharkhand => SUCCESS
# Trying ID 169 => Saving Ranchi , Jharkhand => SUCCESS
# Trying ID 170 => Saving Jamshedpur , Jharkhand => SUCCESS
# Trying ID 171 => Saving Singhbhum , Jharkhand => SUCCESS
# Trying ID 172 => Saving Khunti , Jharkhand => SUCCESS
# Trying ID 173 => Saving Lohardaga , Jharkhand => SUCCESS
# Trying ID 174 => Saving Palamau , Jharkhand => SUCCESS
# Trying ID 175 => Saving Hazaribagh , Jharkhand => SUCCESS
# Trying ID 176 => Saving Bidar , Karnataka => SUCCESS
# Trying ID 177 => Saving Gulbarga , Karnataka => SUCCESS
# Trying ID 178 => Saving Raichur , Karnataka => SUCCESS
# Trying ID 179 => Saving Koppal , Karnataka => SUCCESS
# Trying ID 180 => Saving Bellary , Karnataka => SUCCESS
# Trying ID 181 => Saving Davangere , Karnataka => SUCCESS
# Trying ID 182 => Saving Chitradurga , Karnataka => SUCCESS
# Trying ID 183 => Saving Tumkur , Karnataka => SUCCESS
# Trying ID 184 => Saving Chikballapur , Karnataka => SUCCESS
# Trying ID 185 => Saving Kolar , Karnataka => SUCCESS
# Trying ID 186 => Saving Kanakapura , Karnataka => SUCCESS
# Trying ID 187 => Saving Bangalore North , Karnataka => SUCCESS
# Trying ID 188 => Saving Bangalore South , Karnataka => SUCCESS
# Trying ID 189 => Saving Mandya , Karnataka => SUCCESS
# Trying ID 190 => Saving Chamarajanagar , Karnataka => SUCCESS
# Trying ID 191 => Saving Mysore , Karnataka => SUCCESS
# Trying ID 192 => Saving Mangalore , Karnataka => SUCCESS
# Trying ID 193 => Saving Udupi , Karnataka => SUCCESS
# Trying ID 194 => Saving Hassan , Karnataka => SUCCESS
# Trying ID 195 => Saving Chikmagalur , Karnataka => SUCCESS
# Trying ID 196 => Saving Shimoga , Karnataka => SUCCESS
# Trying ID 197 => Saving Kanara , Karnataka => SUCCESS
# Trying ID 198 => Saving Dharwad South , Karnataka => SUCCESS
# Trying ID 199 => Saving Dharwad North , Karnataka => SUCCESS
# Trying ID 200 => Saving Belgaum , Karnataka => SUCCESS
# Trying ID 201 => Saving Chikkodi , Karnataka => SUCCESS
# Trying ID 202 => Saving Bagalkot , Karnataka => SUCCESS
# Trying ID 203 => Saving Bijapur , Karnataka => SUCCESS
# Trying ID 204 => Saving Kasaragod , Kerala => SUCCESS
# Trying ID 205 => Saving Cannanore , Kerala => SUCCESS
# Trying ID 206 => Saving Badagara , Kerala => SUCCESS
# Trying ID 207 => Saving Calicut , Kerala => SUCCESS
# Trying ID 208 => Saving Manjeri , Kerala => SUCCESS
# Trying ID 209 => Saving Ponnani , Kerala => SUCCESS
# Trying ID 210 => Saving Palghat , Kerala => SUCCESS
# Trying ID 211 => Saving Ottapalam , Kerala => SUCCESS
# Trying ID 212 => Saving Trichur , Kerala => SUCCESS
# Trying ID 213 => Saving Mukundapuram , Kerala => SUCCESS
# Trying ID 214 => Saving Ernakulam , Kerala => SUCCESS
# Trying ID 215 => Saving Muvattupuzha , Kerala => SUCCESS
# Trying ID 216 => Saving Kottayam , Kerala => SUCCESS
# Trying ID 217 => Saving Idukki , Kerala => SUCCESS
# Trying ID 218 => Saving Alleppey , Kerala => SUCCESS
# Trying ID 219 => Saving Mavelikara , Kerala => SUCCESS
# Trying ID 220 => Saving Adoor , Kerala => SUCCESS
# Trying ID 221 => Saving Quilon , Kerala => SUCCESS
# Trying ID 222 => Saving Chirayinkil , Kerala => SUCCESS
# Trying ID 223 => Saving Trivandrum , Kerala => SUCCESS
# Trying ID 224 => Saving Lakshadweep , Lakshadweep => SUCCESS
# Trying ID 225 => Saving Morena , Madhya Pradesh => SUCCESS
# Trying ID 226 => Saving Bhind , Madhya Pradesh => SUCCESS
# Trying ID 227 => Saving Gwalior , Madhya Pradesh => SUCCESS
# Trying ID 228 => Saving Guna , Madhya Pradesh => SUCCESS
# Trying ID 229 => Saving Sagar , Madhya Pradesh => SUCCESS
# Trying ID 230 => Saving Khajuraho , Madhya Pradesh => SUCCESS
# Trying ID 231 => Saving Damoh , Madhya Pradesh => SUCCESS
# Trying ID 232 => Saving Satna , Madhya Pradesh => SUCCESS
# Trying ID 233 => Saving Rewa , Madhya Pradesh => SUCCESS
# Trying ID 234 => Saving Sidhi , Madhya Pradesh => SUCCESS
# Trying ID 235 => Saving Shahdol , Madhya Pradesh => SUCCESS
# Trying ID 236 => Saving Balaghat , Madhya Pradesh => SUCCESS
# Trying ID 237 => Saving Mandla , Madhya Pradesh => SUCCESS
# Trying ID 238 => Saving Jabalpur , Madhya Pradesh => SUCCESS
# Trying ID 239 => Saving Seoni , Madhya Pradesh => SUCCESS
# Trying ID 240 => Saving Chhindwara , Madhya Pradesh => SUCCESS
# Trying ID 241 => Saving Betul , Madhya Pradesh => SUCCESS
# Trying ID 242 => Saving Hoshangabad , Madhya Pradesh => SUCCESS
# Trying ID 243 => Saving Bhopal , Madhya Pradesh => SUCCESS
# Trying ID 244 => Saving Vidisha , Madhya Pradesh => SUCCESS
# Trying ID 245 => Saving Rajgarh , Madhya Pradesh => SUCCESS
# Trying ID 246 => Saving Shajapur , Madhya Pradesh => SUCCESS
# Trying ID 247 => Saving Khandwa , Madhya Pradesh => SUCCESS
# Trying ID 248 => Saving Khargone , Madhya Pradesh => SUCCESS
# Trying ID 249 => Saving Dhar , Madhya Pradesh => SUCCESS
# Trying ID 250 => Saving Indore , Madhya Pradesh => SUCCESS
# Trying ID 251 => Saving Ujjain , Madhya Pradesh => SUCCESS
# Trying ID 252 => Saving Jhabua , Madhya Pradesh => SUCCESS
# Trying ID 253 => Saving Mandsaur , Madhya Pradesh => SUCCESS
# Trying ID 254 => Saving Rajapur , Maharashtra => SUCCESS
# Trying ID 255 => Saving Ratnagiri , Maharashtra => SUCCESS
# Trying ID 256 => Saving Kolaba , Maharashtra => SUCCESS
# Trying ID 257 => Saving Mumbai South , Maharashtra => SUCCESS
# Trying ID 258 => Saving Mumbai South Central , Maharashtra => SUCCESS
# Trying ID 259 => Saving Mumbai North Central , Maharashtra => SUCCESS
# Trying ID 260 => Saving Mumbai North East , Maharashtra => SUCCESS
# Trying ID 261 => Saving Mumbai North West , Maharashtra => SUCCESS
# Trying ID 262 => Saving Mumbai North , Maharashtra => SUCCESS
# Trying ID 263 => Saving Thane , Maharashtra => SUCCESS
# Trying ID 264 => Saving Dahanu , Maharashtra => SUCCESS
# Trying ID 265 => Saving Nashik , Maharashtra => SUCCESS
# Trying ID 266 => Saving Malegaon , Maharashtra => SUCCESS
# Trying ID 267 => Saving Dhule , Maharashtra => SUCCESS
# Trying ID 268 => Saving Nandurbar , Maharashtra => SUCCESS
# Trying ID 269 => Saving Erandol , Maharashtra => SUCCESS
# Trying ID 270 => Saving Jalgaon , Maharashtra => SUCCESS
# Trying ID 271 => Saving Buldhana , Maharashtra => SUCCESS
# Trying ID 272 => Saving Akola , Maharashtra => SUCCESS
# Trying ID 273 => Saving Washim , Maharashtra => SUCCESS
# Trying ID 274 => Saving Amravati , Maharashtra => SUCCESS
# Trying ID 275 => Saving Ramtek , Maharashtra => SUCCESS
# Trying ID 276 => Saving Nagpur , Maharashtra => SUCCESS
# Trying ID 277 => Saving Bhandara , Maharashtra => SUCCESS
# Trying ID 278 => Saving Chimur , Maharashtra => SUCCESS
# Trying ID 279 => Saving Chandrapur , Maharashtra => SUCCESS
# Trying ID 280 => Saving Wardha , Maharashtra => SUCCESS
# Trying ID 281 => Saving Yavatmal , Maharashtra => SUCCESS
# Trying ID 282 => Saving Hingoli , Maharashtra => SUCCESS
# Trying ID 283 => Saving Nanded , Maharashtra => SUCCESS
# Trying ID 284 => Saving Parbhani , Maharashtra => SUCCESS
# Trying ID 285 => Saving Jalna , Maharashtra => SUCCESS
# Trying ID 286 => Saving Aurangabad , Maharashtra => SUCCESS
# Trying ID 287 => Saving Beed , Maharashtra => SUCCESS
# Trying ID 288 => Saving Latur , Maharashtra => SUCCESS
# Trying ID 289 => Saving Osmanabad , Maharashtra => SUCCESS
# Trying ID 290 => Saving Sholapur , Maharashtra => SUCCESS
# Trying ID 291 => Saving Pandharpur , Maharashtra => SUCCESS
# Trying ID 292 => Saving Ahmednagar , Maharashtra => SUCCESS
# Trying ID 293 => Saving Kopargaon , Maharashtra => SUCCESS
# Trying ID 294 => Saving Khed , Maharashtra => SUCCESS
# Trying ID 295 => Saving Pune , Maharashtra => SUCCESS
# Trying ID 296 => Saving Baramati , Maharashtra => SUCCESS
# Trying ID 297 => Saving Satara , Maharashtra => SUCCESS
# Trying ID 298 => Saving Karad , Maharashtra => SUCCESS
# Trying ID 299 => Saving Sangli , Maharashtra => SUCCESS
# Trying ID 300 => Saving Ichalkaranji , Maharashtra => SUCCESS
# Trying ID 301 => Saving Kolhapur , Maharashtra => SUCCESS
# Trying ID 302 => Saving Inner Manipur , Manipur => SUCCESS
# Trying ID 303 => Saving Outer Manipur , Manipur => SUCCESS
# Trying ID 304 => Saving Shillong , Meghalaya => SUCCESS
# Trying ID 305 => Saving Tura , Meghalaya => SUCCESS
# Trying ID 306 => Saving Mizoram , Mizoram => SUCCESS
# Trying ID 307 => Saving Nagaland , Nagaland => SUCCESS
# Trying ID 308 => Saving New Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 309 => Saving South Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 310 => Saving Outer Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 311 => Saving East Delhi , National Capital Territory Of Delhi => SUCCESS
# Trying ID 312 => Saving Chandni Chowk , National Capital Territory Of Delhi => SUCCESS
# Trying ID 313 => Saving Delhi Sadar , National Capital Territory Of Delhi => SUCCESS
# Trying ID 314 => Saving Karol Bagh , National Capital Territory Of Delhi => SUCCESS
# Trying ID 315 => Saving Mayurbhanj , Orissa => SUCCESS
# Trying ID 316 => Saving Balasore , Orissa => SUCCESS
# Trying ID 317 => Saving Bhadrak , Orissa => SUCCESS
# Trying ID 318 => Saving Jajpur , Orissa => SUCCESS
# Trying ID 319 => Saving Kendrapara , Orissa => SUCCESS
# Trying ID 320 => Saving Cuttack , Orissa => SUCCESS
# Trying ID 321 => Saving Jagatsinghpur , Orissa => SUCCESS
# Trying ID 322 => Saving Puri , Orissa => SUCCESS
# Trying ID 323 => Saving Bhubaneswar , Orissa => SUCCESS
# Trying ID 324 => Saving Aska , Orissa => SUCCESS
# Trying ID 325 => Saving Berhampur , Orissa => SUCCESS
# Trying ID 326 => Saving Koraput , Orissa => SUCCESS
# Trying ID 327 => Saving Nowrangpur , Orissa => SUCCESS
# Trying ID 328 => Saving Kalahandi , Orissa => SUCCESS
# Trying ID 329 => Saving Phulbani , Orissa => SUCCESS
# Trying ID 330 => Saving Bolangir , Orissa => SUCCESS
# Trying ID 331 => Saving Sambalpur , Orissa => SUCCESS
# Trying ID 332 => Saving Deogarh , Orissa => SUCCESS
# Trying ID 333 => Saving Dhenkanal , Orissa => SUCCESS
# Trying ID 334 => Saving Sundargarh , Orissa => SUCCESS
# Trying ID 335 => Saving Keonjhar , Orissa => SUCCESS
# Trying ID 336 => Saving Pondicherry , Pondicherry => SUCCESS
# Trying ID 337 => Saving Gurdaspur , Punjab => SUCCESS
# Trying ID 338 => Saving Amritsar , Punjab => SUCCESS
# Trying ID 339 => Saving Tarn Taran , Punjab => SUCCESS
# Trying ID 340 => Saving Jullundur , Punjab => SUCCESS
# Trying ID 341 => Saving Phillaur , Punjab => SUCCESS
# Trying ID 342 => Saving Hoshiarpur , Punjab => SUCCESS
# Trying ID 343 => Saving Ropar , Punjab => SUCCESS
# Trying ID 344 => Saving Patiala , Punjab => SUCCESS
# Trying ID 345 => Saving Ludhiana , Punjab => SUCCESS
# Trying ID 346 => Saving Sangrur , Punjab => SUCCESS
# Trying ID 347 => Saving Bhatinda , Punjab => SUCCESS
# Trying ID 348 => Saving Faridkot , Punjab => SUCCESS
# Trying ID 349 => Saving Ferozepur , Punjab => SUCCESS
# Trying ID 350 => Saving Ganganagar , Rajasthan => SUCCESS
# Trying ID 351 => Saving Bikaner , Rajasthan => SUCCESS
# Trying ID 352 => Saving Churu , Rajasthan => SUCCESS
# Trying ID 353 => Saving Jhunjhunu , Rajasthan => SUCCESS
# Trying ID 354 => Saving Sikar , Rajasthan => SUCCESS
# Trying ID 355 => Saving Jaipur , Rajasthan => SUCCESS
# Trying ID 356 => Saving Dausa , Rajasthan => SUCCESS
# Trying ID 357 => Saving Alwar , Rajasthan => SUCCESS
# Trying ID 358 => Saving Bharatpur , Rajasthan => SUCCESS
# Trying ID 359 => Saving Bayana , Rajasthan => SUCCESS
# Trying ID 360 => Saving Sawai Madhopur , Rajasthan => SUCCESS
# Trying ID 361 => Saving Ajmer , Rajasthan => SUCCESS
# Trying ID 362 => Saving Tonk , Rajasthan => SUCCESS
# Trying ID 363 => Saving Kota , Rajasthan => SUCCESS
# Trying ID 364 => Saving Jhalawar , Rajasthan => SUCCESS
# Trying ID 365 => Saving Banswara , Rajasthan => SUCCESS
# Trying ID 366 => Saving Salumber , Rajasthan => SUCCESS
# Trying ID 367 => Saving Udaipur , Rajasthan => SUCCESS
# Trying ID 368 => Saving Chittorgarh , Rajasthan => SUCCESS
# Trying ID 369 => Saving Bhilwara , Rajasthan => SUCCESS
# Trying ID 370 => Saving Pali , Rajasthan => SUCCESS
# Trying ID 371 => Saving Jalore , Rajasthan => SUCCESS
# Trying ID 372 => Saving Barmer , Rajasthan => SUCCESS
# Trying ID 373 => Saving Jodhpur , Rajasthan => SUCCESS
# Trying ID 374 => Saving Nagaur , Rajasthan => SUCCESS
# Trying ID 375 => Saving Sikkim , Sikkim => SUCCESS
# Trying ID 376 => Saving Madras North , Tamil Nadu => SUCCESS
# Trying ID 377 => Saving Madras Central , Tamil Nadu => SUCCESS
# Trying ID 378 => Saving Madras South , Tamil Nadu => SUCCESS
# Trying ID 379 => Saving Sriperumbudur , Tamil Nadu => SUCCESS
# Trying ID 380 => Saving Chengalpattu , Tamil Nadu => SUCCESS
# Trying ID 381 => Saving Arakkonam , Tamil Nadu => SUCCESS
# Trying ID 382 => Saving Vellore , Tamil Nadu => SUCCESS
# Trying ID 383 => Saving Tiruppattur , Tamil Nadu => SUCCESS
# Trying ID 384 => Saving Vandavasi , Tamil Nadu => ERROR
# Trying ID 385 => Saving Tindivanam , Tamil Nadu => SUCCESS
# Trying ID 386 => Saving Cuddalore , Tamil Nadu => SUCCESS
# Trying ID 387 => Saving Chidambaram , Tamil Nadu => SUCCESS
# Trying ID 388 => Saving Dharmapuri , Tamil Nadu => SUCCESS
# Trying ID 389 => Saving Krishnagiri , Tamil Nadu => SUCCESS
# Trying ID 390 => Saving Rasipuram , Tamil Nadu => SUCCESS
# Trying ID 391 => Saving Salem , Tamil Nadu => SUCCESS
# Trying ID 392 => Saving Tiruchengode , Tamil Nadu => SUCCESS
# Trying ID 393 => Saving Nilgiris , Tamil Nadu => SUCCESS
# Trying ID 394 => Saving Gobichettipalayam , Tamil Nadu => SUCCESS
# Trying ID 395 => Saving Coimbatore , Tamil Nadu => SUCCESS
# Trying ID 396 => Saving Pollachi , Tamil Nadu => SUCCESS
# Trying ID 397 => Saving Palani , Tamil Nadu => ERROR
# Trying ID 398 => Saving Dindigul , Tamil Nadu => SUCCESS
# Trying ID 399 => Saving Madurai , Tamil Nadu => SUCCESS
# Trying ID 400 => Saving Periyakulam , Tamil Nadu => SUCCESS
# Trying ID 401 => Saving Karur , Tamil Nadu => SUCCESS
# Trying ID 402 => Saving Tiruchirappalli , Tamil Nadu => SUCCESS
# Trying ID 403 => Saving Perambalur , Tamil Nadu => SUCCESS
# Trying ID 404 => Saving Mayiladuturai , Tamil Nadu => SUCCESS
# Trying ID 405 => Saving Nagapattinam , Tamil Nadu => SUCCESS
# Trying ID 406 => Saving Thanjavur , Tamil Nadu => SUCCESS
# Trying ID 407 => Saving Pudukkottai , Tamil Nadu => SUCCESS
# Trying ID 408 => Saving Sivaganga , Tamil Nadu => SUCCESS
# Trying ID 409 => Saving Ramanathapuram , Tamil Nadu => SUCCESS
# Trying ID 410 => Saving Sivakasi , Tamil Nadu => SUCCESS
# Trying ID 411 => Saving Tirunelveli , Tamil Nadu => SUCCESS
# Trying ID 412 => Saving Tenkasi , Tamil Nadu => SUCCESS
# Trying ID 413 => Saving Tiruchendur , Tamil Nadu => ERROR
# Trying ID 414 => Saving Nagercoil , Tamil Nadu => SUCCESS
# Trying ID 415 => Saving Tripura West , Tripura => SUCCESS
# Trying ID 416 => Saving Tripura East , Tripura => SUCCESS
# Trying ID 417 => Saving Bijnor , Uttar Pradesh => SUCCESS
# Trying ID 418 => Saving Amroha , Uttar Pradesh => SUCCESS
# Trying ID 419 => Saving Moradabad , Uttar Pradesh => SUCCESS
# Trying ID 420 => Saving Rampur , Uttar Pradesh => SUCCESS
# Trying ID 421 => Saving Sambhal , Uttar Pradesh => SUCCESS
# Trying ID 422 => Saving Budaun , Uttar Pradesh => SUCCESS
# Trying ID 423 => Saving Aonla , Uttar Pradesh => SUCCESS
# Trying ID 424 => Saving Bareilly , Uttar Pradesh => SUCCESS
# Trying ID 425 => Saving Pilibhit , Uttar Pradesh => SUCCESS
# Trying ID 426 => Saving Shahjahanpur , Uttar Pradesh => SUCCESS
# Trying ID 427 => Saving Kheri , Uttar Pradesh => SUCCESS
# Trying ID 428 => Saving Shahabad , Uttar Pradesh => SUCCESS
# Trying ID 429 => Saving Sitapur , Uttar Pradesh => SUCCESS
# Trying ID 430 => Saving Misrikh , Uttar Pradesh => SUCCESS
# Trying ID 431 => Saving Hardoi , Uttar Pradesh => SUCCESS
# Trying ID 432 => Saving Lucknow , Uttar Pradesh => SUCCESS
# Trying ID 433 => Saving Mohanlalganj , Uttar Pradesh => SUCCESS
# Trying ID 434 => Saving Unnao , Uttar Pradesh => SUCCESS
# Trying ID 435 => Saving Rae Bareli , Uttar Pradesh => SUCCESS
# Trying ID 436 => Saving Pratapgarh , Uttar Pradesh => SUCCESS
# Trying ID 437 => Saving Amethi , Uttar Pradesh => SUCCESS
# Trying ID 438 => Saving Sultanpur , Uttar Pradesh => SUCCESS
# Trying ID 439 => Saving Akbarpur , Uttar Pradesh => SUCCESS
# Trying ID 440 => Saving Faizabad , Uttar Pradesh => SUCCESS
# Trying ID 441 => Saving Bara Banki , Uttar Pradesh => SUCCESS
# Trying ID 442 => Saving Kaiserganj , Uttar Pradesh => SUCCESS
# Trying ID 443 => Saving Bahraich , Uttar Pradesh => SUCCESS
# Trying ID 444 => Saving Balrampur , Uttar Pradesh => SUCCESS
# Trying ID 445 => Saving Gonda , Uttar Pradesh => SUCCESS
# Trying ID 446 => Saving Basti , Uttar Pradesh => SUCCESS
# Trying ID 447 => Saving Domariaganj , Uttar Pradesh => SUCCESS
# Trying ID 448 => Saving Khalilabad , Uttar Pradesh => SUCCESS
# Trying ID 449 => Saving Bansgaon , Uttar Pradesh => SUCCESS
# Trying ID 450 => Saving Gorakhpur , Uttar Pradesh => SUCCESS
# Trying ID 451 => Saving Maharajganj , Uttar Pradesh => SUCCESS
# Trying ID 452 => Saving Padrauna , Uttar Pradesh => SUCCESS
# Trying ID 453 => Saving Deoria , Uttar Pradesh => SUCCESS
# Trying ID 454 => Saving Salempur , Uttar Pradesh => SUCCESS
# Trying ID 455 => Saving Ballia , Uttar Pradesh => SUCCESS
# Trying ID 456 => Saving Ghosi , Uttar Pradesh => SUCCESS
# Trying ID 457 => Saving Azamgarh , Uttar Pradesh => SUCCESS
# Trying ID 458 => Saving Lalganj , Uttar Pradesh => SUCCESS
# Trying ID 459 => Saving Machhlishahr , Uttar Pradesh => SUCCESS
# Trying ID 460 => Saving Jaunpur , Uttar Pradesh => SUCCESS
# Trying ID 461 => Saving Saidpur , Uttar Pradesh => SUCCESS
# Trying ID 462 => Saving Ghazipur , Uttar Pradesh => SUCCESS
# Trying ID 463 => Saving Chandauli , Uttar Pradesh => SUCCESS
# Trying ID 464 => Saving Varanasi , Uttar Pradesh => SUCCESS
# Trying ID 465 => Saving Robertsganj , Uttar Pradesh => SUCCESS
# Trying ID 466 => Saving Mirzapur , Uttar Pradesh => SUCCESS
# Trying ID 467 => Saving Phulpur , Uttar Pradesh => SUCCESS
# Trying ID 468 => Saving Allahabad , Uttar Pradesh => SUCCESS
# Trying ID 469 => Saving Chail , Uttar Pradesh => SUCCESS
# Trying ID 470 => Saving Fatehpur , Uttar Pradesh => SUCCESS
# Trying ID 471 => Saving Banda , Uttar Pradesh => SUCCESS
# Trying ID 472 => Saving Hamirpur , Uttar Pradesh => SUCCESS
# Trying ID 473 => Saving Jhansi , Uttar Pradesh => SUCCESS
# Trying ID 474 => Saving Jalaun , Uttar Pradesh => SUCCESS
# Trying ID 475 => Saving Ghatampur , Uttar Pradesh => SUCCESS
# Trying ID 476 => Saving Bilhaur , Uttar Pradesh => SUCCESS
# Trying ID 477 => Saving Kanpur , Uttar Pradesh => SUCCESS
# Trying ID 478 => Saving Etawah , Uttar Pradesh => SUCCESS
# Trying ID 479 => Saving Kannauj , Uttar Pradesh => SUCCESS
# Trying ID 480 => Saving Farrukhabad , Uttar Pradesh => SUCCESS
# Trying ID 481 => Saving Mainpuri , Uttar Pradesh => SUCCESS
# Trying ID 482 => Saving Jalesar , Uttar Pradesh => SUCCESS
# Trying ID 483 => Saving Etah , Uttar Pradesh => SUCCESS
# Trying ID 484 => Saving Firozabad , Uttar Pradesh => SUCCESS
# Trying ID 485 => Saving Agra , Uttar Pradesh => SUCCESS
# Trying ID 486 => Saving Mathura , Uttar Pradesh => SUCCESS
# Trying ID 487 => Saving Hathras , Uttar Pradesh => SUCCESS
# Trying ID 488 => Saving Aligarh , Uttar Pradesh => SUCCESS
# Trying ID 489 => Saving Khurja , Uttar Pradesh => SUCCESS
# Trying ID 490 => Saving Bulandshahr , Uttar Pradesh => SUCCESS
# Trying ID 491 => Saving Hapur , Uttar Pradesh => SUCCESS
# Trying ID 492 => Saving Meerut , Uttar Pradesh => SUCCESS
# Trying ID 493 => Saving Baghpat , Uttar Pradesh => SUCCESS
# Trying ID 494 => Saving Muzaffarnagar , Uttar Pradesh => SUCCESS
# Trying ID 495 => Saving Kairana , Uttar Pradesh => SUCCESS
# Trying ID 496 => Saving Saharanpur , Uttar Pradesh => SUCCESS
# Trying ID 497 => Saving Tehri Garhwal , Uttaranchal => SUCCESS
# Trying ID 498 => Saving Garhwal , Uttaranchal => SUCCESS
# Trying ID 499 => Saving Almora , Uttaranchal => SUCCESS
# Trying ID 500 => Saving Nainital , Uttaranchal => SUCCESS
# Trying ID 501 => Saving Hardwar , Uttaranchal => SUCCESS
# Trying ID 502 => Saving Cooch Behar , West Bengal => SUCCESS
# Trying ID 503 => Saving Alipurduars , West Bengal => SUCCESS
# Trying ID 504 => Saving Jalpaiguri , West Bengal => SUCCESS
# Trying ID 505 => Saving Darjeeling , West Bengal => SUCCESS
# Trying ID 506 => Saving Raiganj , West Bengal => SUCCESS
# Trying ID 507 => Saving Balurghat , West Bengal => SUCCESS
# Trying ID 508 => Saving Malda , West Bengal => SUCCESS
# Trying ID 509 => Saving Jangipur , West Bengal => SUCCESS
# Trying ID 510 => Saving Murshidabad , West Bengal => ERROR
# Trying ID 511 => Saving Berhampore , West Bengal => SUCCESS
# Trying ID 512 => Saving Krishnagar , West Bengal => SUCCESS
# Trying ID 513 => Saving Nabadwip , West Bengal => SUCCESS
# Trying ID 514 => Saving Barasat , West Bengal => SUCCESS
# Trying ID 515 => Saving Basirhat , West Bengal => SUCCESS
# Trying ID 516 => Saving Joynagar , West Bengal => SUCCESS
# Trying ID 517 => Saving Mathurapur , West Bengal => SUCCESS
# Trying ID 518 => Saving Diamond Harbour , West Bengal => SUCCESS
# Trying ID 519 => Saving Jadavpur , West Bengal => SUCCESS
# Trying ID 520 => Saving Barrackpore , West Bengal => SUCCESS
# Trying ID 521 => Saving Dum Dum , West Bengal => SUCCESS
# Trying ID 522 => Saving Calcutta North West , West Bengal => SUCCESS
# Trying ID 523 => Saving Calcutta North East , West Bengal => SUCCESS
# Trying ID 524 => Saving Calcutta South , West Bengal => SUCCESS
# Trying ID 525 => Saving Howrah , West Bengal => SUCCESS
# Trying ID 526 => Saving Uluberia , West Bengal => SUCCESS
# Trying ID 527 => Saving Serampore , West Bengal => SUCCESS
# Trying ID 528 => Saving Hooghly , West Bengal => SUCCESS
# Trying ID 529 => Saving Arambagh , West Bengal => SUCCESS
# Trying ID 530 => Saving Panskura , West Bengal => SUCCESS
# Trying ID 531 => Saving Tamluk , West Bengal => SUCCESS
# Trying ID 532 => Saving Contai , West Bengal => SUCCESS
# Trying ID 533 => Saving Midnapore , West Bengal => SUCCESS
# Trying ID 534 => Saving Jhargram , West Bengal => SUCCESS
# Trying ID 535 => Saving Purulia , West Bengal => SUCCESS
# Trying ID 536 => Saving Bankura , West Bengal => SUCCESS
# Trying ID 537 => Saving Vishnupur , West Bengal => SUCCESS
# Trying ID 538 => Saving Durgapur , West Bengal => SUCCESS
# Trying ID 539 => Saving Asansol , West Bengal => SUCCESS
# Trying ID 540 => Saving Burdwan , West Bengal => SUCCESS
# Trying ID 541 => Saving Katwa , West Bengal => SUCCESS
# Trying ID 542 => Saving Bolpur , West Bengal => SUCCESS
# Trying ID 543 => Saving Birbhum , West Bengal => SUCCESS
# Trying ID 544 => Saving  => ERROR
# Saved => 3642 candidates from 537 constituencies

# %% [markdown]
# ## Visualizing data

# %%
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

matplotlib.rc('figure', figsize=(10, 5))
matplotlib.rc('font', weight='bold', size=12)

# %%
data = pd.read_csv('2004.csv')
data
# Out:
#                         Candidate  Party  Criminal Cases      Education  Age  \
# 0     MANORANJAN BHAKTA   Winner     INC               0  Post Graduate   65
# 1                      A K BISWAS    BSP               0       Graduate   61
# 2                ASIT BARAN DUTTA    IND               0       Graduate   50
# 3                 BISHNU PADA RAY    BJP               0       Graduate   54
# 4                   DEEPAK BISWAS    IND               0      Not Given   28
# ...                           ...    ...             ...            ...  ...
# 3637                   Arjun Saha    BJP               0       Graduate   35
# 3638              Braja Mohon Das    IND               0         Others   62
# 3639                Chinta Sarkar  JD(S)               0      12th Pass   30
# 3640            Gopal Chandra Das    INC               0  Post Graduate   35
# 3641           Kartik Chandra Das    BSP               0       Graduate   51
#
#                                            Constituency  Total Assets  \
# 0     Andaman & Nicobar Islands + Andaman & Nicobar ...       5926740
# 1     Andaman & Nicobar Islands + Andaman & Nicobar ...       7876500
# 2     Andaman & Nicobar Islands + Andaman & Nicobar ...       3070000
# 3     Andaman & Nicobar Islands + Andaman & Nicobar ...       1250619
# 4     Andaman & Nicobar Islands + Andaman & Nicobar ...          3000
# ...                                                 ...           ...
# 3637                              Birbhum + West Bengal        515000
# 3638                              Birbhum + West Bengal        357360
# 3639                              Birbhum + West Bengal         29000
# 3640                              Birbhum + West Bengal        119000
# 3641                              Birbhum + West Bengal       3314000
#
#       Liabilities  Year
# 0          272061  2004
# 1           65000  2004
# 2               0  2004
# 3          128710  2004
# 4               0  2004
# ...           ...   ...
# 3637            0  2004
# 3638        20000  2004
# 3639            0  2004
# 3640            0  2004
# 3641            0  2004
#
# [3642 rows x 9 columns]

# %%
data.describe()
# Out:
#        Criminal Cases          Age  Total Assets   Liabilities    Year
# count     3642.000000  3642.000000  3.642000e+03  3.642000e+03  3642.0
# mean         0.373421    46.130972  1.146401e+07  6.454531e+05  2004.0
# std          1.809383    13.708530  2.561430e+08  1.146954e+07     0.0
# min          0.000000     0.000000  0.000000e+00  0.000000e+00  2004.0
# 25%          0.000000    37.000000  1.125120e+05  0.000000e+00  2004.0
# 50%          0.000000    46.000000  8.450750e+05  0.000000e+00  2004.0
# 75%          0.000000    55.750000  4.033326e+06  9.000000e+04  2004.0
# max         36.000000    94.000000  1.522455e+10  6.333000e+08  2004.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       3642 non-null   object
#  1   Party           3642 non-null   object
#  2   Criminal Cases  3642 non-null   int64
#  3   Education       3642 non-null   object
#  4   Age             3642 non-null   int64
#  5   Constituency    3642 non-null   object
#  6   Total Assets    3642 non-null   int64
#  7   Liabilities     3642 non-null   int64
#  8   Year            3642 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 256.2+ KB

# %%
# Total number of Parties
np.size(data["Party"].unique()) - 1
# Reducing by one for independent candidates
# Out:
# 188

# %%
candidates = np.size(data["Candidate"])
candidates
# Out:
# 3642

# %%
candidates - np.size(data["Candidate"].unique())
# Out:
# 70

# %%
candidates - data.groupby(['Candidate', 'Party']).ngroups
# Out:
# 22

# %%
candidates - data.groupby(['Candidate', 'Constituency']).ngroups
# Out:
# 2

# %%
data.groupby(['Candidate', 'Education'])['Total Assets'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                                               Education
# SRIKANTADATTA NARASIMHARAJA WADIYAR                     Post Graduate            15224553998
# ALIM                                                    5th Pass                  2000080500
# MALOOK NAGAR                                            Graduate                   762437000
# D.K. AUDIKESAVULU   Winner                              Not Given                  670576468
# VED PRAKASH                                             12th Pass                  616557379
# PALANISAMY, K. C.   Winner                              5th Pass                   546569007
# PRENEET KAUR   Winner                                   Graduate                   412867297
# V.M SINGH                                               Graduate                   407555000
# MANABENDRA SHAH   Winner                                12th Pass                  347563683
# VISHWANATH DUBEY                                        Post Graduate              277530906
# DHARMENDRA   Winner                                     12th Pass                  230326000
# PRATIBHA SINGH   Winner                                 Graduate                   230288018
# KRISHNAPPA M                                            Graduate                   228924447
# KISHORE CHANDRA SURYANARAYANA DEO VYRICHERLA   Winner   Post Graduate              220678000
# MALLIKARJUN S S                                         Graduate                   210693494
# PINAKI MISRA                                            Graduate Professional      207245000
# RANA GURJEET SINGH   Winner                             10th Pass                  205828008
# SUNIL DUTT   Winner                                     Graduate                   204321510
# NARESH GUJRAL                                           Graduate Professional      192876742
# N A MOHAMMED                                            10th Pass                  188527614
# MONI KUMAR SUBBA   Winner                               8th Pass                   186443565
# CHIDAMBARAM, P.   Winner                                Post Graduate              179861587
# PRAVEEN SINGH ARON                                      Graduate Professional      177736104
# MADDI LAKSHMAIAH                                        Others                     169062689
# KAPIL SIBAL   Winner                                    Post Graduate              158850000
# Name: Total Assets, dtype: int64

# %%
data.groupby(['Candidate', 'Education'])['Liabilities'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                             Education
# ARUN KUMAR                            Graduate Professional    633300000
# VED PRAKASH                           12th Pass                238262560
# SAIDUZZAMAN                           Post Graduate             75683504
# PALANISAMY, K. C.   Winner            5th Pass                  63920476
# LALU PRASAD   Winner                  Graduate Professional     44082800
# SHIV KHERA                            Graduate                  34825000
# PRALHAD JOSHI   Winner                Graduate                  32587745
# MADHU GOUD YASKHI   Winner            Post Graduate             32560000
# CHETAN CHAUHAN                        Graduate                  29825340
# GOVINDA   Winner                      Graduate                  25000000
# KULDEEP BISHNOI   Winner              Graduate                  21865304
# C UDAI BHASKER                        Not Given                 21438399
# MALLIKARJUN S S                       Graduate                  19043113
# KAMBALAPADU EDIGA KRISHNAMURTHI       Not Given                 18682834
# MAHADIK DHANANJAY BHIMRAO             Graduate                  18095000
# SUKHBIR SINGH BADAL   Winner          Post Graduate             17359781
# HINDURAO N. NAIK NIMBALKAR            8th Pass                  17200000
# KRISHNAPPA M                          Graduate                  15451501
# ANGLE RAMAKANT SOIRU                  Graduate                  15431905
# GHISA LAL AGARWALLA                   12th Pass                 13671007
# ANANTHKUMAR HEGDE   Winner            12th Pass                 13401653
# S. P. Y. REDDY   Winner               Graduate Professional     13374000
# ADHALARAO PATIL SHIVAJIRAO   Winner   Post Graduate             12332651
# BADIGA RAMAKRISHNA   Winner           12th Pass                 11559000
# BIRAJ ADHIKARI                        Graduate Professional     11420000
# Name: Liabilities, dtype: int64

# %%
party_data = data[data["Party"].isin(["AAP","SAD","BSP","BJP","INC","IND","Republican Party of India (A)", "Punjab Lok Congress Party"])]
party_data.reset_index()
party_data
# Out:
#                         Candidate Party  Criminal Cases      Education  Age  \
# 0     MANORANJAN BHAKTA   Winner    INC               0  Post Graduate   65
# 1                      A K BISWAS   BSP               0       Graduate   61
# 2                ASIT BARAN DUTTA   IND               0       Graduate   50
# 3                 BISHNU PADA RAY   BJP               0       Graduate   54
# 4                   DEEPAK BISWAS   IND               0      Not Given   28
# ...                           ...   ...             ...            ...  ...
# 3634              Dhananjoy Ghosh   INC               0       Graduate   47
# 3637                   Arjun Saha   BJP               0       Graduate   35
# 3638              Braja Mohon Das   IND               0         Others   62
# 3640            Gopal Chandra Das   INC               0  Post Graduate   35
# 3641           Kartik Chandra Das   BSP               0       Graduate   51
#
#                                            Constituency  Total Assets  \
# 0     Andaman & Nicobar Islands + Andaman & Nicobar ...       5926740
# 1     Andaman & Nicobar Islands + Andaman & Nicobar ...       7876500
# 2     Andaman & Nicobar Islands + Andaman & Nicobar ...       3070000
# 3     Andaman & Nicobar Islands + Andaman & Nicobar ...       1250619
# 4     Andaman & Nicobar Islands + Andaman & Nicobar ...          3000
# ...                                                 ...           ...
# 3634                               Bolpur + West Bengal        939568
# 3637                              Birbhum + West Bengal        515000
# 3638                              Birbhum + West Bengal        357360
# 3640                              Birbhum + West Bengal        119000
# 3641                              Birbhum + West Bengal       3314000
#
#       Liabilities  Year
# 0          272061  2004
# 1           65000  2004
# 2               0  2004
# 3          128710  2004
# 4               0  2004
# ...           ...   ...
# 3634        14000  2004
# 3637            0  2004
# 3638        20000  2004
# 3640            0  2004
# 3641            0  2004
#
# [2344 rows x 9 columns]

# %%
party_sorted = party_data[["Party","Candidate"]].groupby(["Party"]).aggregate(lambda x: len(x.unique())).sort_values(["Candidate"], ascending = False )
party_sorted
# Out:
#        Candidate
# Party
# IND         1257
# INC          380
# BSP          348
# BJP          331
# SAD           10

# %%
party_sorted.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
ed_data = pd.pivot_table(data,values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"]).sort_values(["Candidate"], ascending = False )
ed_data.reset_index()
ed_data.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
ed_party_data = pd.pivot_table(party_data, values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"], columns=["Party"])
ed_party_data.fillna(0)
# Out:
#                       Candidate
# Party                       BJP   BSP    INC    IND  SAD
# Education
# 10th Pass                  23.0  46.0   25.0  194.0  2.0
# 12th Pass                  30.0  32.0   25.0  123.0  0.0
# 5th Pass                    0.0   6.0    3.0   41.0  0.0
# 8th Pass                    4.0  10.0    5.0   92.0  0.0
# Doctorate                  15.0   8.0   14.0   22.0  0.0
# Graduate                  103.0  87.0  111.0  226.0  1.0
# Graduate Professional      39.0  17.0   36.0   40.0  4.0
# Illiterate                  0.0   0.0    0.0   17.0  0.0
# Literate                    6.0  12.0    8.0   77.0  0.0
# Not Given                  14.0  38.0   22.0  231.0  0.0
# Others                     12.0  17.0    6.0   62.0  1.0
# Post Graduate              85.0  75.0  125.0  146.0  2.0

# %%
criminal_data_asc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=False).head(25)
criminal_data_asc = criminal_data_asc.reset_index(drop=True)
criminal_data_asc
# Out:
#                                    Candidate                    Constituency  \
# 0                    ATIQUE AHAMAD   Winner          Phulpur + Uttar Pradesh
# 1                          ANAND MOHAN SINGH                 Sheohar + Bihar
# 2                         MITRASEN   Winner         Faizabad + Uttar Pradesh
# 3            RAJESH RANJAN ALIAS PAPPU YADAV                  Purnea + Bihar
# 4   AKSHAY PRATAP SINGH (GOPAL JI)   Winner       Pratapgarh + Uttar Pradesh
# 5                          AWADESH KU MANDAL                  Purnea + Bihar
# 6                                   AKHILESH     Maharajganj + Uttar Pradesh
# 7                   P. KARUNAKARAN   Winner               Kasaragod + Kerala
# 8                        RANVEER SINGH GUDHA           Jhunjhunu + Rajasthan
# 9             MOHAMMAD SHAHABUDDIN   Winner                    Siwan + Bihar
# 10                     BRAHMESHWAR NATH SIGH                   Arrah + Bihar
# 11                     SURAJ SINGH   Winner                    Balia + Bihar
# 12                        VIJAY KUMAR SHUKLA                Vaishali + Bihar
# 13           AHIR HANSRAJ GANGARAM   Winner         Chandrapur + Maharashtra
# 14                              RANVIR YADAV                   Banka + Bihar
# 15              CHANDRAKANT KHAIRE   Winner         Aurangabad + Maharashtra
# 16   TUKARAM GANPATRAO RENGE PATIL   Winner           Parbhani + Maharashtra
# 17                             SUKHRAM ORAON           Singhbhum + Jharkhand
# 18          ELANGOVAN, E. V. K. S.   Winner   Gobichettipalayam + Tamil Nadu
# 19                       GHISA LAL AGARWALLA                  Tezpur + Assam
# 20                              RAJAN TIWARI                 Bettiah + Bihar
# 21                PRABHUNATH SINGH   Winner              Maharajganj + Bihar
# 22              BHALCHANDRA YADAVA   Winner       Khalilabad + Uttar Pradesh
# 23                 ASHOK KUMAR SINGH CHANDEL        Hamirpur + Uttar Pradesh
# 24                     TASLIMUDDIN   Winner               Kishanganj + Bihar
#
#          Party      Education  Criminal Cases
# 0           SP       8th Pass              36
# 1         BPSP      12th Pass              32
# 2          BSP      12th Pass              27
# 3        LJNSP      12th Pass              27
# 4           SP       Literate              26
# 5          IND       Literate              24
# 6           SP       Graduate              23
# 7          CPM  Post Graduate              20
# 8        LJNSP       Graduate              19
# 9          RJD      Doctorate              19
# 10         IND      12th Pass              19
# 11       LJNSP       Literate              17
# 12         IND       Graduate              16
# 13         BJP      10th Pass              16
# 14          SP      10th Pass              15
# 15         SHS       Graduate              13
# 16         SHS  Post Graduate              13
# 17  AJSU Party      10th Pass              13
# 18         INC       Graduate              13
# 19         BJP      12th Pass              12
# 20         IND       8th Pass              11
# 21       JD(U)      12th Pass              11
# 22         BSP       Graduate              10
# 23         BSP       Graduate              10
# 24         RJD       Literate               9

# %%
criminal_data_dsc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=True).head(25)
criminal_data_dsc = criminal_data_dsc.reset_index(drop=True)
criminal_data_dsc
# Out:
#                           Candidate  \
# 0       MANORANJAN BHAKTA   Winner
# 1          BALWANT SINGH RAMOOWALIA
# 2              RABINDER SINGH SOHIL
# 3                RASHPAL SINGH GILL
# 4   SUKHDEV SINGH DHINDSA   Winner
# 5                     ARVIND KHANNA
# 6   PARAMJIT KAUR GULSHAN   Winner
# 7             BHAGWANT SINGH SAMAON
# 8                      GURNAM SINGH
# 9                      JASVIR SINGH
# 10          KAUSHALYA CHAMAN BHAURA
# 11                  KANWALJIT SINGH
# 12                      ASHOK KUMAR
# 13                    HARMAIL SINGH
# 14                  KARAN KAUR BRAR
# 15                    NAVNEET KUMAR
# 16                     NIRMAL SINGH
# 17                         SANT RAM
# 18                    SUKHBIR SINGH
# 19            AJAY DANIEL ( TINKU )
# 20                 DHIAN SINGH MAND
# 21               JAGMEET SINGH BRAR
# 22                MAHINDERJIT SINGH
# 23                     GURLAL SINGH
# 24          MOHAN SINGH FALIAN WALA
#
#                                          Constituency  \
# 0   Andaman & Nicobar Islands + Andaman & Nicobar ...
# 1                                   Ludhiana + Punjab
# 2                                   Ludhiana + Punjab
# 3                                   Ludhiana + Punjab
# 4                                    Sangrur + Punjab
# 5                                    Sangrur + Punjab
# 6                                   Bhatinda + Punjab
# 7                                   Bhatinda + Punjab
# 8                                   Bhatinda + Punjab
# 9                                   Bhatinda + Punjab
# 10                                  Bhatinda + Punjab
# 11                                   Patiala + Punjab
# 12                                  Faridkot + Punjab
# 13                                  Faridkot + Punjab
# 14                                  Faridkot + Punjab
# 15                                  Faridkot + Punjab
# 16                                  Faridkot + Punjab
# 17                                  Faridkot + Punjab
# 18                                  Faridkot + Punjab
# 19                                 Ferozepur + Punjab
# 20                                 Ferozepur + Punjab
# 21                                 Ferozepur + Punjab
# 22                                 Ferozepur + Punjab
# 23                                  Faridkot + Punjab
# 24                                 Ferozepur + Punjab
#
#                            Party      Education  Criminal Cases
# 0                            INC  Post Graduate               0
# 1                            LBP  Post Graduate               0
# 2                            BSP  Post Graduate               0
# 3                            IND       Graduate               0
# 4                            SAD       Graduate               0
# 5                            INC         Others               0
# 6                            SAD  Post Graduate               0
# 7                     CPI(ML)(L)         Others               0
# 8                            BSP  Post Graduate               0
# 9                            IND       Graduate               0
# 10                           CPI       Graduate               0
# 11                           SAD         Others               0
# 12                         JD(S)      Not Given               0
# 13                           IND      10th Pass               0
# 14                           INC       Graduate               0
# 15                           SHS      12th Pass               0
# 16                         LJNSP      10th Pass               0
# 17                           BSP      10th Pass               0
# 18                           IND      12th Pass               0
# 19                           IND      12th Pass               0
# 20  SAD(A)(Simranjit Singh Mann)         Others               0
# 21                           INC       Graduate               0
# 22                           IND      10th Pass               0
# 23  SAD(A)(Simranjit Singh Mann)      12th Pass               0
# 24                           BSP      10th Pass               0

# %%
criminal_data_asc.groupby("Party").aggregate(np.sum).sort_values("Criminal Cases",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
asset_data = data[["Candidate","Constituency","Party", "Total Assets"]].sort_values('Total Assets', ascending=False).head(25)
asset_data = asset_data.reset_index(drop=True)
asset_data
# Out:
#                                             Candidate  \
# 0                 SRIKANTADATTA NARASIMHARAJA WADIYAR
# 1                                                ALIM
# 2                                        MALOOK NAGAR
# 3                         D.K. AUDIKESAVULU   Winner
# 4                                         VED PRAKASH
# 5                         PALANISAMY, K. C.   Winner
# 6                              PRENEET KAUR   Winner
# 7                                           V.M SINGH
# 8                           MANABENDRA SHAH   Winner
# 9                                    VISHWANATH DUBEY
# 10                               DHARMENDRA   Winner
# 11                           PRATIBHA SINGH   Winner
# 12                                       KRISHNAPPA M
# 13  KISHORE CHANDRA SURYANARAYANA DEO VYRICHERLA  ...
# 14                                    MALLIKARJUN S S
# 15                                       PINAKI MISRA
# 16                       RANA GURJEET SINGH   Winner
# 17                               SUNIL DUTT   Winner
# 18                                      NARESH GUJRAL
# 19                                       N A MOHAMMED
# 20                         MONI KUMAR SUBBA   Winner
# 21                          CHIDAMBARAM, P.   Winner
# 22                                 PRAVEEN SINGH ARON
# 23                                   MADDI LAKSHMAIAH
# 24                              KAPIL SIBAL   Winner
#
#                                          Constituency Party  Total Assets
# 0                                  Mysore + Karnataka   INC   15224553998
# 1   Chandni Chowk + National Capital Territory Of ...   IND    2000080500
# 2                              Meerut + Uttar Pradesh   RLD     762437000
# 3                           Chittoor + Andhra Pradesh   TDP     670576468
# 4                               Bharatpur + Rajasthan   INC     616557379
# 5                                  Karur + Tamil Nadu   DMK     546569007
# 6                                    Patiala + Punjab   INC     412867297
# 7                            Pilibhit + Uttar Pradesh   INC     407555000
# 8                         Tehri Garhwal + Uttaranchal   BJP     347563683
# 9                           Jabalpur + Madhya Pradesh   INC     277530906
# 10                                Bikaner + Rajasthan   BJP     230326000
# 11                           Mandi + Himachal Pradesh   INC     230288018
# 12                        Bangalore South + Karnataka   INC     228924447
# 13                     Parvathipuram + Andhra Pradesh   INC     220678000
# 14                              Davangere + Karnataka   INC     210693494
# 15                                      Puri + Orissa   INC     207245000
# 16                                 Jullundur + Punjab   INC     205828008
# 17                    Mumbai North West + Maharashtra   INC     204321510
# 18                                 Jullundur + Punjab   SAD     192876742
# 19                                 Kasaragod + Kerala   INC     188527614
# 20                                     Tezpur + Assam   INC     186443565
# 21                             Sivaganga + Tamil Nadu   INC     179861587
# 22                           Bareilly + Uttar Pradesh   INC     177736104
# 23                      Narasaraopet + Andhra Pradesh   TDP     169062689
# 24  Chandni Chowk + National Capital Territory Of ...   INC     158850000

# %%
asset_data.groupby("Party").aggregate(np.sum).sort_values("Total Assets",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>
