# %% [markdown]
# # What are the crime rates against sc and other backward classes in different states of India

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("data\crime_by_state_rt.csv").copy()
df
# Out:
#            STATE/UT  Year  Murder  Assault on women  Kidnapping and Abduction  \
# 0    ANDHRA PRADESH  2001      45                69                        22
# 1    ANDHRA PRADESH  2002      60                98                        18
# 2    ANDHRA PRADESH  2003      33                79                        27
# 3    ANDHRA PRADESH  2004      39                66                        28
# 4    ANDHRA PRADESH  2005      37                74                        21
# ..              ...   ...     ...               ...                       ...
# 415      PUDUCHERRY  2008       0                 0                         0
# 416      PUDUCHERRY  2009       0                 0                         0
# 417      PUDUCHERRY  2010       1                 0                         1
# 418      PUDUCHERRY  2011       0                 0                         0
# 419      PUDUCHERRY  2012       2                 0                         0
#
#      Dacoity  Robbery  Arson  Hurt  Prevention of atrocities (POA) Act  \
# 0          3        2      6   518                                 950
# 1          0        4     12   568                                 830
# 2          1       15      4   615                                1234
# 3          0        7     20   474                                1319
# 4          0        0      9   459                                1244
# ..       ...      ...    ...   ...                                 ...
# 415        0        0      0     0                                   2
# 416        0        0      0     0                                   3
# 417        0        0      0     1                                   2
# 418        0        0      0     0                                   1
# 419        0        0      0     0                                   1
#
#      Protection of Civil Rights (PCR) Act  Other Crimes Against SCs
# 0                                     312                      1006
# 1                                     459                      1336
# 2                                     165                      1386
# 3                                      68                      1234
# 4                                      61                      1212
# ..                                    ...                       ...
# 415                                    27                         0
# 416                                    26                         0
# 417                                    26                         0
# 418                                    15                         2
# 419                                    20                         1
#
# [420 rows x 12 columns]

# %%
df.shape
# Out:
# (420, 12)

# %%
df.isnull().sum() # nice we don't have to deal with any null values
# Out:
# STATE/UT                                0
# Year                                    0
# Murder                                  0
# Assault on women                        0
# Kidnapping and Abduction                0
# Dacoity                                 0
# Robbery                                 0
# Arson                                   0
# Hurt                                    0
# Prevention of atrocities (POA) Act      0
# Protection of Civil Rights (PCR) Act    0
# Other Crimes Against SCs                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   STATE/UT                              420 non-null    object
#  1   Year                                  420 non-null    int64
#  2   Murder                                420 non-null    int64
#  3   Assault on women                      420 non-null    int64
#  4   Kidnapping and Abduction              420 non-null    int64
#  5   Dacoity                               420 non-null    int64
#  6   Robbery                               420 non-null    int64
#  7   Arson                                 420 non-null    int64
#  8   Hurt                                  420 non-null    int64
#  9   Prevention of atrocities (POA) Act    420 non-null    int64
#  10  Protection of Civil Rights (PCR) Act  420 non-null    int64
#  11  Other Crimes Against SCs              420 non-null    int64
# dtypes: int64(11), object(1)
# memory usage: 39.5+ KB

# %% [markdown]
# ## EDA

# %%
states=df['STATE/UT'].value_counts().keys()
states
# Out:
# Index(['ANDHRA PRADESH', 'UTTARAKHAND', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'WEST BENGAL', 'NAGALAND',
#        'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI',
#        'LAKSHADWEEP', 'ODISHA', 'MIZORAM', 'ARUNACHAL PRADESH',
#        'HIMACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHHATTISGARH', 'GOA', 'GUJARAT',
#        'HARYANA', 'JAMMU & KASHMIR', 'MEGHALAYA', 'JHARKHAND', 'KARNATAKA',
#        'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'PUDUCHERRY'],
#       dtype='object')

# %%
df.columns
col=[]
for i in df.columns:
    if (i !='STATE/UT') & (i!='Prevention of atrocities (POA) Act') & (i!='Protection of Civil Rights (PCR) Act')&(i!='Year'):
        col.append(i)
col
# Out:
# ['Murder',
#  'Assault on women',
#  'Kidnapping and Abduction',
#  'Dacoity',
#  'Robbery',
#  'Arson',
#  'Hurt',
#  'Other Crimes Against SCs']

# %%
# Now making a final Dictionary for which will contain crimes related to each state
Ans={}
for i in states:
    temp=df[df['STATE/UT']==i]
    dic={}
    for k in col:
        dic[k]=temp[k].sum()
    Ans[i]=dic
Ans
# Out:
# {'ANDHRA PRADESH': {'Murder': 556,
#   'Assault on women': 1110,
#   'Kidnapping and Abduction': 238,
#   'Dacoity': 9,
#   'Robbery': 39,
#   'Arson': 136,
#   'Hurt': 7248,
#   'Other Crimes Against SCs': 17412},
#  'UTTARAKHAND': {'Murder': 50,
#   'Assault on women': 65,
#   'Kidnapping and Abduction': 27,
#   'Dacoity': 0,
#   'Robbery': 1,
#   'Arson': 4,
#   'Hurt': 160,
#   'Other Crimes Against SCs': 45},
#  'PUNJAB': {'Murder': 32,
#   'Assault on women': 115,
#   'Kidnapping and Abduction': 18,
#   'Dacoity': 0,
#   'Robbery': 1,
#   'Arson': 0,
#   'Hurt': 134,
#   'Other Crimes Against SCs': 502},
#  'RAJASTHAN': {'Murder': 630,
#   'Assault on women': 1909,
#   'Kidnapping and Abduction': 365,
#   'Dacoity': 1,
#   'Robbery': 33,
#   'Arson': 481,
#   'Hurt': 5984,
#   'Other Crimes Against SCs': 37653},
#  'SIKKIM': {'Murder': 8,
#   'Assault on women': 17,
#   'Kidnapping and Abduction': 8,
#   'Dacoity': 0,
#   'Robbery': 4,
#   'Arson': 2,
#   'Hurt': 39,
#   'Other Crimes Against SCs': 18},
#  'TAMIL NADU': {'Murder': 352,
#   'Assault on women': 259,
#   'Kidnapping and Abduction': 62,
#   'Dacoity': 5,
#   'Robbery': 15,
#   'Arson': 89,
#   'Hurt': 2269,
#   'Other Crimes Against SCs': 4227},
#  'TRIPURA': {'Murder': 4,
#   'Assault on women': 15,
#   'Kidnapping and Abduction': 6,
#   'Dacoity': 0,
#   'Robbery': 1,
#   'Arson': 1,
#   'Hurt': 64,
#   'Other Crimes Against SCs': 84},
#  'UTTAR PRADESH': {'Murder': 3577,
#   'Assault on women': 3625,
#   'Kidnapping and Abduction': 2225,
#   'Dacoity': 55,
#   'Robbery': 214,
#   'Arson': 715,
#   'Hurt': 4889,
#   'Other Crimes Against SCs': 34294},
#  'WEST BENGAL': {'Murder': 2,
#   'Assault on women': 19,
#   'Kidnapping and Abduction': 1,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 1,
#   'Hurt': 26,
#   'Other Crimes Against SCs': 148},
#  'NAGALAND': {'Murder': 12,
#   'Assault on women': 6,
#   'Kidnapping and Abduction': 1,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 31},
#  'A & N ISLANDS': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'CHANDIGARH': {'Murder': 0,
#   'Assault on women': 2,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 4},
#  'D & N HAVELI': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 2,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 5},
#  'DAMAN & DIU': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 5},
#  'DELHI': {'Murder': 1,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 10},
#  'LAKSHADWEEP': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'ODISHA': {'Murder': 158,
#   'Assault on women': 574,
#   'Kidnapping and Abduction': 135,
#   'Dacoity': 18,
#   'Robbery': 67,
#   'Arson': 170,
#   'Hurt': 3281,
#   'Other Crimes Against SCs': 4274},
#  'MIZORAM': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 1,
#   'Dacoity': 0,
#   'Robbery': 1,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'ARUNACHAL PRADESH': {'Murder': 1,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 1,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'HIMACHAL PRADESH': {'Murder': 10,
#   'Assault on women': 93,
#   'Kidnapping and Abduction': 2,
#   'Dacoity': 8,
#   'Robbery': 6,
#   'Arson': 1,
#   'Hurt': 11,
#   'Other Crimes Against SCs': 329},
#  'ASSAM': {'Murder': 57,
#   'Assault on women': 57,
#   'Kidnapping and Abduction': 96,
#   'Dacoity': 14,
#   'Robbery': 33,
#   'Arson': 25,
#   'Hurt': 341,
#   'Other Crimes Against SCs': 318},
#  'BIHAR': {'Murder': 286,
#   'Assault on women': 284,
#   'Kidnapping and Abduction': 127,
#   'Dacoity': 29,
#   'Robbery': 77,
#   'Arson': 309,
#   'Hurt': 4524,
#   'Other Crimes Against SCs': 3814},
#  'CHHATTISGARH': {'Murder': 117,
#   'Assault on women': 661,
#   'Kidnapping and Abduction': 43,
#   'Dacoity': 1,
#   'Robbery': 13,
#   'Arson': 17,
#   'Hurt': 743,
#   'Other Crimes Against SCs': 2672},
#  'GOA': {'Murder': 0,
#   'Assault on women': 1,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 1,
#   'Other Crimes Against SCs': 13},
#  'GUJARAT': {'Murder': 204,
#   'Assault on women': 325,
#   'Kidnapping and Abduction': 301,
#   'Dacoity': 85,
#   'Robbery': 214,
#   'Arson': 115,
#   'Hurt': 3271,
#   'Other Crimes Against SCs': 5399},
#  'HARYANA': {'Murder': 128,
#   'Assault on women': 447,
#   'Kidnapping and Abduction': 221,
#   'Dacoity': 1,
#   'Robbery': 10,
#   'Arson': 32,
#   'Hurt': 524,
#   'Other Crimes Against SCs': 1148},
#  'JAMMU & KASHMIR': {'Murder': 3,
#   'Assault on women': 7,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 1,
#   'Hurt': 7,
#   'Other Crimes Against SCs': 12},
#  'MEGHALAYA': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'JHARKHAND': {'Murder': 65,
#   'Assault on women': 129,
#   'Kidnapping and Abduction': 44,
#   'Dacoity': 16,
#   'Robbery': 2,
#   'Arson': 22,
#   'Hurt': 912,
#   'Other Crimes Against SCs': 1507},
#  'KARNATAKA': {'Murder': 302,
#   'Assault on women': 329,
#   'Kidnapping and Abduction': 70,
#   'Dacoity': 17,
#   'Robbery': 19,
#   'Arson': 20,
#   'Hurt': 1939,
#   'Other Crimes Against SCs': 7455},
#  'KERALA': {'Murder': 36,
#   'Assault on women': 782,
#   'Kidnapping and Abduction': 23,
#   'Dacoity': 5,
#   'Robbery': 9,
#   'Arson': 21,
#   'Hurt': 2023,
#   'Other Crimes Against SCs': 2231},
#  'MADHYA PRADESH': {'Murder': 1062,
#   'Assault on women': 4107,
#   'Kidnapping and Abduction': 510,
#   'Dacoity': 9,
#   'Robbery': 96,
#   'Arson': 446,
#   'Hurt': 9993,
#   'Other Crimes Against SCs': 30721},
#  'MAHARASHTRA': {'Murder': 243,
#   'Assault on women': 979,
#   'Kidnapping and Abduction': 151,
#   'Dacoity': 122,
#   'Robbery': 97,
#   'Arson': 109,
#   'Hurt': 766,
#   'Other Crimes Against SCs': 5354},
#  'MANIPUR': {'Murder': 0,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 0,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 0,
#   'Other Crimes Against SCs': 0},
#  'PUDUCHERRY': {'Murder': 4,
#   'Assault on women': 0,
#   'Kidnapping and Abduction': 1,
#   'Dacoity': 0,
#   'Robbery': 0,
#   'Arson': 0,
#   'Hurt': 5,
#   'Other Crimes Against SCs': 7}}

# %%
df['Total crimes']=(df['Murder'])+(df['Assault on women'])+(df['Kidnapping and Abduction'])+(df['Dacoity'])+(df['Robbery'])+(df['Arson'])+(df['Hurt'])+(df['Other Crimes Against SCs'])
df
# Out:
#            STATE/UT  Year  Murder  Assault on women  Kidnapping and Abduction  \
# 0    ANDHRA PRADESH  2001      45                69                        22
# 1    ANDHRA PRADESH  2002      60                98                        18
# 2    ANDHRA PRADESH  2003      33                79                        27
# 3    ANDHRA PRADESH  2004      39                66                        28
# 4    ANDHRA PRADESH  2005      37                74                        21
# ..              ...   ...     ...               ...                       ...
# 415      PUDUCHERRY  2008       0                 0                         0
# 416      PUDUCHERRY  2009       0                 0                         0
# 417      PUDUCHERRY  2010       1                 0                         1
# 418      PUDUCHERRY  2011       0                 0                         0
# 419      PUDUCHERRY  2012       2                 0                         0
#
#      Dacoity  Robbery  Arson  Hurt  Prevention of atrocities (POA) Act  \
# 0          3        2      6   518                                 950
# 1          0        4     12   568                                 830
# 2          1       15      4   615                                1234
# 3          0        7     20   474                                1319
# 4          0        0      9   459                                1244
# ..       ...      ...    ...   ...                                 ...
# 415        0        0      0     0                                   2
# 416        0        0      0     0                                   3
# 417        0        0      0     1                                   2
# 418        0        0      0     0                                   1
# 419        0        0      0     0                                   1
#
#      Protection of Civil Rights (PCR) Act  Other Crimes Against SCs  \
# 0                                     312                      1006
# 1                                     459                      1336
# 2                                     165                      1386
# 3                                      68                      1234
# 4                                      61                      1212
# ..                                    ...                       ...
# 415                                    27                         0
# 416                                    26                         0
# 417                                    26                         0
# 418                                    15                         2
# 419                                    20                         1
#
#      Total crimes
# 0            1671
# 1            2096
# 2            2160
# 3            1868
# 4            1812
# ..            ...
# 415             0
# 416             0
# 417             3
# 418             2
# 419             3
#
# [420 rows x 13 columns]

# %%
# Total crimes for each state
total={}
for i in states:
    temp=df[df['STATE/UT']==i]
    total[i]=temp['Total crimes'].sum()
total
# Out:
# {'ANDHRA PRADESH': 26748,
#  'UTTARAKHAND': 352,
#  'PUNJAB': 802,
#  'RAJASTHAN': 47056,
#  'SIKKIM': 96,
#  'TAMIL NADU': 7278,
#  'TRIPURA': 175,
#  'UTTAR PRADESH': 49594,
#  'WEST BENGAL': 197,
#  'NAGALAND': 50,
#  'A & N ISLANDS': 0,
#  'CHANDIGARH': 6,
#  'D & N HAVELI': 7,
#  'DAMAN & DIU': 5,
#  'DELHI': 11,
#  'LAKSHADWEEP': 0,
#  'ODISHA': 8677,
#  'MIZORAM': 2,
#  'ARUNACHAL PRADESH': 2,
#  'HIMACHAL PRADESH': 460,
#  'ASSAM': 941,
#  'BIHAR': 9450,
#  'CHHATTISGARH': 4267,
#  'GOA': 15,
#  'GUJARAT': 9914,
#  'HARYANA': 2511,
#  'JAMMU & KASHMIR': 30,
#  'MEGHALAYA': 0,
#  'JHARKHAND': 2697,
#  'KARNATAKA': 10151,
#  'KERALA': 5130,
#  'MADHYA PRADESH': 46944,
#  'MAHARASHTRA': 7821,
#  'MANIPUR': 0,
#  'PUDUCHERRY': 17}

# %%
total=dict(sorted(total.items(), key=lambda item: item[1]))
total
# Out:
# {'A & N ISLANDS': 0,
#  'LAKSHADWEEP': 0,
#  'MEGHALAYA': 0,
#  'MANIPUR': 0,
#  'MIZORAM': 2,
#  'ARUNACHAL PRADESH': 2,
#  'DAMAN & DIU': 5,
#  'CHANDIGARH': 6,
#  'D & N HAVELI': 7,
#  'DELHI': 11,
#  'GOA': 15,
#  'PUDUCHERRY': 17,
#  'JAMMU & KASHMIR': 30,
#  'NAGALAND': 50,
#  'SIKKIM': 96,
#  'TRIPURA': 175,
#  'WEST BENGAL': 197,
#  'UTTARAKHAND': 352,
#  'HIMACHAL PRADESH': 460,
#  'PUNJAB': 802,
#  'ASSAM': 941,
#  'HARYANA': 2511,
#  'JHARKHAND': 2697,
#  'CHHATTISGARH': 4267,
#  'KERALA': 5130,
#  'TAMIL NADU': 7278,
#  'MAHARASHTRA': 7821,
#  'ODISHA': 8677,
#  'BIHAR': 9450,
#  'GUJARAT': 9914,
#  'KARNATAKA': 10151,
#  'ANDHRA PRADESH': 26748,
#  'MADHYA PRADESH': 46944,
#  'RAJASTHAN': 47056,
#  'UTTAR PRADESH': 49594}

# %%
plt.figure(figsize=(9,9))
plt.bar(total.keys(),total.values())
plt.xticks(rotation=85)
plt.title('Total Crimes vs State')
plt.show()

# %% [markdown]
# # Observation 1 - Uttar Pradesh , Rajasthan , MP ,Andhra Pradesh ,Karnataka are the top 5 cities with most no of crimes against Backward Classes
# # Mizoram,Manipur,Meghalaya Lakshadweep are some states with almost zero crimes agnaist Backward Classes

# %%
women={}
for i in states:
    temp=df[df['STATE/UT']==i]
    women[i]=temp['Assault on women'].sum()
women
# Out:
# {'ANDHRA PRADESH': 1110,
#  'UTTARAKHAND': 65,
#  'PUNJAB': 115,
#  'RAJASTHAN': 1909,
#  'SIKKIM': 17,
#  'TAMIL NADU': 259,
#  'TRIPURA': 15,
#  'UTTAR PRADESH': 3625,
#  'WEST BENGAL': 19,
#  'NAGALAND': 6,
#  'A & N ISLANDS': 0,
#  'CHANDIGARH': 2,
#  'D & N HAVELI': 0,
#  'DAMAN & DIU': 0,
#  'DELHI': 0,
#  'LAKSHADWEEP': 0,
#  'ODISHA': 574,
#  'MIZORAM': 0,
#  'ARUNACHAL PRADESH': 0,
#  'HIMACHAL PRADESH': 93,
#  'ASSAM': 57,
#  'BIHAR': 284,
#  'CHHATTISGARH': 661,
#  'GOA': 1,
#  'GUJARAT': 325,
#  'HARYANA': 447,
#  'JAMMU & KASHMIR': 7,
#  'MEGHALAYA': 0,
#  'JHARKHAND': 129,
#  'KARNATAKA': 329,
#  'KERALA': 782,
#  'MADHYA PRADESH': 4107,
#  'MAHARASHTRA': 979,
#  'MANIPUR': 0,
#  'PUDUCHERRY': 0}

# %%
women=dict(sorted(women.items(), key=lambda item: item[1]))
women
# Out:
# {'A & N ISLANDS': 0,
#  'D & N HAVELI': 0,
#  'DAMAN & DIU': 0,
#  'DELHI': 0,
#  'LAKSHADWEEP': 0,
#  'MIZORAM': 0,
#  'ARUNACHAL PRADESH': 0,
#  'MEGHALAYA': 0,
#  'MANIPUR': 0,
#  'PUDUCHERRY': 0,
#  'GOA': 1,
#  'CHANDIGARH': 2,
#  'NAGALAND': 6,
#  'JAMMU & KASHMIR': 7,
#  'TRIPURA': 15,
#  'SIKKIM': 17,
#  'WEST BENGAL': 19,
#  'ASSAM': 57,
#  'UTTARAKHAND': 65,
#  'HIMACHAL PRADESH': 93,
#  'PUNJAB': 115,
#  'JHARKHAND': 129,
#  'TAMIL NADU': 259,
#  'BIHAR': 284,
#  'GUJARAT': 325,
#  'KARNATAKA': 329,
#  'HARYANA': 447,
#  'ODISHA': 574,
#  'CHHATTISGARH': 661,
#  'KERALA': 782,
#  'MAHARASHTRA': 979,
#  'ANDHRA PRADESH': 1110,
#  'RAJASTHAN': 1909,
#  'UTTAR PRADESH': 3625,
#  'MADHYA PRADESH': 4107}

# %%
women1=list(women.keys())[-6:-1]
women2=list(women.values())[-6:-1]

# %%
plt.pie(women2,labels=women1,autopct='%.1f%%')
plt.title('Crime Against Women')
plt.show()

# %% [markdown]
# # Observation 2- We can see the top 5 states with most crimes against women

# %%
year=list(df['Year'].unique())
year
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]

# %%
year_total={}
for i in year:
    temp=df[df['Year']==i]
    year_total[str(i)]=temp['Total crimes'].sum()
year_total
# Out:
# {'2001': 19755,
#  '2002': 21719,
#  '2003': 17570,
#  '2004': 17632,
#  '2005': 17339,
#  '2006': 18084,
#  '2007': 20006,
#  '2008': 21686,
#  '2009': 22207,
#  '2010': 22081,
#  '2011': 22310,
#  '2012': 21017}

# %%
plt.bar(year_total.keys(),year_total.values())
plt.show()

# %% [markdown]
# # Observation 3 - Crimes against Backward classes decreased from 2001 to 2003 and remained still for 4 years till 2006
# # But from 2006 crimes significantly increased
