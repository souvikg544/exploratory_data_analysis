# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("tmdb_5000_movies.csv")

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
type(df.release_date[0])
# Out:
# str

# %%
df=df.drop(labels='homepage',axis=1)
df=df.drop(labels='tagline',axis=1)

# %%
df=df[df.release_date.isnull()==False]

# %%
df.runtime[df.runtime.isnull()==False].mean()
# Out:
# 106.898125

# %%
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
len(df.release_date)
# Out:
# 4802

# %%
df['year']='na'

# %%
for i in range(4802):
    s=df.release_date.iloc[i].split("-")
    df.year[i]=s[0]
# Out:
# C:\Users\91842\AppData\Local\Temp\ipykernel_13820\3306661112.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\91842\AppData\Local\Temp\ipykernel_13820\3306661112.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.year=pd.Series(df['year'], dtype="int")

# %%
df[df.year=='na']
# Out:
#       budget                               genres     id  \
# 4802       0  [{"id": 99, "name": "Documentary"}]  25975
#
#                                                keywords original_language  \
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#          original_title                                           overview  \
# 4802  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  \
# 4802    1.929883  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  revenue  \
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05        0
#
#       runtime                          spoken_languages    status  \
# 4802     90.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                   title  vote_average  vote_count year
# ...

# %%
df.year.iloc[4801]=2005
# Out:
# C:\Users\91842\AppData\Local\Temp\ipykernel_13820\3431299839.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x=df.genres.value_counts()
y=df.year.value_counts()

# %%
import plotly.express as px
figlc = px.scatter(df,x='year', y='genres',title="Change in genres over years")
figlc.show()
# Out:
# <div>                            <div id="ce564a3b-fc4c-4cda-b2da-384611816875" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce564a3b-fc4c-4cda-b2da-384611816875")) {                    Plotly.newPlot(                        "ce564a3b-fc4c-4cda-b2da-384611816875",                        [{"hovertemplate":"year=%{x}<br>genres=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["2009","2007","2015","2012","2012","2007","2010","2015","2009","2016","2006","2008","2006","2013","2013","2008","2012","2011","2012","2014","2012","2010","2013","2007","2005","1997","2016","2012","2015","2012","2004","2013","2010","2006","2013","2009","2014","2013","2014","2010","2011","2011"
# ...
