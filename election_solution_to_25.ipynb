# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('/2004-2019.csv')

# %%
df.head()
# Out:
#                     Candidate Constituency Party  Criminal Cases  \
# 0  MADHUSUDHAN REDDY THAKKALA     Adilabad   TRS               0
# 1          CHENGARA SURENDRAN        Adoor   CPI               0
# 2                  RAJ BABBAR         Agra    SP               2
# 3                HARIN PATHAK    Ahmedabad   BJP               1
# 4    GADAKH TUKARAM GANGADHAR   Ahmednagar   NCP               2
#
#                Education  Total Assets  Liabilities  Year
# 0  Graduate Professional       7550000       120000  2004
# 1               Graduate          6274        41438  2004
# 2               Graduate      22326400      1000000  2004
# 3  Graduate Professional      10287931            0  2004
# 4               Graduate      23446680      4680000  2004

# %%
df.shape
# Out:
# (2118, 8)

# %%
df.isnull().sum()
# Out:
# Candidate         0
# Constituency      0
# Party             0
# Criminal Cases    0
# Education         0
# Total Assets      0
# Liabilities       0
# Year              0
# dtype: int64

# %%
df.isnull()
# Out:
#       Candidate  Constituency  Party  Criminal Cases  Education  Total Assets  \
# 0         False         False  False           False      False         False
# 1         False         False  False           False      False         False
# 2         False         False  False           False      False         False
# 3         False         False  False           False      False         False
# 4         False         False  False           False      False         False
# ...         ...           ...    ...             ...        ...           ...
# 2113      False         False  False           False      False         False
# 2114      False         False  False           False      False         False
# 2115      False         False  False           False      False         False
# 2116      False         False  False           False      False         False
# 2117      False         False  False           False      False         False
#
#       Liabilities   Year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2118 entries, 0 to 2117
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       2118 non-null   object
#  1   Constituency    2118 non-null   object
#  2   Party           2118 non-null   object
#  3   Criminal Cases  2118 non-null   int64
#  4   Education       2118 non-null   object
#  5   Total Assets    2118 non-null   int64
#  6   Liabilities     2118 non-null   int64
#  7   Year            2118 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 132.5+ KB

# %%
df.describe()
# Out:
#        Criminal Cases  Total Assets   Liabilities         Year
# count     2118.000000  2.118000e+03  2.118000e+03  2118.000000
# mean         1.278093  1.092130e+08  1.389721e+07  2011.618036
# std          5.506607  3.699401e+08  7.857403e+07     5.581787
# min          0.000000  0.000000e+00  0.000000e+00  2004.000000
# 25%          0.000000  6.110977e+06  0.000000e+00  2009.000000
# 50%          0.000000  1.946278e+07  4.827675e+05  2014.000000
# 75%          1.000000  6.580133e+07  3.128824e+06  2019.000000
# max        204.000000  6.830581e+09  1.547511e+09  2019.000000

# %%
plt.figure(figsize=(12,6))
sns.set_theme(style="white")
corr = df.corr()
sns.heatmap(corr, annot=True, annot_kws={"size": 7})

# %%
sns.pairplot(df)
plt.show()

# %%
sns.barplot(x='Party',y='Criminal Cases',data=df)

# %%
df1= df[['Party', 'Education', 'Criminal Cases']]
df1
# Out:
#      Party              Education  Criminal Cases
# 0      TRS  Graduate Professional               0
# 1      CPI               Graduate               0
# 2       SP               Graduate               2
# 3      BJP  Graduate Professional               1
# 4      NCP               Graduate               2
# ...    ...                    ...             ...
# 2113   BJP              10th Pass               0
# 2114   INC          Post Graduate               5
# 2115   BJP          Post Graduate               0
# 2116   SHS               Graduate               3
# 2117   TRS               Graduate              18
#
# [2118 rows x 3 columns]

# %%
df1.corr()
# Out:
#                 Criminal Cases
# Criminal Cases             1.0

# %%
print(df1['Education'].corr(df1['Criminal Cases']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-a40939adb4a2> in <module>
# ----> 1 print(df1['Education'].corr(df1['Criminal Cases']))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2508             return nanops.nancorr(
# -> 2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#    2511
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# ...

# %%
plt.figure(figsize=(20, 20))
cmap = sns.diverging_palette(222, 10, as_cmap=True)
_ = sns.heatmap(df1.corr(), annot=True, vmax=.8, square=True, cmap=cmap)

# %%
figure = plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True,cmap=plt.cm.cool)
plt.tight_layout()
plt.xlabel('Corr')
plt.show()
